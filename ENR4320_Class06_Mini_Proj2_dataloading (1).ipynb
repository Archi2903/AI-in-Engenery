# %% [markdown]
# # Seismic Image Classification

# %% [markdown]
# ### 1. Data loading

# %%
import matplotlib.pyplot as plt
import numpy as np

# read npy format data
datadir='./my_data_fault/'
X_syn = np.load(datadir+'synth_500_proc.npy')
X_fld = np.load(datadir+'field_500_proc.npy')
# print(X_org.shape, Y_org.shape)
print(X_syn.shape)
print(X_fld.shape)
# Out:
# (500, 128, 128)
# (500, 128, 128)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_label_comp(data1, data2, image_index):

    fig, axes = plt.subplots(1, 2, figsize=(8, 4))

    # 첫 번째 subplot
    im1 = axes[0].imshow(np.transpose(data1[image_index]), cmap='gray_r', interpolation='none')
    axes[0].set_title('seismic image 1')

    # 첫 번째 subplot에 대한 colorbar (세로 크기 동일)
    divider1 = make_axes_locatable(axes[0])
    cax1 = divider1.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im1, cax=cax1)

    # 두 번째 subplot
    im2 = axes[1].imshow(np.transpose(data2[image_index]), cmap='gray_r', interpolation='none')
    axes[1].set_title('seismic image 2')

    # 두 번째 subplot에 대한 colorbar (세로 크기 동일)
    divider2 = make_axes_locatable(axes[1])
    cax2 = divider2.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im2, cax=cax2)

    plt.tight_layout()
    plt.show()

# %%
plot_label_comp(X_syn, X_fld, 250)
