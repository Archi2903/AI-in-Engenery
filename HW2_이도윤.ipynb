# %% [markdown]
# <a href="https://colab.research.google.com/github/Archi2903/AI-in-Engenery/blob/main/HW2_%EC%9D%B4%EB%8F%84%EC%9C%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Energy resources and artificial intelligence 이도윤22251844
#
# HW#01 - XOR model
#
# 내용:
# Using Keras (tf.keras), train and compare a single-layer perceptron and a small MLP (e.g. one hidden layer) to learn the logical gates AND, OR, and XOR on the four 2-bit inputs.
#
# Report final accuracy for each gate, show the models’ predictions (and optionally a loss curve).
#
# Submit the jupyter notebook file.

# %%
# Set random seeds for reproducibility 42
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# DATA 준비
X = np.array([
    [0., 0.],
    [0., 1.],
    [1., 0.],
    [1., 1.]
])

# Target labels for each task (AND, OR, XOR)
y_AND = np.array([[0.], [0.], [0.], [1.]])
y_OR  = np.array([[0.], [1.], [1.], [1.]])
y_XOR = np.array([[0.], [1.], [1.], [0.]])

# Defenite main functions(perceptron, mlp_xor, train)
def perceptron(input_dim=2):        # input_dim - binary input (0 and 1) )
    """function perceptron (AND/OR)."""
    model = keras.Sequential([
                              # Sequential - model type (a linear stack of layers)
        keras.layers.Dense(1,    # Dense - fully connected layer with 1 neuron
                           activation='sigmoid',    # sigmoid - activation function (outputs values between 0 and 1)
                           input_shape=(input_dim,)) # input_shape - shape of the input data (2 features)
    ]) #
    model.compile(  # compile the model with specified parameters
        optimizer=keras.optimizers.SGD(learning_rate=0.1), # optimizer - Stochastic Gradient Descent with learning rate 0.1
        loss='binary_crossentropy', # loss function - binary crossentropy (suitable for binary classification)
        metrics=['accuracy'] # metrics - accuracy to evaluate the model's performance
    )
    return model

def mlp_xor(input_dim=2):
    """function mlp_xor (XOR)"""
    model = keras.Sequential([
        keras.layers.Dense(2, # hidden layer with 4 neurons,because XOR is not linearly separable
                           activation='sigmoid', #
                           input_shape=(input_dim,)),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(
        optimizer=keras.optimizers.SGD(learning_rate=0.1), # optimizer - Stochastic Gradient Descent with learning rate 0.1
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

def train(name, model, X, y, epochs): # name : AND/OR/XOR , model - perceptron, X - bin data(0,1), y , epochs - number training
    model.fit(X, y, epochs=epochs, verbose=0) # verbose=0 - no output during training
    print(f"Logical gate \n{name} - probabilities and rounding (threshold 0.5)") # if value > 0.5,then 1, else 0
    for a, b in X:
        p = model.predict(np.array([[a, b]], dtype=np.float32), verbose=0)[0, 0]
        print(f"{int(a)} {name} {int(b)} -> prob={p:.4f} pred={int(p>=0.5)}")

    print("Weights:", [w.shape for w in model.get_weights()])

# %% [markdown]
# Training perceptron
#
# # Training models for AND, OR, XOR logical gates

# %%
# 1.Simulation situacion Underfitting (epochs=5) ~3 sec calculation

# Training AND
model_and = perceptron()
train("AND", model_and, X, y_AND, epochs=5) # epochs - число эпох обучения

# Training OR
model_or = perceptron()
train("OR", model_or, X, y_OR, epochs=5)

# Training XOR(model - perceptron)
model_xor = perceptron()
train("XOR", model_xor, X, y_XOR, epochs=5)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Logical gate
# AND - probabilities and rounding (threshold 0.5)
# 0 AND 0 -> prob=0.4829 pred=0
# 0 AND 1 -> prob=0.2056 pred=0
# 1 AND 0 -> prob=0.5722 pred=1
# 1 AND 1 -> prob=0.2704 pred=0
# Weights: [(2, 1), (1,)]
# Logical gate
# OR - probabilities and rounding (threshold 0.5)
# 0 OR 0 -> prob=0.5298 pred=1
# 0 OR 1 -> prob=0.5963 pred=1
# 1 OR 0 -> prob=0.4956 pred=0
# 1 OR 1 -> prob=0.5629 pred=1
# Weights: [(2, 1), (1,)]
# Logical gate
# XOR - probabilities and rounding (threshold 0.5)
# 0 XOR 0 -> prob=0.4963 pred=0
# 0 XOR 1 -> prob=0.4228 pred=0
# 1 XOR 0 -> prob=0.6281 pred=1
# 1 XOR 1 -> prob=0.5567 pred=1
# Weights: [(2, 1), (1,)]

# %%
# 1.Simulation situacion derfitting (epochs>300) ~40 sec calculation!

# Training AND
model_and = perceptron()
train("AND", model_and, X, y_AND, epochs=300) # epochs - number training
# Training OR
model_or = perceptron()
train("OR", model_or, X, y_OR, epochs=300)

# Training XOR(model - perceptron)
model_xor = perceptron()
train("XOR", model_xor, X, y_XOR, epochs=300)
# Out:
# Logical gate
# AND - probabilities and rounding (threshold 0.5)
# 0 AND 0 -> prob=0.0638 pred=0
# 0 AND 1 -> prob=0.2433 pred=0
# 1 AND 0 -> prob=0.2562 pred=0
# 1 AND 1 -> prob=0.6191 pred=1
# Weights: [(2, 1), (1,)]
# Logical gate
# OR - probabilities and rounding (threshold 0.5)
# 0 OR 0 -> prob=0.4184 pred=0
# 0 OR 1 -> prob=0.8174 pred=1
# 1 OR 0 -> prob=0.8968 pred=1
# 1 OR 1 -> prob=0.9818 pred=1
# Weights: [(2, 1), (1,)]
# Logical gate
# XOR - probabilities and rounding (threshold 0.5)
# 0 XOR 0 -> prob=0.4931 pred=0
# 0 XOR 1 -> prob=0.5222 pred=1
# 1 XOR 0 -> prob=0.4756 pred=0
# 1 XOR 1 -> prob=0.5047 pred=1
# Weights: [(2, 1), (1,)]

# %% [markdown]
# # Problem XOR
# A simple perceptron model is not suitable for learning the XOR logical gate, because the XOR function is not linearly separable. Therefore, a more complex model (such as a multilayer perceptron with a hidden layer) will be used for training.

# %%
# Training XOR with MLP(Success only big epochs>10000) ~7minutes calculation!!!!!!!!!
model_xor = mlp_xor()
train("XOR", model_xor, X, y_XOR, epochs=5000)
"T4 5000 epochs ~3min  test:1-0, 2-0,3 - x, 4-x"
# Out:
# Logical gate
# XOR - probabilities and rounding (threshold 0.5)
# 0 XOR 0 -> prob=0.0508 pred=0
# 0 XOR 1 -> prob=0.9259 pred=1
# 1 XOR 0 -> prob=0.9256 pred=1
# 1 XOR 1 -> prob=0.1294 pred=0
# Weights: [(2, 2), (2,), (2, 1), (1,)]
# 'T4 5000 epochs ~3min  test:1-0, 2-0,3 - x, 4-x'

# %% [markdown]
# # **HW #02 - Automatic differentiation**
# 22251844 이도윤
# ## Write a program that prints out the gradients of your neural network model (designed to solve the XOR problem) at each epoch during training, so that you can observe how the weights change throughout the training process.

# %%
"For output the gradients at each epoch in tensorflow has tf.GradientTape"

"1.Add loss function and optimization method SGD"
# Selection of the loss function (MSE) and the optimization method (SGD) for training
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)

"2. Write function every epoch with Gradient"
# A training loop for 1000 epochs with gradient computation and output; for gradient output the tf.GradientTape() API is used
for epoch in range(10000):
    # operation for auti different
    with tf.GradientTape() as tape:
        y_pred = model_xor(X)                             # forward
        loss_value = tf.reduce_mean(tf.square(y_pred - y_XOR))  # MSE: the mean squared difference between the prediction and the target value
    # We compute the gradients of the loss function with respect to all trainable parameters (weights and biases)

    gradients = tape.gradient(loss_value, model_xor.trainable_variables)
    # update the model parameters at each step of gradient descent
    optimizer.apply_gradients(zip(gradients, model_xor.trainable_variables))
    # We output the gradients for each parameter at the current epoch
    print(f"Epoch {epoch}:")
    for var, grad in zip(model_xor.trainable_variables, gradients):
        print(f"Gradient for {var.name}: {grad.numpy()}")

# Check
predictions = model_xor(X).numpy()


print("True labels (y):", y_XOR.reshape(-1))          # True XOR
print("Predictions after training:", predictions.reshape(-1))  # Predict

"Result: wrtite programm"
"A program has been written to output the gradients at each epoch using TensorFlow s GradientTape library, and it has been tested. "
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Epoch 9286:
# Gradient for kernel: [[-0.00112719 -0.00133021]
#  [ 0.0010929   0.00134344]]
# Gradient for bias: [ 0.00048352 -0.00067756]
# Gradient for kernel: [[-0.00243906]
#  [ 0.00257714]]
# Gradient for bias: [-0.00132649]
# Epoch 9287:
# Gradient for kernel: [[-0.00112691 -0.00132988]
#  [ 0.00109264  0.0013431 ]]
# Gradient for bias: [ 0.0004834  -0.00067739]
# Gradient for kernel: [[-0.00243854]
#  [ 0.00257656]]
# Gradient for bias: [-0.0013262]
# Epoch 9288:
# Gradient for kernel: [[-0.00112663 -0.00132955]
#  [ 0.00109238  0.00134277]]
# Gradient for bias: [ 0.00048329 -0.00067722]
# Gradient for kernel: [[-0.00243802]
#  [ 0.00257599]]
# Gradient for bias: [-0.0013259]
# Epoch 9289:
# Gradient for kernel: [[-0.00112636 -0.00132922]
#  [ 0.00109212  0.00134243]]
# Gradient for bias: [ 0.00048318 -0.00067706]
# Gradient for kernel: [[-0.0024375 ]
#  [ 0.00257543]]
# Gradient for bias: [-0.00132559]
# Epoch 9290:
# Gradient for kernel: [[-0.00112609 -0.00132889]
#  [ 0.00109186  0.0013421 ]]
# Gradient for bias: [ 0.00048306 -0.00067688]
# Gradient for kernel: [[-0.00243699]
#  [ 0.00257485]]
# Gradient for bias: [-0.00132531]
# Epoch 9291:
# Gradient for kernel: [[-0.00112581 -0.00132856]
#  [ 0.0010916   0.00134176]]
# Gradient for bias: [ 0.00048295 -0.00067672]
# Gradient for kernel: [[-0.00243647]
#  [ 0.00257428]]
# Gradient for bias: [-0.001325]
# Epoch 9292:
# Gradient for kernel: [[-0.00112554 -0.00132822]
#  [ 0.00109134  0.00134143]]
# Gradient for bias: [ 0.00048283 -0.00067655]
# Gradient for kernel: [[-0.00243596]
#  [ 0.00257371]]
# Gradient for bias: [-0.00132471]
# Epoch 9293:
# Gradient for kernel: [[-0.00112527 -0.00132789]
#  [ 0.00109108  0.0013411 ]]
# Gradient for bias: [ 0.00048272 -0.00067637]
# Gradient for kernel: [[-0.00243544]
#  [ 0.00257313]]
# Gradient for bias: [-0.00132443]
# Epoch 9294:
# Gradient for kernel: [[-0.00112499 -0.00132757]
#  [ 0.00109083  0.00134076]]
# Gradient for bias: [ 0.00048261 -0.00067621]
# Gradient for kernel: [[-0.00243492]
#  [ 0.00257257]]
# Gradient for bias: [-0.00132411]
# Epoch 9295:
# Gradient for kernel: [[-0.00112471 -0.00132723]
#  [ 0.00109056  0.00134044]]
# Gradient for bias: [ 0.0004825  -0.00067603]
# Gradient for kernel: [[-0.0024344 ]
#  [ 0.00257199]]
# Gradient for bias: [-0.00132383]
# Epoch 9296:
# Gradient for kernel: [[-0.00112444 -0.0013269 ]
#  [ 0.00109031  0.00134011]]
# Gradient for bias: [ 0.00048238 -0.00067586]
# Gradient for kernel: [[-0.00243389]
#  [ 0.00257142]]
# Gradient for bias: [-0.00132354]
# Epoch 9297:
# Gradient for kernel: [[-0.00112416 -0.00132658]
#  [ 0.00109005  0.00133977]]
# Gradient for bias: [ 0.00048228 -0.0006757 ]
# Gradient for kernel: [[-0.00243337]
#  [ 0.00257086]]
# Gradient for bias: [-0.00132323]
# Epoch 9298:
# Gradient for kernel: [[-0.00112389 -0.00132625]
#  [ 0.00108979  0.00133943]]
# Gradient for bias: [ 0.00048216 -0.00067554]
# Gradient for kernel: [[-0.00243285]
#  [ 0.00257029]]
# Gradient for bias: [-0.00132293]
# Epoch 9299:
# Gradient for kernel: [[-0.00112361 -0.00132591]
#  [ 0.00108953  0.0013391 ]]
# Gradient for bias: [ 0.00048206 -0.00067536]
# Gradient for kernel: [[-0.00243233]
#  [ 0.00256973]]
# Gradient for bias: [-0.00132264]
# Epoch 9300:
# Gradient for kernel: [[-0.00112334 -0.00132559]
#  [ 0.00108928  0.00133876]]
# Gradient for bias: [ 0.00048194 -0.0006752 ]
# Gradient for kernel: [[-0.00243182]
#  [ 0.00256916]]
# Gradient for bias: [-0.00132234]
# Epoch 9301:
# Gradient for kernel: [[-0.00112306 -0.00132526]
#  [ 0.00108902  0.00133843]]
# Gradient for bias: [ 0.00048183 -0.00067503]
# Gradient for kernel: [[-0.0024313]
#  [ 0.0025686]]
# Gradient for bias: [-0.00132204]
# Epoch 9302:
# Gradient for kernel: [[-0.00112278 -0.00132493]
#  [ 0.00108876  0.0013381 ]]
# Gradient for bias: [ 0.00048173 -0.00067486]
# Gradient for kernel: [[-0.00243078]
#  [ 0.00256804]]
# Gradient for bias: [-0.00132174]
# Epoch 9303:
# Gradient for kernel: [[-0.00112251 -0.0013246 ]
#  [ 0.0010885   0.00133776]]
# Gradient for bias: [ 0.00048161 -0.00067469]
# Gradient for kernel: [[-0.00243027]
#  [ 0.00256746]]
# Gradient for bias: [-0.00132145]
# Epoch 9304:
# Gradient for kernel: [[-0.00112224 -0.00132427]
#  [ 0.00108825  0.00133743]]
# Gradient for bias: [ 0.0004815  -0.00067453]
# Gradient for kernel: [[-0.00242975]
#  [ 0.00256689]]
# Gradient for bias: [-0.00132115]
# Epoch 9305:
# Gradient for kernel: [[-0.00112196 -0.00132394]
#  [ 0.00108799  0.0013371 ]]
# Gradient for bias: [ 0.00048139 -0.00067435]
# Gradient for kernel: [[-0.00242924]
#  [ 0.00256633]]
# Gradient for bias: [-0.00132086]
# Epoch 9306:
# Gradient for kernel: [[-0.00112169 -0.00132361]
#  [ 0.00108773  0.00133677]]
# Gradient for bias: [ 0.00048127 -0.00067418]
# Gradient for kernel: [[-0.00242872]
#  [ 0.00256576]]
# Gradient for bias: [-0.00132057]
# Epoch 9307:
# Gradient for kernel: [[-0.00112142 -0.00132329]
#  [ 0.00108747  0.00133644]]
# Gradient for bias: [ 0.00048116 -0.00067402]
# Gradient for kernel: [[-0.00242821]
#  [ 0.00256518]]
# Gradient for bias: [-0.00132028]
# Epoch 9308:
# Gradient for kernel: [[-0.00112115 -0.00132296]
#  [ 0.00108722  0.00133611]]
# Gradient for bias: [ 0.00048105 -0.00067384]
# Gradient for kernel: [[-0.0024277 ]
#  [ 0.00256462]]
# Gradient for bias: [-0.00131999]
# Epoch 9309:
# Gradient for kernel: [[-0.00112088 -0.00132263]
#  [ 0.00108696  0.00133578]]
# Gradient for bias: [ 0.00048093 -0.00067368]
# Gradient for kernel: [[-0.00242719]
#  [ 0.00256405]]
# Gradient for bias: [-0.00131969]
# Epoch 9310:
# Gradient for kernel: [[-0.00112061 -0.0013223 ]
#  [ 0.0010867   0.00133545]]
# Gradient for bias: [ 0.00048082 -0.00067351]
# Gradient for kernel: [[-0.00242667]
#  [ 0.00256348]]
# Gradient for bias: [-0.0013194]
# Epoch 9311:
# Gradient for kernel: [[-0.00112033 -0.00132197]
#  [ 0.00108644  0.00133512]]
# Gradient for bias: [ 0.0004807  -0.00067333]
# Gradient for kernel: [[-0.00242616]
#  [ 0.00256291]]
# Gradient for bias: [-0.00131912]
# Epoch 9312:
# Gradient for kernel: [[-0.00112006 -0.00132165]
#  [ 0.00108619  0.00133479]]
# Gradient for bias: [ 0.0004806  -0.00067317]
# Gradient for kernel: [[-0.00242565]
#  [ 0.00256235]]
# Gradient for bias: [-0.00131881]
# Epoch 9313:
# Gradient for kernel: [[-0.00111979 -0.00132132]
#  [ 0.00108593  0.00133445]]
# Gradient for bias: [ 0.00048049 -0.00067301]
# Gradient for kernel: [[-0.00242513]
#  [ 0.00256179]]
# Gradient for bias: [-0.00131851]
# Epoch 9314:
# Gradient for kernel: [[-0.00111951 -0.00132099]
#  [ 0.00108568  0.00133412]]
# Gradient for bias: [ 0.00048038 -0.00067284]
# Gradient for kernel: [[-0.00242461]
#  [ 0.00256123]]
# Gradient for bias: [-0.00131821]
# Epoch 9315:
# Gradient for kernel: [[-0.00111924 -0.00132067]
#  [ 0.00108542  0.00133379]]
# Gradient for bias: [ 0.00048026 -0.00067268]
# Gradient for kernel: [[-0.00242411]
#  [ 0.00256066]]
# Gradient for bias: [-0.00131792]
# Epoch 9316:
# Gradient for kernel: [[-0.00111897 -0.00132034]
#  [ 0.00108516  0.00133346]]
# Gradient for bias: [ 0.00048016 -0.00067251]
# Gradient for kernel: [[-0.00242359]
#  [ 0.0025601 ]]
# Gradient for bias: [-0.00131762]
# Epoch 9317:
# Gradient for kernel: [[-0.00111869 -0.00132001]
#  [ 0.00108491  0.00133313]]
# Gradient for bias: [ 0.00048004 -0.00067234]
# Gradient for kernel: [[-0.00242308]
#  [ 0.00255953]]
# Gradient for bias: [-0.00131733]
# Epoch 9318:
# Gradient for kernel: [[-0.00111842 -0.00131969]
#  [ 0.00108465  0.0013328 ]]
# Gradient for bias: [ 0.00047994 -0.00067218]
# Gradient for kernel: [[-0.00242257]
#  [ 0.00255897]]
# Gradient for bias: [-0.00131704]
# Epoch 9319:
# Gradient for kernel: [[-0.00111814 -0.00131936]
#  [ 0.0010844   0.00133247]]
# Gradient for bias: [ 0.00047983 -0.00067201]
# Gradient for kernel: [[-0.00242205]
#  [ 0.00255841]]
# Gradient for bias: [-0.00131674]
# Epoch 9320:
# Gradient for kernel: [[-0.00111787 -0.00131903]
#  [ 0.00108414  0.00133213]]
# Gradient for bias: [ 0.00047972 -0.00067184]
# Gradient for kernel: [[-0.00242154]
#  [ 0.00255785]]
# Gradient for bias: [-0.00131644]
# Epoch 9321:
# Gradient for kernel: [[-0.0011176  -0.0013187 ]
#  [ 0.00108388  0.00133181]]
# Gradient for bias: [ 0.0004796  -0.00067167]
# Gradient for kernel: [[-0.00242103]
#  [ 0.00255728]]
# Gradient for bias: [-0.00131616]
# Epoch 9322:
# Gradient for kernel: [[-0.00111733 -0.00131838]
#  [ 0.00108363  0.00133148]]
# Gradient for bias: [ 0.00047949 -0.0006715 ]
# Gradient for kernel: [[-0.00242051]
#  [ 0.00255672]]
# Gradient for bias: [-0.00131586]
# Epoch 9323:
# Gradient for kernel: [[-0.00111706 -0.00131805]
#  [ 0.00108337  0.00133115]]
# Gradient for bias: [ 0.00047938 -0.00067134]
# Gradient for kernel: [[-0.00242001]
#  [ 0.00255615]]
# Gradient for bias: [-0.00131557]
# Epoch 9324:
# Gradient for kernel: [[-0.00111679 -0.00131773]
#  [ 0.00108312  0.00133082]]
# Gradient for bias: [ 0.00047927 -0.00067117]
# Gradient for kernel: [[-0.00241949]
#  [ 0.00255559]]
# Gradient for bias: [-0.00131528]
# Epoch 9325:
# Gradient for kernel: [[-0.00111652 -0.0013174 ]
#  [ 0.00108286  0.00133049]]
# Gradient for bias: [ 0.00047915 -0.000671  ]
# Gradient for kernel: [[-0.00241899]
#  [ 0.00255502]]
# Gradient for bias: [-0.001315]
# Epoch 9326:
# Gradient for kernel: [[-0.00111625 -0.00131708]
#  [ 0.00108261  0.00133016]]
# Gradient for bias: [ 0.00047904 -0.00067084]
# Gradient for kernel: [[-0.00241848]
#  [ 0.00255446]]
# Gradient for bias: [-0.0013147]
# Epoch 9327:
# Gradient for kernel: [[-0.00111598 -0.00131675]
#  [ 0.00108235  0.00132983]]
# Gradient for bias: [ 0.00047894 -0.00067067]
# Gradient for kernel: [[-0.00241796]
#  [ 0.0025539 ]]
# Gradient for bias: [-0.0013144]
# Epoch 9328:
# Gradient for kernel: [[-0.00111571 -0.00131643]
#  [ 0.0010821   0.00132951]]
# Gradient for bias: [ 0.00047882 -0.0006705 ]
# Gradient for kernel: [[-0.00241746]
#  [ 0.00255333]]
# Gradient for bias: [-0.00131413]
# Epoch 9329:
# Gradient for kernel: [[-0.00111544 -0.0013161 ]
#  [ 0.00108184  0.00132917]]
# Gradient for bias: [ 0.00047871 -0.00067034]
# Gradient for kernel: [[-0.00241694]
#  [ 0.00255278]]
# Gradient for bias: [-0.00131382]
# Epoch 9330:
# Gradient for kernel: [[-0.00111517 -0.00131578]
#  [ 0.00108159  0.00132885]]
# Gradient for bias: [ 0.0004786  -0.00067017]
# Gradient for kernel: [[-0.00241643]
#  [ 0.00255222]]
# Gradient for bias: [-0.00131353]
# Epoch 9331:
# Gradient for kernel: [[-0.00111489 -0.00131546]
#  [ 0.00108133  0.00132852]]
# Gradient for bias: [ 0.0004785  -0.00067001]
# Gradient for kernel: [[-0.00241592]
#  [ 0.00255166]]
# Gradient for bias: [-0.00131323]
# Epoch 9332:
# Gradient for kernel: [[-0.00111462 -0.00131513]
#  [ 0.00108108  0.00132818]]
# Gradient for bias: [ 0.00047839 -0.00066985]
# Gradient for kernel: [[-0.00241541]
#  [ 0.00255111]]
# Gradient for bias: [-0.00131292]
# Epoch 9333:
# Gradient for kernel: [[-0.00111435 -0.0013148 ]
#  [ 0.00108082  0.00132786]]
# Gradient for bias: [ 0.00047827 -0.00066968]
# Gradient for kernel: [[-0.0024149 ]
#  [ 0.00255054]]
# Gradient for bias: [-0.00131264]
# Epoch 9334:
# Gradient for kernel: [[-0.00111408 -0.00131448]
#  [ 0.00108057  0.00132753]]
# Gradient for bias: [ 0.00047816 -0.00066951]
# Gradient for kernel: [[-0.00241439]
#  [ 0.00254998]]
# Gradient for bias: [-0.00131235]
# Epoch 9335:
# Gradient for kernel: [[-0.00111381 -0.00131416]
#  [ 0.00108032  0.0013272 ]]
# Gradient for bias: [ 0.00047805 -0.00066934]
# Gradient for kernel: [[-0.00241388]
#  [ 0.00254942]]
# Gradient for bias: [-0.00131207]
# Epoch 9336:
# Gradient for kernel: [[-0.00111355 -0.00131383]
#  [ 0.00108006  0.00132688]]
# Gradient for bias: [ 0.00047794 -0.00066917]
# Gradient for kernel: [[-0.00241338]
#  [ 0.00254885]]
# Gradient for bias: [-0.00131178]
# Epoch 9337:
# Gradient for kernel: [[-0.00111327 -0.0013135 ]
#  [ 0.00107981  0.00132655]]
# Gradient for bias: [ 0.00047783 -0.000669  ]
# Gradient for kernel: [[-0.00241287]
#  [ 0.00254829]]
# Gradient for bias: [-0.0013115]
# Epoch 9338:
# Gradient for kernel: [[-0.00111301 -0.00131318]
#  [ 0.00107955  0.00132623]]
# Gradient for bias: [ 0.00047772 -0.00066883]
# Gradient for kernel: [[-0.00241236]
#  [ 0.00254773]]
# Gradient for bias: [-0.00131121]
# Epoch 9339:
# Gradient for kernel: [[-0.00111273 -0.00131285]
#  [ 0.0010793   0.0013259 ]]
# Gradient for bias: [ 0.00047761 -0.00066867]
# Gradient for kernel: [[-0.00241185]
#  [ 0.00254717]]
# Gradient for bias: [-0.00131091]
# Epoch 9340:
# Gradient for kernel: [[-0.00111247 -0.00131254]
#  [ 0.00107905  0.00132557]]
# Gradient for bias: [ 0.0004775  -0.00066851]
# Gradient for kernel: [[-0.00241135]
#  [ 0.00254661]]
# Gradient for bias: [-0.00131062]
# Epoch 9341:
# Gradient for kernel: [[-0.00111219 -0.00131221]
#  [ 0.00107879  0.00132524]]
# Gradient for bias: [ 0.00047739 -0.00066834]
# Gradient for kernel: [[-0.00241083]
#  [ 0.00254606]]
# Gradient for bias: [-0.00131032]
# Epoch 9342:
# Gradient for kernel: [[-0.00111192 -0.00131189]
#  [ 0.00107854  0.00132491]]
# Gradient for bias: [ 0.00047728 -0.00066818]
# Gradient for kernel: [[-0.00241033]
#  [ 0.00254551]]
# Gradient for bias: [-0.00131002]
# Epoch 9343:
# Gradient for kernel: [[-0.00111166 -0.00131157]
#  [ 0.00107829  0.00132459]]
# Gradient for bias: [ 0.00047717 -0.00066801]
# Gradient for kernel: [[-0.00240982]
#  [ 0.00254494]]
# Gradient for bias: [-0.00130974]
# Epoch 9344:
# Gradient for kernel: [[-0.00111139 -0.00131124]
#  [ 0.00107803  0.00132426]]
# Gradient for bias: [ 0.00047706 -0.00066785]
# Gradient for kernel: [[-0.00240931]
#  [ 0.00254438]]
# Gradient for bias: [-0.00130945]
# Epoch 9345:
# Gradient for kernel: [[-0.00111112 -0.00131092]
#  [ 0.00107778  0.00132393]]
# Gradient for bias: [ 0.00047695 -0.00066769]
# Gradient for kernel: [[-0.00240881]
#  [ 0.00254382]]
# Gradient for bias: [-0.00130916]
# Epoch 9346:
# Gradient for kernel: [[-0.00111085 -0.0013106 ]
#  [ 0.00107753  0.00132361]]
# Gradient for bias: [ 0.00047684 -0.00066752]
# Gradient for kernel: [[-0.0024083 ]
#  [ 0.00254326]]
# Gradient for bias: [-0.00130887]
# Epoch 9347:
# Gradient for kernel: [[-0.00111058 -0.00131028]
#  [ 0.00107727  0.00132328]]
# Gradient for bias: [ 0.00047673 -0.00066735]
# Gradient for kernel: [[-0.0024078]
#  [ 0.0025427]]
# Gradient for bias: [-0.00130859]
# Epoch 9348:
# Gradient for kernel: [[-0.00111031 -0.00130995]
#  [ 0.00107702  0.00132296]]
# Gradient for bias: [ 0.00047662 -0.00066719]
# Gradient for kernel: [[-0.00240729]
#  [ 0.00254215]]
# Gradient for bias: [-0.00130829]
# Epoch 9349:
# Gradient for kernel: [[-0.00111004 -0.00130963]
#  [ 0.00107677  0.00132263]]
# Gradient for bias: [ 0.00047651 -0.00066703]
# Gradient for kernel: [[-0.00240678]
#  [ 0.0025416 ]]
# Gradient for bias: [-0.00130799]
# Epoch 9350:
# Gradient for kernel: [[-0.00110977 -0.00130931]
#  [ 0.00107652  0.0013223 ]]
# Gradient for bias: [ 0.0004764  -0.00066686]
# Gradient for kernel: [[-0.00240627]
#  [ 0.00254105]]
# Gradient for bias: [-0.0013077]
# Epoch 9351:
# Gradient for kernel: [[-0.0011095  -0.00130899]
#  [ 0.00107626  0.00132198]]
# Gradient for bias: [ 0.0004763  -0.00066669]
# Gradient for kernel: [[-0.00240577]
#  [ 0.00254049]]
# Gradient for bias: [-0.00130741]
# Epoch 9352:
# Gradient for kernel: [[-0.00110924 -0.00130866]
#  [ 0.00107601  0.00132166]]
# Gradient for bias: [ 0.00047618 -0.00066652]
# Gradient for kernel: [[-0.00240526]
#  [ 0.00253992]]
# Gradient for bias: [-0.00130714]
# Epoch 9353:
# Gradient for kernel: [[-0.00110897 -0.00130834]
#  [ 0.00107576  0.00132134]]
# Gradient for bias: [ 0.00047607 -0.00066635]
# Gradient for kernel: [[-0.00240476]
#  [ 0.00253936]]
# Gradient for bias: [-0.00130685]
# Epoch 9354:
# Gradient for kernel: [[-0.0011087  -0.00130802]
#  [ 0.0010755   0.00132101]]
# Gradient for bias: [ 0.00047596 -0.00066619]
# Gradient for kernel: [[-0.00240426]
#  [ 0.0025388 ]]
# Gradient for bias: [-0.00130657]
# Epoch 9355:
# Gradient for kernel: [[-0.00110844 -0.0013077 ]
#  [ 0.00107525  0.00132068]]
# Gradient for bias: [ 0.00047585 -0.00066603]
# Gradient for kernel: [[-0.00240375]
#  [ 0.00253825]]
# Gradient for bias: [-0.00130627]
# Epoch 9356:
# Gradient for kernel: [[-0.00110817 -0.00130738]
#  [ 0.001075    0.00132036]]
# Gradient for bias: [ 0.00047574 -0.00066587]
# Gradient for kernel: [[-0.00240325]
#  [ 0.0025377 ]]
# Gradient for bias: [-0.00130598]
# Epoch 9357:
# Gradient for kernel: [[-0.0011079  -0.00130706]
#  [ 0.00107475  0.00132003]]
# Gradient for bias: [ 0.00047563 -0.0006657 ]
# Gradient for kernel: [[-0.00240274]
#  [ 0.00253715]]
# Gradient for bias: [-0.00130569]
# Epoch 9358:
# Gradient for kernel: [[-0.00110763 -0.00130674]
#  [ 0.0010745   0.00131971]]
# Gradient for bias: [ 0.00047553 -0.00066554]
# Gradient for kernel: [[-0.00240223]
#  [ 0.0025366 ]]
# Gradient for bias: [-0.0013054]
# Epoch 9359:
# Gradient for kernel: [[-0.00110737 -0.00130642]
#  [ 0.00107425  0.00131938]]
# Gradient for bias: [ 0.00047541 -0.00066538]
# Gradient for kernel: [[-0.00240173]
#  [ 0.00253603]]
# Gradient for bias: [-0.00130511]
# Epoch 9360:
# Gradient for kernel: [[-0.0011071  -0.00130609]
#  [ 0.001074    0.00131906]]
# Gradient for bias: [ 0.00047531 -0.00066521]
# Gradient for kernel: [[-0.00240122]
#  [ 0.00253549]]
# Gradient for bias: [-0.00130482]
# Epoch 9361:
# Gradient for kernel: [[-0.00110683 -0.00130578]
#  [ 0.00107374  0.00131873]]
# Gradient for bias: [ 0.0004752  -0.00066505]
# Gradient for kernel: [[-0.00240072]
#  [ 0.00253493]]
# Gradient for bias: [-0.00130453]
# Epoch 9362:
# Gradient for kernel: [[-0.00110656 -0.00130546]
#  [ 0.00107349  0.00131841]]
# Gradient for bias: [ 0.00047508 -0.00066489]
# Gradient for kernel: [[-0.00240022]
#  [ 0.00253437]]
# Gradient for bias: [-0.00130425]
# Epoch 9363:
# Gradient for kernel: [[-0.0011063  -0.00130514]
#  [ 0.00107324  0.00131808]]
# Gradient for bias: [ 0.00047497 -0.00066472]
# Gradient for kernel: [[-0.00239972]
#  [ 0.00253381]]
# Gradient for bias: [-0.00130396]
# Epoch 9364:
# Gradient for kernel: [[-0.00110603 -0.00130481]
#  [ 0.00107299  0.00131776]]
# Gradient for bias: [ 0.00047487 -0.00066456]
# Gradient for kernel: [[-0.00239921]
#  [ 0.00253327]]
# Gradient for bias: [-0.00130366]
# Epoch 9365:
# Gradient for kernel: [[-0.00110576 -0.00130449]
#  [ 0.00107274  0.00131744]]
# Gradient for bias: [ 0.00047477 -0.00066439]
# Gradient for kernel: [[-0.0023987 ]
#  [ 0.00253272]]
# Gradient for bias: [-0.00130338]
# Epoch 9366:
# Gradient for kernel: [[-0.00110549 -0.00130417]
#  [ 0.00107249  0.00131711]]
# Gradient for bias: [ 0.00047466 -0.00066423]
# Gradient for kernel: [[-0.0023982 ]
#  [ 0.00253217]]
# Gradient for bias: [-0.00130308]
# Epoch 9367:
# Gradient for kernel: [[-0.00110523 -0.00130385]
#  [ 0.00107224  0.0013168 ]]
# Gradient for bias: [ 0.00047455 -0.00066406]
# Gradient for kernel: [[-0.0023977 ]
#  [ 0.00253162]]
# Gradient for bias: [-0.0013028]
# Epoch 9368:
# Gradient for kernel: [[-0.00110496 -0.00130353]
#  [ 0.00107199  0.00131647]]
# Gradient for bias: [ 0.00047444 -0.00066389]
# Gradient for kernel: [[-0.0023972 ]
#  [ 0.00253106]]
# Gradient for bias: [-0.00130252]
# Epoch 9369:
# Gradient for kernel: [[-0.00110469 -0.00130321]
#  [ 0.00107174  0.00131615]]
# Gradient for bias: [ 0.00047433 -0.00066374]
# Gradient for kernel: [[-0.00239669]
#  [ 0.00253051]]
# Gradient for bias: [-0.00130222]
# Epoch 9370:
# Gradient for kernel: [[-0.00110443 -0.00130289]
#  [ 0.00107149  0.00131583]]
# Gradient for bias: [ 0.00047422 -0.00066357]
# Gradient for kernel: [[-0.00239619]
#  [ 0.00252996]]
# Gradient for bias: [-0.00130194]
# Epoch 9371:
# Gradient for kernel: [[-0.00110416 -0.00130258]
#  [ 0.00107124  0.00131551]]
# Gradient for bias: [ 0.00047411 -0.0006634 ]
# Gradient for kernel: [[-0.00239569]
#  [ 0.00252939]]
# Gradient for bias: [-0.00130167]
# Epoch 9372:
# Gradient for kernel: [[-0.00110389 -0.00130226]
#  [ 0.00107099  0.00131518]]
# Gradient for bias: [ 0.000474   -0.00066324]
# Gradient for kernel: [[-0.00239519]
#  [ 0.00252885]]
# Gradient for bias: [-0.00130137]
# Epoch 9373:
# Gradient for kernel: [[-0.00110363 -0.00130194]
#  [ 0.00107074  0.00131485]]
# Gradient for bias: [ 0.0004739  -0.00066309]
# Gradient for kernel: [[-0.00239469]
#  [ 0.0025283 ]]
# Gradient for bias: [-0.00130107]
# Epoch 9374:
# Gradient for kernel: [[-0.00110336 -0.00130162]
#  [ 0.00107049  0.00131454]]
# Gradient for bias: [ 0.00047379 -0.00066292]
# Gradient for kernel: [[-0.00239418]
#  [ 0.00252775]]
# Gradient for bias: [-0.00130079]
# Epoch 9375:
# Gradient for kernel: [[-0.0011031  -0.0013013 ]
#  [ 0.00107024  0.00131421]]
# Gradient for bias: [ 0.00047368 -0.00066276]
# Gradient for kernel: [[-0.00239368]
#  [ 0.0025272 ]]
# Gradient for bias: [-0.0013005]
# Epoch 9376:
# Gradient for kernel: [[-0.00110283 -0.00130098]
#  [ 0.00106999  0.00131389]]
# Gradient for bias: [ 0.00047357 -0.0006626 ]
# Gradient for kernel: [[-0.00239318]
#  [ 0.00252665]]
# Gradient for bias: [-0.00130021]
# Epoch 9377:
# Gradient for kernel: [[-0.00110257 -0.00130066]
#  [ 0.00106974  0.00131357]]
# Gradient for bias: [ 0.00047346 -0.00066243]
# Gradient for kernel: [[-0.00239268]
#  [ 0.00252609]]
# Gradient for bias: [-0.00129994]
# Epoch 9378:
# Gradient for kernel: [[-0.0011023  -0.00130035]
#  [ 0.00106949  0.00131324]]
# Gradient for bias: [ 0.00047335 -0.00066227]
# Gradient for kernel: [[-0.00239218]
#  [ 0.00252555]]
# Gradient for bias: [-0.00129964]
# Epoch 9379:
# Gradient for kernel: [[-0.00110204 -0.00130002]
#  [ 0.00106924  0.00131293]]
# Gradient for bias: [ 0.00047324 -0.0006621 ]
# Gradient for kernel: [[-0.00239169]
#  [ 0.00252498]]
# Gradient for bias: [-0.00129937]
# Epoch 9380:
# Gradient for kernel: [[-0.00110178 -0.00129971]
#  [ 0.00106899  0.00131261]]
# Gradient for bias: [ 0.00047313 -0.00066193]
# Gradient for kernel: [[-0.00239118]
#  [ 0.00252444]]
# Gradient for bias: [-0.00129908]
# Epoch 9381:
# Gradient for kernel: [[-0.00110152 -0.00129939]
#  [ 0.00106874  0.00131229]]
# Gradient for bias: [ 0.00047302 -0.00066177]
# Gradient for kernel: [[-0.00239069]
#  [ 0.00252388]]
# Gradient for bias: [-0.00129881]
# Epoch 9382:
# Gradient for kernel: [[-0.00110125 -0.00129907]
#  [ 0.00106849  0.00131197]]
# Gradient for bias: [ 0.00047292 -0.00066161]
# Gradient for kernel: [[-0.00239019]
#  [ 0.00252334]]
# Gradient for bias: [-0.00129851]
# Epoch 9383:
# Gradient for kernel: [[-0.00110098 -0.00129875]
#  [ 0.00106824  0.00131164]]
# Gradient for bias: [ 0.00047281 -0.00066145]
# Gradient for kernel: [[-0.00238968]
#  [ 0.00252279]]
# Gradient for bias: [-0.00129822]
# Epoch 9384:
# Gradient for kernel: [[-0.00110072 -0.00129844]
#  [ 0.00106799  0.00131132]]
# Gradient for bias: [ 0.0004727  -0.00066129]
# Gradient for kernel: [[-0.00238919]
#  [ 0.00252224]]
# Gradient for bias: [-0.00129794]
# Epoch 9385:
# Gradient for kernel: [[-0.00110045 -0.00129812]
#  [ 0.00106774  0.001311  ]]
# Gradient for bias: [ 0.00047259 -0.00066112]
# Gradient for kernel: [[-0.00238869]
#  [ 0.00252169]]
# Gradient for bias: [-0.00129765]
# Epoch 9386:
# Gradient for kernel: [[-0.00110019 -0.0012978 ]
#  [ 0.00106749  0.00131069]]
# Gradient for bias: [ 0.00047248 -0.00066096]
# Gradient for kernel: [[-0.00238819]
#  [ 0.00252114]]
# Gradient for bias: [-0.00129738]
# Epoch 9387:
# Gradient for kernel: [[-0.00109992 -0.00129749]
#  [ 0.00106725  0.00131036]]
# Gradient for bias: [ 0.00047238 -0.0006608 ]
# Gradient for kernel: [[-0.00238769]
#  [ 0.0025206 ]]
# Gradient for bias: [-0.00129708]
# Epoch 9388:
# Gradient for kernel: [[-0.00109965 -0.00129717]
#  [ 0.001067    0.00131004]]
# Gradient for bias: [ 0.00047228 -0.00066064]
# Gradient for kernel: [[-0.00238719]
#  [ 0.00252005]]
# Gradient for bias: [-0.00129679]
# Epoch 9389:
# Gradient for kernel: [[-0.00109939 -0.00129686]
#  [ 0.00106675  0.00130972]]
# Gradient for bias: [ 0.00047217 -0.00066048]
# Gradient for kernel: [[-0.00238669]
#  [ 0.00251951]]
# Gradient for bias: [-0.0012965]
# Epoch 9390:
# Gradient for kernel: [[-0.00109913 -0.00129654]
#  [ 0.0010665   0.0013094 ]]
# Gradient for bias: [ 0.00047206 -0.00066032]
# Gradient for kernel: [[-0.00238619]
#  [ 0.00251896]]
# Gradient for bias: [-0.00129621]
# Epoch 9391:
# Gradient for kernel: [[-0.00109886 -0.00129622]
#  [ 0.00106625  0.00130907]]
# Gradient for bias: [ 0.00047196 -0.00066016]
# Gradient for kernel: [[-0.00238569]
#  [ 0.00251842]]
# Gradient for bias: [-0.00129592]
# Epoch 9392:
# Gradient for kernel: [[-0.0010986  -0.00129591]
#  [ 0.00106601  0.00130875]]
# Gradient for bias: [ 0.00047185 -0.00066   ]
# Gradient for kernel: [[-0.00238519]
#  [ 0.00251787]]
# Gradient for bias: [-0.00129564]
# Epoch 9393:
# Gradient for kernel: [[-0.00109834 -0.00129559]
#  [ 0.00106576  0.00130844]]
# Gradient for bias: [ 0.00047174 -0.00065984]
# Gradient for kernel: [[-0.0023847 ]
#  [ 0.00251732]]
# Gradient for bias: [-0.00129536]
# Epoch 9394:
# Gradient for kernel: [[-0.00109808 -0.00129527]
#  [ 0.00106551  0.00130812]]
# Gradient for bias: [ 0.00047162 -0.00065967]
# Gradient for kernel: [[-0.0023842 ]
#  [ 0.00251677]]
# Gradient for bias: [-0.00129508]
# Epoch 9395:
# Gradient for kernel: [[-0.00109781 -0.00129496]
#  [ 0.00106526  0.0013078 ]]
# Gradient for bias: [ 0.00047152 -0.00065951]
# Gradient for kernel: [[-0.0023837 ]
#  [ 0.00251623]]
# Gradient for bias: [-0.00129479]
# Epoch 9396:
# Gradient for kernel: [[-0.00109755 -0.00129464]
#  [ 0.00106501  0.00130749]]
# Gradient for bias: [ 0.00047141 -0.00065934]
# Gradient for kernel: [[-0.00238321]
#  [ 0.00251567]]
# Gradient for bias: [-0.00129452]
# Epoch 9397:
# Gradient for kernel: [[-0.00109729 -0.00129432]
#  [ 0.00106476  0.00130717]]
# Gradient for bias: [ 0.0004713  -0.00065917]
# Gradient for kernel: [[-0.00238271]
#  [ 0.00251512]]
# Gradient for bias: [-0.00129424]
# Epoch 9398:
# Gradient for kernel: [[-0.00109702 -0.00129401]
#  [ 0.00106452  0.00130685]]
# Gradient for bias: [ 0.00047119 -0.00065902]
# Gradient for kernel: [[-0.00238221]
#  [ 0.00251458]]
# Gradient for bias: [-0.00129394]
# Epoch 9399:
# Gradient for kernel: [[-0.00109676 -0.00129369]
#  [ 0.00106427  0.00130653]]
# Gradient for bias: [ 0.00047109 -0.00065886]
# Gradient for kernel: [[-0.00238172]
#  [ 0.00251404]]
# Gradient for bias: [-0.00129365]
# Epoch 9400:
# Gradient for kernel: [[-0.0010965  -0.00129338]
#  [ 0.00106402  0.00130621]]
# Gradient for bias: [ 0.00047098 -0.0006587 ]
# Gradient for kernel: [[-0.00238122]
#  [ 0.00251349]]
# Gradient for bias: [-0.00129337]
# Epoch 9401:
# Gradient for kernel: [[-0.00109624 -0.00129306]
#  [ 0.00106377  0.00130589]]
# Gradient for bias: [ 0.00047087 -0.00065853]
# Gradient for kernel: [[-0.00238072]
#  [ 0.00251295]]
# Gradient for bias: [-0.00129309]
# Epoch 9402:
# Gradient for kernel: [[-0.00109597 -0.00129275]
#  [ 0.00106353  0.00130557]]
# Gradient for bias: [ 0.00047077 -0.00065838]
# Gradient for kernel: [[-0.00238023]
#  [ 0.0025124 ]]
# Gradient for bias: [-0.0012928]
# Epoch 9403:
# Gradient for kernel: [[-0.00109571 -0.00129244]
#  [ 0.00106328  0.00130525]]
# Gradient for bias: [ 0.00047066 -0.00065822]
# Gradient for kernel: [[-0.00237974]
#  [ 0.00251185]]
# Gradient for bias: [-0.00129252]
# Epoch 9404:
# Gradient for kernel: [[-0.00109544 -0.00129212]
#  [ 0.00106303  0.00130493]]
# Gradient for bias: [ 0.00047056 -0.00065805]
# Gradient for kernel: [[-0.00237923]
#  [ 0.00251131]]
# Gradient for bias: [-0.00129223]
# Epoch 9405:
# Gradient for kernel: [[-0.00109519 -0.00129181]
#  [ 0.00106279  0.00130461]]
# Gradient for bias: [ 0.00047044 -0.00065789]
# Gradient for kernel: [[-0.00237875]
#  [ 0.00251076]]
# Gradient for bias: [-0.00129197]
# Epoch 9406:
# Gradient for kernel: [[-0.00109493 -0.00129149]
#  [ 0.00106254  0.00130429]]
# Gradient for bias: [ 0.00047033 -0.00065773]
# Gradient for kernel: [[-0.00237825]
#  [ 0.00251021]]
# Gradient for bias: [-0.00129168]
# Epoch 9407:
# Gradient for kernel: [[-0.00109466 -0.00129118]
#  [ 0.00106229  0.00130398]]
# Gradient for bias: [ 0.00047023 -0.00065757]
# Gradient for kernel: [[-0.00237775]
#  [ 0.00250968]]
# Gradient for bias: [-0.00129139]
# Epoch 9408:
# Gradient for kernel: [[-0.00109439 -0.00129087]
#  [ 0.00106205  0.00130366]]
# Gradient for bias: [ 0.00047013 -0.00065742]
# Gradient for kernel: [[-0.00237726]
#  [ 0.00250914]]
# Gradient for bias: [-0.00129109]
# Epoch 9409:
# Gradient for kernel: [[-0.00109413 -0.00129055]
#  [ 0.0010618   0.00130334]]
# Gradient for bias: [ 0.00047003 -0.00065725]
# Gradient for kernel: [[-0.00237675]
#  [ 0.00250861]]
# Gradient for bias: [-0.0012908]
# Epoch 9410:
# Gradient for kernel: [[-0.00109387 -0.00129023]
#  [ 0.00106155  0.00130303]]
# Gradient for bias: [ 0.00046992 -0.00065708]
# Gradient for kernel: [[-0.00237626]
#  [ 0.00250805]]
# Gradient for bias: [-0.00129054]
# Epoch 9411:
# Gradient for kernel: [[-0.00109362 -0.00128992]
#  [ 0.00106131  0.00130272]]
# Gradient for bias: [ 0.0004698  -0.00065692]
# Gradient for kernel: [[-0.00237577]
#  [ 0.0025075 ]]
# Gradient for bias: [-0.00129026]
# Epoch 9412:
# Gradient for kernel: [[-0.00109335 -0.00128961]
#  [ 0.00106106  0.0013024 ]]
# Gradient for bias: [ 0.0004697  -0.00065676]
# Gradient for kernel: [[-0.00237528]
#  [ 0.00250697]]
# Gradient for bias: [-0.00128997]
# Epoch 9413:
# Gradient for kernel: [[-0.00109309 -0.00128929]
#  [ 0.00106081  0.00130208]]
# Gradient for bias: [ 0.00046959 -0.0006566 ]
# Gradient for kernel: [[-0.00237479]
#  [ 0.00250641]]
# Gradient for bias: [-0.0012897]
# Epoch 9414:
# Gradient for kernel: [[-0.00109283 -0.00128898]
#  [ 0.00106057  0.00130176]]
# Gradient for bias: [ 0.00046948 -0.00065644]
# Gradient for kernel: [[-0.00237429]
#  [ 0.00250587]]
# Gradient for bias: [-0.00128941]
# Epoch 9415:
# Gradient for kernel: [[-0.00109257 -0.00128867]
#  [ 0.00106032  0.00130145]]
# Gradient for bias: [ 0.00046937 -0.00065628]
# Gradient for kernel: [[-0.0023738 ]
#  [ 0.00250533]]
# Gradient for bias: [-0.00128914]
# Epoch 9416:
# Gradient for kernel: [[-0.00109231 -0.00128835]
#  [ 0.00106008  0.00130113]]
# Gradient for bias: [ 0.00046926 -0.00065612]
# Gradient for kernel: [[-0.00237331]
#  [ 0.00250478]]
# Gradient for bias: [-0.00128886]
# Epoch 9417:
# Gradient for kernel: [[-0.00109205 -0.00128804]
#  [ 0.00105983  0.00130081]]
# Gradient for bias: [ 0.00046916 -0.00065596]
# Gradient for kernel: [[-0.00237281]
#  [ 0.00250425]]
# Gradient for bias: [-0.00128857]
# Epoch 9418:
# Gradient for kernel: [[-0.00109178 -0.00128773]
#  [ 0.00105959  0.00130049]]
# Gradient for bias: [ 0.00046906 -0.00065581]
# Gradient for kernel: [[-0.00237231]
#  [ 0.00250371]]
# Gradient for bias: [-0.00128828]
# Epoch 9419:
# Gradient for kernel: [[-0.00109153 -0.00128741]
#  [ 0.00105934  0.00130018]]
# Gradient for bias: [ 0.00046895 -0.00065564]
# Gradient for kernel: [[-0.00237183]
#  [ 0.00250316]]
# Gradient for bias: [-0.00128801]
# Epoch 9420:
# Gradient for kernel: [[-0.00109127 -0.00128711]
#  [ 0.0010591   0.00129986]]
# Gradient for bias: [ 0.00046884 -0.00065549]
# Gradient for kernel: [[-0.00237134]
#  [ 0.00250262]]
# Gradient for bias: [-0.00128772]
# Epoch 9421:
# Gradient for kernel: [[-0.00109101 -0.00128679]
#  [ 0.00105885  0.00129955]]
# Gradient for bias: [ 0.00046873 -0.00065532]
# Gradient for kernel: [[-0.00237084]
#  [ 0.00250208]]
# Gradient for bias: [-0.00128744]
# Epoch 9422:
# Gradient for kernel: [[-0.00109074 -0.00128648]
#  [ 0.00105861  0.00129923]]
# Gradient for bias: [ 0.00046863 -0.00065517]
# Gradient for kernel: [[-0.00237035]
#  [ 0.00250154]]
# Gradient for bias: [-0.00128716]
# Epoch 9423:
# Gradient for kernel: [[-0.00109049 -0.00128617]
#  [ 0.00105836  0.00129892]]
# Gradient for bias: [ 0.00046851 -0.000655  ]
# Gradient for kernel: [[-0.00236987]
#  [ 0.00250099]]
# Gradient for bias: [-0.00128689]
# Epoch 9424:
# Gradient for kernel: [[-0.00109023 -0.00128585]
#  [ 0.00105812  0.0012986 ]]
# Gradient for bias: [ 0.00046841 -0.00065484]
# Gradient for kernel: [[-0.00236937]
#  [ 0.00250045]]
# Gradient for bias: [-0.00128661]
# Epoch 9425:
# Gradient for kernel: [[-0.00108997 -0.00128554]
#  [ 0.00105787  0.00129829]]
# Gradient for bias: [ 0.00046831 -0.00065469]
# Gradient for kernel: [[-0.00236888]
#  [ 0.00249992]]
# Gradient for bias: [-0.00128631]
# Epoch 9426:
# Gradient for kernel: [[-0.0010897  -0.00128523]
#  [ 0.00105763  0.00129797]]
# Gradient for bias: [ 0.0004682  -0.00065452]
# Gradient for kernel: [[-0.00236838]
#  [ 0.00249938]]
# Gradient for bias: [-0.00128604]
# Epoch 9427:
# Gradient for kernel: [[-0.00108944 -0.00128492]
#  [ 0.00105738  0.00129766]]
# Gradient for bias: [ 0.0004681  -0.00065436]
# Gradient for kernel: [[-0.00236789]
#  [ 0.00249884]]
# Gradient for bias: [-0.00128576]
# Epoch 9428:
# Gradient for kernel: [[-0.00108918 -0.00128461]
#  [ 0.00105714  0.00129735]]
# Gradient for bias: [ 0.000468  -0.0006542]
# Gradient for kernel: [[-0.0023674 ]
#  [ 0.00249831]]
# Gradient for bias: [-0.00128547]
# Epoch 9429:
# Gradient for kernel: [[-0.00108892 -0.0012843 ]
#  [ 0.00105689  0.00129703]]
# Gradient for bias: [ 0.00046789 -0.00065404]
# Gradient for kernel: [[-0.0023669 ]
#  [ 0.00249777]]
# Gradient for bias: [-0.00128519]
# Epoch 9430:
# Gradient for kernel: [[-0.00108867 -0.00128398]
#  [ 0.00105665  0.00129672]]
# Gradient for bias: [ 0.00046778 -0.00065388]
# Gradient for kernel: [[-0.00236642]
#  [ 0.00249722]]
# Gradient for bias: [-0.00128492]
# Epoch 9431:
# Gradient for kernel: [[-0.00108841 -0.00128368]
#  [ 0.0010564   0.0012964 ]]
# Gradient for bias: [ 0.00046767 -0.00065372]
# Gradient for kernel: [[-0.00236593]
#  [ 0.00249668]]
# Gradient for bias: [-0.00128464]
# Epoch 9432:
# Gradient for kernel: [[-0.00108815 -0.00128336]
#  [ 0.00105616  0.00129608]]
# Gradient for bias: [ 0.00046757 -0.00065357]
# Gradient for kernel: [[-0.00236544]
#  [ 0.00249614]]
# Gradient for bias: [-0.00128435]
# Epoch 9433:
# Gradient for kernel: [[-0.00108789 -0.00128306]
#  [ 0.00105592  0.00129577]]
# Gradient for bias: [ 0.00046746 -0.00065341]
# Gradient for kernel: [[-0.00236495]
#  [ 0.0024956 ]]
# Gradient for bias: [-0.00128408]
# Epoch 9434:
# Gradient for kernel: [[-0.00108763 -0.00128274]
#  [ 0.00105567  0.00129545]]
# Gradient for bias: [ 0.00046736 -0.00065325]
# Gradient for kernel: [[-0.00236446]
#  [ 0.00249507]]
# Gradient for bias: [-0.00128379]
# Epoch 9435:
# Gradient for kernel: [[-0.00108737 -0.00128243]
#  [ 0.00105543  0.00129514]]
# Gradient for bias: [ 0.00046725 -0.00065309]
# Gradient for kernel: [[-0.00236397]
#  [ 0.00249453]]
# Gradient for bias: [-0.0012835]
# Epoch 9436:
# Gradient for kernel: [[-0.00108712 -0.00128213]
#  [ 0.00105519  0.00129482]]
# Gradient for bias: [ 0.00046714 -0.00065294]
# Gradient for kernel: [[-0.00236348]
#  [ 0.002494  ]]
# Gradient for bias: [-0.00128323]
# Epoch 9437:
# Gradient for kernel: [[-0.00108686 -0.00128182]
#  [ 0.00105494  0.00129451]]
# Gradient for bias: [ 0.00046703 -0.00065278]
# Gradient for kernel: [[-0.00236299]
#  [ 0.00249345]]
# Gradient for bias: [-0.00128295]
# Epoch 9438:
# Gradient for kernel: [[-0.0010866 -0.0012815]
#  [ 0.0010547  0.0012942]]
# Gradient for bias: [ 0.00046693 -0.00065262]
# Gradient for kernel: [[-0.0023625 ]
#  [ 0.00249292]]
# Gradient for bias: [-0.00128267]
# Epoch 9439:
# Gradient for kernel: [[-0.00108634 -0.00128119]
#  [ 0.00105446  0.00129389]]
# Gradient for bias: [ 0.00046683 -0.00065245]
# Gradient for kernel: [[-0.00236201]
#  [ 0.00249238]]
# Gradient for bias: [-0.0012824]
# Epoch 9440:
# Gradient for kernel: [[-0.00108608 -0.00128088]
#  [ 0.00105421  0.00129357]]
# Gradient for bias: [ 0.00046672 -0.0006523 ]
# Gradient for kernel: [[-0.00236153]
#  [ 0.00249184]]
# Gradient for bias: [-0.00128212]
# Epoch 9441:
# Gradient for kernel: [[-0.00108582 -0.00128057]
#  [ 0.00105397  0.00129326]]
# Gradient for bias: [ 0.00046661 -0.00065214]
# Gradient for kernel: [[-0.00236104]
#  [ 0.00249131]]
# Gradient for bias: [-0.00128184]
# Epoch 9442:
# Gradient for kernel: [[-0.00108557 -0.00128026]
#  [ 0.00105373  0.00129295]]
# Gradient for bias: [ 0.0004665  -0.00065197]
# Gradient for kernel: [[-0.00236055]
#  [ 0.00249076]]
# Gradient for bias: [-0.00128157]
# Epoch 9443:
# Gradient for kernel: [[-0.00108531 -0.00127996]
#  [ 0.00105348  0.00129264]]
# Gradient for bias: [ 0.0004664  -0.00065182]
# Gradient for kernel: [[-0.00236006]
#  [ 0.00249023]]
# Gradient for bias: [-0.00128128]
# Epoch 9444:
# Gradient for kernel: [[-0.00108505 -0.00127965]
#  [ 0.00105324  0.00129232]]
# Gradient for bias: [ 0.0004663  -0.00065166]
# Gradient for kernel: [[-0.00235957]
#  [ 0.0024897 ]]
# Gradient for bias: [-0.00128099]
# Epoch 9445:
# Gradient for kernel: [[-0.00108479 -0.00127934]
#  [ 0.001053    0.00129201]]
# Gradient for bias: [ 0.00046619 -0.0006515 ]
# Gradient for kernel: [[-0.00235909]
#  [ 0.00248916]]
# Gradient for bias: [-0.00128073]
# Epoch 9446:
# Gradient for kernel: [[-0.00108453 -0.00127903]
#  [ 0.00105276  0.0012917 ]]
# Gradient for bias: [ 0.00046609 -0.00065134]
# Gradient for kernel: [[-0.0023586 ]
#  [ 0.00248862]]
# Gradient for bias: [-0.00128045]
# Epoch 9447:
# Gradient for kernel: [[-0.00108427 -0.00127872]
#  [ 0.00105251  0.00129138]]
# Gradient for bias: [ 0.00046599 -0.00065119]
# Gradient for kernel: [[-0.00235811]
#  [ 0.0024881 ]]
# Gradient for bias: [-0.00128015]
# Epoch 9448:
# Gradient for kernel: [[-0.00108402 -0.00127841]
#  [ 0.00105227  0.00129108]]
# Gradient for bias: [ 0.00046588 -0.00065103]
# Gradient for kernel: [[-0.00235762]
#  [ 0.00248756]]
# Gradient for bias: [-0.00127989]
# Epoch 9449:
# Gradient for kernel: [[-0.00108376 -0.0012781 ]
#  [ 0.00105203  0.00129076]]
# Gradient for bias: [ 0.00046577 -0.00065088]
# Gradient for kernel: [[-0.00235714]
#  [ 0.00248702]]
# Gradient for bias: [-0.0012796]
# Epoch 9450:
# Gradient for kernel: [[-0.00108351 -0.0012778 ]
#  [ 0.00105179  0.00129045]]
# Gradient for bias: [ 0.00046566 -0.00065072]
# Gradient for kernel: [[-0.00235665]
#  [ 0.00248648]]
# Gradient for bias: [-0.00127933]
# Epoch 9451:
# Gradient for kernel: [[-0.00108325 -0.00127749]
#  [ 0.00105154  0.00129014]]
# Gradient for bias: [ 0.00046556 -0.00065056]
# Gradient for kernel: [[-0.00235616]
#  [ 0.00248595]]
# Gradient for bias: [-0.00127905]
# Epoch 9452:
# Gradient for kernel: [[-0.00108299 -0.00127718]
#  [ 0.0010513   0.00128983]]
# Gradient for bias: [ 0.00046545 -0.0006504 ]
# Gradient for kernel: [[-0.00235568]
#  [ 0.00248541]]
# Gradient for bias: [-0.00127878]
# Epoch 9453:
# Gradient for kernel: [[-0.00108274 -0.00127687]
#  [ 0.00105106  0.00128951]]
# Gradient for bias: [ 0.00046535 -0.00065025]
# Gradient for kernel: [[-0.00235519]
#  [ 0.00248488]]
# Gradient for bias: [-0.00127849]
# Epoch 9454:
# Gradient for kernel: [[-0.00108248 -0.00127656]
#  [ 0.00105082  0.00128921]]
# Gradient for bias: [ 0.00046524 -0.00065008]
# Gradient for kernel: [[-0.0023547 ]
#  [ 0.00248435]]
# Gradient for bias: [-0.00127821]
# Epoch 9455:
# Gradient for kernel: [[-0.00108223 -0.00127625]
#  [ 0.00105058  0.00128889]]
# Gradient for bias: [ 0.00046513 -0.00064992]
# Gradient for kernel: [[-0.00235423]
#  [ 0.0024838 ]]
# Gradient for bias: [-0.00127795]
# Epoch 9456:
# Gradient for kernel: [[-0.00108197 -0.00127594]
#  [ 0.00105033  0.00128859]]
# Gradient for bias: [ 0.00046503 -0.00064976]
# Gradient for kernel: [[-0.00235373]
#  [ 0.00248328]]
# Gradient for bias: [-0.00127767]
# Epoch 9457:
# Gradient for kernel: [[-0.00108171 -0.00127564]
#  [ 0.00105009  0.00128828]]
# Gradient for bias: [ 0.00046493 -0.0006496 ]
# Gradient for kernel: [[-0.00235325]
#  [ 0.00248274]]
# Gradient for bias: [-0.00127739]
# Epoch 9458:
# Gradient for kernel: [[-0.00108146 -0.00127533]
#  [ 0.00104985  0.00128797]]
# Gradient for bias: [ 0.00046482 -0.00064945]
# Gradient for kernel: [[-0.00235277]
#  [ 0.00248221]]
# Gradient for bias: [-0.00127711]
# Epoch 9459:
# Gradient for kernel: [[-0.0010812  -0.00127502]
#  [ 0.00104961  0.00128766]]
# Gradient for bias: [ 0.00046471 -0.00064929]
# Gradient for kernel: [[-0.00235228]
#  [ 0.00248167]]
# Gradient for bias: [-0.00127684]
# Epoch 9460:
# Gradient for kernel: [[-0.00108094 -0.00127471]
#  [ 0.00104937  0.00128735]]
# Gradient for bias: [ 0.00046462 -0.00064913]
# Gradient for kernel: [[-0.00235179]
#  [ 0.00248115]]
# Gradient for bias: [-0.00127656]
# Epoch 9461:
# Gradient for kernel: [[-0.00108068 -0.00127441]
#  [ 0.00104913  0.00128703]]
# Gradient for bias: [ 0.00046451 -0.00064898]
# Gradient for kernel: [[-0.00235131]
#  [ 0.00248062]]
# Gradient for bias: [-0.00127628]
# Epoch 9462:
# Gradient for kernel: [[-0.00108043 -0.0012741 ]
#  [ 0.00104889  0.00128672]]
# Gradient for bias: [ 0.0004644  -0.00064882]
# Gradient for kernel: [[-0.00235083]
#  [ 0.00248008]]
# Gradient for bias: [-0.001276]
# Epoch 9463:
# Gradient for kernel: [[-0.00108017 -0.0012738 ]
#  [ 0.00104865  0.00128641]]
# Gradient for bias: [ 0.00046431 -0.00064866]
# Gradient for kernel: [[-0.00235033]
#  [ 0.00247956]]
# Gradient for bias: [-0.00127572]
# Epoch 9464:
# Gradient for kernel: [[-0.00107991 -0.00127349]
#  [ 0.00104841  0.0012861 ]]
# Gradient for bias: [ 0.0004642  -0.00064851]
# Gradient for kernel: [[-0.00234985]
#  [ 0.00247903]]
# Gradient for bias: [-0.00127544]
# Epoch 9465:
# Gradient for kernel: [[-0.00107966 -0.00127318]
#  [ 0.00104817  0.00128579]]
# Gradient for bias: [ 0.0004641  -0.00064835]
# Gradient for kernel: [[-0.00234936]
#  [ 0.0024785 ]]
# Gradient for bias: [-0.00127517]
# Epoch 9466:
# Gradient for kernel: [[-0.00107941 -0.00127288]
#  [ 0.00104792  0.00128548]]
# Gradient for bias: [ 0.00046399 -0.00064819]
# Gradient for kernel: [[-0.00234889]
#  [ 0.00247795]]
# Gradient for bias: [-0.0012749]
# Epoch 9467:
# Gradient for kernel: [[-0.00107915 -0.00127257]
#  [ 0.00104768  0.00128517]]
# Gradient for bias: [ 0.00046388 -0.00064804]
# Gradient for kernel: [[-0.0023484 ]
#  [ 0.00247742]]
# Gradient for bias: [-0.00127462]
# Epoch 9468:
# Gradient for kernel: [[-0.0010789  -0.00127226]
#  [ 0.00104744  0.00128486]]
# Gradient for bias: [ 0.00046378 -0.00064789]
# Gradient for kernel: [[-0.00234792]
#  [ 0.0024769 ]]
# Gradient for bias: [-0.00127433]
# Epoch 9469:
# Gradient for kernel: [[-0.00107865 -0.00127196]
#  [ 0.0010472   0.00128455]]
# Gradient for bias: [ 0.00046366 -0.00064772]
# Gradient for kernel: [[-0.00234744]
#  [ 0.00247635]]
# Gradient for bias: [-0.00127408]
# Epoch 9470:
# Gradient for kernel: [[-0.00107839 -0.00127165]
#  [ 0.00104696  0.00128425]]
# Gradient for bias: [ 0.00046356 -0.00064756]
# Gradient for kernel: [[-0.00234696]
#  [ 0.00247583]]
# Gradient for bias: [-0.0012738]
# Epoch 9471:
# Gradient for kernel: [[-0.00107813 -0.00127135]
#  [ 0.00104672  0.00128394]]
# Gradient for bias: [ 0.00046346 -0.00064741]
# Gradient for kernel: [[-0.00234647]
#  [ 0.0024753 ]]
# Gradient for bias: [-0.00127352]
# Epoch 9472:
# Gradient for kernel: [[-0.00107788 -0.00127104]
#  [ 0.00104648  0.00128363]]
# Gradient for bias: [ 0.00046335 -0.00064725]
# Gradient for kernel: [[-0.00234599]
#  [ 0.00247476]]
# Gradient for bias: [-0.00127325]
# Epoch 9473:
# Gradient for kernel: [[-0.00107763 -0.00127073]
#  [ 0.00104624  0.00128332]]
# Gradient for bias: [ 0.00046324 -0.00064709]
# Gradient for kernel: [[-0.00234551]
#  [ 0.00247422]]
# Gradient for bias: [-0.00127298]
# Epoch 9474:
# Gradient for kernel: [[-0.00107737 -0.00127043]
#  [ 0.001046    0.00128301]]
# Gradient for bias: [ 0.00046315 -0.00064694]
# Gradient for kernel: [[-0.00234502]
#  [ 0.00247371]]
# Gradient for bias: [-0.00127269]
# Epoch 9475:
# Gradient for kernel: [[-0.00107712 -0.00127012]
#  [ 0.00104576  0.00128271]]
# Gradient for bias: [ 0.00046304 -0.00064677]
# Gradient for kernel: [[-0.00234455]
#  [ 0.00247316]]
# Gradient for bias: [-0.00127244]
# Epoch 9476:
# Gradient for kernel: [[-0.00107687 -0.00126982]
#  [ 0.00104552  0.0012824 ]]
# Gradient for bias: [ 0.00046294 -0.00064662]
# Gradient for kernel: [[-0.00234407]
#  [ 0.00247264]]
# Gradient for bias: [-0.00127216]
# Epoch 9477:
# Gradient for kernel: [[-0.00107661 -0.00126951]
#  [ 0.00104528  0.00128209]]
# Gradient for bias: [ 0.00046284 -0.00064647]
# Gradient for kernel: [[-0.00234358]
#  [ 0.00247212]]
# Gradient for bias: [-0.00127187]
# Epoch 9478:
# Gradient for kernel: [[-0.00107635 -0.00126921]
#  [ 0.00104505  0.00128178]]
# Gradient for bias: [ 0.00046273 -0.00064632]
# Gradient for kernel: [[-0.0023431 ]
#  [ 0.00247159]]
# Gradient for bias: [-0.0012716]
# Epoch 9479:
# Gradient for kernel: [[-0.0010761  -0.00126891]
#  [ 0.00104481  0.00128147]]
# Gradient for bias: [ 0.00046263 -0.00064616]
# Gradient for kernel: [[-0.00234262]
#  [ 0.00247106]]
# Gradient for bias: [-0.00127132]
# Epoch 9480:
# Gradient for kernel: [[-0.00107584 -0.0012686 ]
#  [ 0.00104457  0.00128116]]
# Gradient for bias: [ 0.00046253 -0.000646  ]
# Gradient for kernel: [[-0.00234214]
#  [ 0.00247053]]
# Gradient for bias: [-0.00127104]
# Epoch 9481:
# Gradient for kernel: [[-0.00107559 -0.0012683 ]
#  [ 0.00104433  0.00128085]]
# Gradient for bias: [ 0.00046243 -0.00064585]
# Gradient for kernel: [[-0.00234165]
#  [ 0.00247001]]
# Gradient for bias: [-0.00127077]
# Epoch 9482:
# Gradient for kernel: [[-0.00107534 -0.00126799]
#  [ 0.00104409  0.00128055]]
# Gradient for bias: [ 0.00046232 -0.00064569]
# Gradient for kernel: [[-0.00234117]
#  [ 0.00246948]]
# Gradient for bias: [-0.00127049]
# Epoch 9483:
# Gradient for kernel: [[-0.00107508 -0.00126769]
#  [ 0.00104385  0.00128023]]
# Gradient for bias: [ 0.00046222 -0.00064554]
# Gradient for kernel: [[-0.00234069]
#  [ 0.00246896]]
# Gradient for bias: [-0.00127021]
# Epoch 9484:
# Gradient for kernel: [[-0.00107483 -0.00126739]
#  [ 0.00104361  0.00127993]]
# Gradient for bias: [ 0.00046211 -0.00064538]
# Gradient for kernel: [[-0.00234021]
#  [ 0.00246843]]
# Gradient for bias: [-0.00126994]
# Epoch 9485:
# Gradient for kernel: [[-0.00107457 -0.00126708]
#  [ 0.00104337  0.00127962]]
# Gradient for bias: [ 0.00046201 -0.00064523]
# Gradient for kernel: [[-0.00233973]
#  [ 0.0024679 ]]
# Gradient for bias: [-0.00126967]
# Epoch 9486:
# Gradient for kernel: [[-0.00107432 -0.00126678]
#  [ 0.00104313  0.00127932]]
# Gradient for bias: [ 0.0004619  -0.00064506]
# Gradient for kernel: [[-0.00233925]
#  [ 0.00246736]]
# Gradient for bias: [-0.0012694]
# Epoch 9487:
# Gradient for kernel: [[-0.00107407 -0.00126647]
#  [ 0.00104289  0.00127901]]
# Gradient for bias: [ 0.0004618  -0.00064491]
# Gradient for kernel: [[-0.00233877]
#  [ 0.00246683]]
# Gradient for bias: [-0.00126913]
# Epoch 9488:
# Gradient for kernel: [[-0.00107382 -0.00126617]
#  [ 0.00104265  0.00127871]]
# Gradient for bias: [ 0.00046169 -0.00064475]
# Gradient for kernel: [[-0.00233829]
#  [ 0.00246631]]
# Gradient for bias: [-0.00126885]
# Epoch 9489:
# Gradient for kernel: [[-0.00107357 -0.00126587]
#  [ 0.00104242  0.0012784 ]]
# Gradient for bias: [ 0.00046159 -0.0006446 ]
# Gradient for kernel: [[-0.00233782]
#  [ 0.00246578]]
# Gradient for bias: [-0.00126858]
# Epoch 9490:
# Gradient for kernel: [[-0.00107331 -0.00126556]
#  [ 0.00104218  0.0012781 ]]
# Gradient for bias: [ 0.00046149 -0.00064444]
# Gradient for kernel: [[-0.00233733]
#  [ 0.00246526]]
# Gradient for bias: [-0.00126831]
# Epoch 9491:
# Gradient for kernel: [[-0.00107307 -0.00126526]
#  [ 0.00104194  0.00127779]]
# Gradient for bias: [ 0.00046138 -0.00064428]
# Gradient for kernel: [[-0.00233686]
#  [ 0.00246472]]
# Gradient for bias: [-0.00126805]
# Epoch 9492:
# Gradient for kernel: [[-0.00107281 -0.00126496]
#  [ 0.0010417   0.00127748]]
# Gradient for bias: [ 0.00046127 -0.00064413]
# Gradient for kernel: [[-0.00233638]
#  [ 0.0024642 ]]
# Gradient for bias: [-0.00126777]
# Epoch 9493:
# Gradient for kernel: [[-0.00107256 -0.00126465]
#  [ 0.00104146  0.00127717]]
# Gradient for bias: [ 0.00046117 -0.00064398]
# Gradient for kernel: [[-0.00233589]
#  [ 0.00246368]]
# Gradient for bias: [-0.00126748]
# Epoch 9494:
# Gradient for kernel: [[-0.0010723  -0.00126435]
#  [ 0.00104123  0.00127687]]
# Gradient for bias: [ 0.00046107 -0.00064382]
# Gradient for kernel: [[-0.00233542]
#  [ 0.00246315]]
# Gradient for bias: [-0.00126721]
# Epoch 9495:
# Gradient for kernel: [[-0.00107206 -0.00126405]
#  [ 0.00104099  0.00127656]]
# Gradient for bias: [ 0.00046096 -0.00064367]
# Gradient for kernel: [[-0.00233494]
#  [ 0.00246262]]
# Gradient for bias: [-0.00126694]
# Epoch 9496:
# Gradient for kernel: [[-0.0010718  -0.00126375]
#  [ 0.00104075  0.00127625]]
# Gradient for bias: [ 0.00046087 -0.00064352]
# Gradient for kernel: [[-0.00233446]
#  [ 0.0024621 ]]
# Gradient for bias: [-0.00126666]
# Epoch 9497:
# Gradient for kernel: [[-0.00107154 -0.00126345]
#  [ 0.00104051  0.00127595]]
# Gradient for bias: [ 0.00046077 -0.00064336]
# Gradient for kernel: [[-0.00233398]
#  [ 0.00246158]]
# Gradient for bias: [-0.00126639]
# Epoch 9498:
# Gradient for kernel: [[-0.00107129 -0.00126314]
#  [ 0.00104028  0.00127564]]
# Gradient for bias: [ 0.00046066 -0.00064321]
# Gradient for kernel: [[-0.00233351]
#  [ 0.00246105]]
# Gradient for bias: [-0.00126611]
# Epoch 9499:
# Gradient for kernel: [[-0.00107103 -0.00126284]
#  [ 0.00104004  0.00127533]]
# Gradient for bias: [ 0.00046057 -0.00064306]
# Gradient for kernel: [[-0.00233302]
#  [ 0.00246054]]
# Gradient for bias: [-0.00126583]
# Epoch 9500:
# Gradient for kernel: [[-0.00107079 -0.00126254]
#  [ 0.0010398   0.00127503]]
# Gradient for bias: [ 0.00046046 -0.0006429 ]
# Gradient for kernel: [[-0.00233255]
#  [ 0.00246001]]
# Gradient for bias: [-0.00126557]
# Epoch 9501:
# Gradient for kernel: [[-0.00107053 -0.00126224]
#  [ 0.00103957  0.00127472]]
# Gradient for bias: [ 0.00046036 -0.00064275]
# Gradient for kernel: [[-0.00233207]
#  [ 0.00245949]]
# Gradient for bias: [-0.00126529]
# Epoch 9502:
# Gradient for kernel: [[-0.00107028 -0.00126194]
#  [ 0.00103933  0.00127442]]
# Gradient for bias: [ 0.00046026 -0.00064259]
# Gradient for kernel: [[-0.00233159]
#  [ 0.00245896]]
# Gradient for bias: [-0.00126502]
# Epoch 9503:
# Gradient for kernel: [[-0.00107004 -0.00126163]
#  [ 0.00103909  0.00127412]]
# Gradient for bias: [ 0.00046015 -0.00064243]
# Gradient for kernel: [[-0.00233112]
#  [ 0.00245843]]
# Gradient for bias: [-0.00126476]
# Epoch 9504:
# Gradient for kernel: [[-0.00106978 -0.00126133]
#  [ 0.00103885  0.00127381]]
# Gradient for bias: [ 0.00046005 -0.00064228]
# Gradient for kernel: [[-0.00233064]
#  [ 0.00245791]]
# Gradient for bias: [-0.00126448]
# Epoch 9505:
# Gradient for kernel: [[-0.00106953 -0.00126103]
#  [ 0.00103862  0.00127351]]
# Gradient for bias: [ 0.00045994 -0.00064212]
# Gradient for kernel: [[-0.00233016]
#  [ 0.00245739]]
# Gradient for bias: [-0.00126421]
# ...
#  [ 0.00225364]]
# Gradient for bias: [-0.00115839]
# Epoch 9928:
# Gradient for kernel: [[-0.00097203 -0.00114419]
#  [ 0.00094651  0.00115541]]
# Gradient for bias: [ 0.00041987 -0.00058224]
# Gradient for kernel: [[-0.00214364]
#  [ 0.00225319]]
# Gradient for bias: [-0.00115815]
# Epoch 9929:
# Gradient for kernel: [[-0.00097182 -0.00114394]
#  [ 0.00094631  0.00115515]]
# Gradient for bias: [ 0.00041978 -0.00058212]
# Gradient for kernel: [[-0.00214324]
#  [ 0.00225275]]
# Gradient for bias: [-0.00115792]
# Epoch 9930:
# Gradient for kernel: [[-0.00097161 -0.00114369]
#  [ 0.00094611  0.0011549 ]]
# Gradient for bias: [ 0.00041969 -0.00058199]
# Gradient for kernel: [[-0.00214283]
#  [ 0.0022523 ]]
# Gradient for bias: [-0.00115769]
# Epoch 9931:
# Gradient for kernel: [[-0.00097139 -0.00114344]
#  [ 0.00094591  0.00115464]]
# Gradient for bias: [ 0.00041961 -0.00058186]
# Gradient for kernel: [[-0.00214242]
#  [ 0.00225187]]
# Gradient for bias: [-0.00115745]
# Epoch 9932:
# Gradient for kernel: [[-0.00097118 -0.00114318]
#  [ 0.00094571  0.00115438]]
# Gradient for bias: [ 0.00041953 -0.00058173]
# Gradient for kernel: [[-0.00214201]
#  [ 0.00225143]]
# Gradient for bias: [-0.00115722]
# Epoch 9933:
# Gradient for kernel: [[-0.00097097 -0.00114293]
#  [ 0.00094551  0.00115413]]
# Gradient for bias: [ 0.00041944 -0.0005816 ]
# Gradient for kernel: [[-0.00214161]
#  [ 0.00225097]]
# Gradient for bias: [-0.001157]
# Epoch 9934:
# Gradient for kernel: [[-0.00097076 -0.00114268]
#  [ 0.00094531  0.00115387]]
# Gradient for bias: [ 0.00041935 -0.00058147]
# Gradient for kernel: [[-0.00214119]
#  [ 0.00225054]]
# Gradient for bias: [-0.00115676]
# Epoch 9935:
# Gradient for kernel: [[-0.00097055 -0.00114242]
#  [ 0.00094511  0.00115362]]
# Gradient for bias: [ 0.00041927 -0.00058134]
# Gradient for kernel: [[-0.00214079]
#  [ 0.00225009]]
# Gradient for bias: [-0.00115653]
# Epoch 9936:
# Gradient for kernel: [[-0.00097034 -0.00114217]
#  [ 0.00094491  0.00115337]]
# Gradient for bias: [ 0.00041918 -0.00058121]
# Gradient for kernel: [[-0.00214039]
#  [ 0.00224964]]
# Gradient for bias: [-0.00115631]
# Epoch 9937:
# Gradient for kernel: [[-0.00097013 -0.00114192]
#  [ 0.00094471  0.00115311]]
# Gradient for bias: [ 0.00041909 -0.00058108]
# Gradient for kernel: [[-0.00213998]
#  [ 0.0022492 ]]
# Gradient for bias: [-0.00115607]
# Epoch 9938:
# Gradient for kernel: [[-0.00096992 -0.00114167]
#  [ 0.00094451  0.00115285]]
# Gradient for bias: [ 0.000419   -0.00058095]
# Gradient for kernel: [[-0.00213957]
#  [ 0.00224875]]
# Gradient for bias: [-0.00115584]
# Epoch 9939:
# Gradient for kernel: [[-0.00096971 -0.00114141]
#  [ 0.00094431  0.0011526 ]]
# Gradient for bias: [ 0.00041891 -0.00058082]
# Gradient for kernel: [[-0.00213917]
#  [ 0.00224831]]
# Gradient for bias: [-0.00115562]
# Epoch 9940:
# Gradient for kernel: [[-0.0009695  -0.00114116]
#  [ 0.00094411  0.00115235]]
# Gradient for bias: [ 0.00041882 -0.00058069]
# Gradient for kernel: [[-0.00213876]
#  [ 0.00224785]]
# Gradient for bias: [-0.0011554]
# Epoch 9941:
# Gradient for kernel: [[-0.00096929 -0.00114091]
#  [ 0.00094391  0.00115209]]
# Gradient for bias: [ 0.00041874 -0.00058056]
# Gradient for kernel: [[-0.00213835]
#  [ 0.00224742]]
# Gradient for bias: [-0.00115516]
# Epoch 9942:
# Gradient for kernel: [[-0.00096908 -0.00114066]
#  [ 0.00094371  0.00115183]]
# Gradient for bias: [ 0.00041865 -0.00058043]
# Gradient for kernel: [[-0.00213795]
#  [ 0.00224698]]
# Gradient for bias: [-0.00115492]
# Epoch 9943:
# Gradient for kernel: [[-0.00096887 -0.00114041]
#  [ 0.00094351  0.00115157]]
# Gradient for bias: [ 0.00041856 -0.00058031]
# Gradient for kernel: [[-0.00213755]
#  [ 0.00224653]]
# Gradient for bias: [-0.00115469]
# Epoch 9944:
# Gradient for kernel: [[-0.00096866 -0.00114016]
#  [ 0.00094331  0.00115132]]
# Gradient for bias: [ 0.00041847 -0.00058018]
# Gradient for kernel: [[-0.00213714]
#  [ 0.00224609]]
# Gradient for bias: [-0.00115447]
# Epoch 9945:
# Gradient for kernel: [[-0.00096845 -0.00113991]
#  [ 0.00094312  0.00115106]]
# Gradient for bias: [ 0.00041838 -0.00058005]
# Gradient for kernel: [[-0.00213674]
#  [ 0.00224565]]
# Gradient for bias: [-0.00115424]
# Epoch 9946:
# Gradient for kernel: [[-0.00096824 -0.00113965]
#  [ 0.00094292  0.00115081]]
# Gradient for bias: [ 0.0004183  -0.00057992]
# Gradient for kernel: [[-0.00213633]
#  [ 0.00224521]]
# Gradient for bias: [-0.001154]
# Epoch 9947:
# Gradient for kernel: [[-0.00096803 -0.0011394 ]
#  [ 0.00094272  0.00115056]]
# Gradient for bias: [ 0.00041822 -0.00057979]
# Gradient for kernel: [[-0.00213592]
#  [ 0.00224477]]
# Gradient for bias: [-0.00115377]
# Epoch 9948:
# Gradient for kernel: [[-0.00096782 -0.00113915]
#  [ 0.00094252  0.00115031]]
# Gradient for bias: [ 0.00041813 -0.00057966]
# Gradient for kernel: [[-0.00213552]
#  [ 0.00224432]]
# Gradient for bias: [-0.00115355]
# Epoch 9949:
# Gradient for kernel: [[-0.00096761 -0.0011389 ]
#  [ 0.00094232  0.00115005]]
# Gradient for bias: [ 0.00041804 -0.00057953]
# Gradient for kernel: [[-0.00213511]
#  [ 0.00224388]]
# Gradient for bias: [-0.00115332]
# Epoch 9950:
# Gradient for kernel: [[-0.0009674  -0.00113865]
#  [ 0.00094212  0.0011498 ]]
# Gradient for bias: [ 0.00041795 -0.00057941]
# Gradient for kernel: [[-0.00213471]
#  [ 0.00224344]]
# Gradient for bias: [-0.00115309]
# Epoch 9951:
# Gradient for kernel: [[-0.00096719 -0.0011384 ]
#  [ 0.00094192  0.00114954]]
# Gradient for bias: [ 0.00041787 -0.00057928]
# Gradient for kernel: [[-0.0021343]
#  [ 0.002243 ]]
# Gradient for bias: [-0.00115285]
# Epoch 9952:
# Gradient for kernel: [[-0.00096698 -0.00113815]
#  [ 0.00094172  0.00114929]]
# Gradient for bias: [ 0.00041779 -0.00057915]
# Gradient for kernel: [[-0.00213389]
#  [ 0.00224256]]
# Gradient for bias: [-0.00115262]
# Epoch 9953:
# Gradient for kernel: [[-0.00096677 -0.0011379 ]
#  [ 0.00094153  0.00114904]]
# Gradient for bias: [ 0.0004177  -0.00057902]
# Gradient for kernel: [[-0.00213349]
#  [ 0.00224212]]
# Gradient for bias: [-0.0011524]
# Epoch 9954:
# Gradient for kernel: [[-0.00096656 -0.00113765]
#  [ 0.00094133  0.00114878]]
# Gradient for bias: [ 0.00041762 -0.00057889]
# Gradient for kernel: [[-0.00213309]
#  [ 0.00224168]]
# Gradient for bias: [-0.00115217]
# Epoch 9955:
# Gradient for kernel: [[-0.00096635 -0.0011374 ]
#  [ 0.00094113  0.00114854]]
# Gradient for bias: [ 0.00041753 -0.00057876]
# Gradient for kernel: [[-0.00213268]
#  [ 0.00224124]]
# Gradient for bias: [-0.00115194]
# Epoch 9956:
# Gradient for kernel: [[-0.00096614 -0.00113714]
#  [ 0.00094093  0.00114828]]
# Gradient for bias: [ 0.00041744 -0.00057863]
# Gradient for kernel: [[-0.00213228]
#  [ 0.0022408 ]]
# Gradient for bias: [-0.00115171]
# Epoch 9957:
# Gradient for kernel: [[-0.00096593 -0.0011369 ]
#  [ 0.00094074  0.00114803]]
# Gradient for bias: [ 0.00041736 -0.0005785 ]
# Gradient for kernel: [[-0.00213187]
#  [ 0.00224036]]
# Gradient for bias: [-0.00115148]
# Epoch 9958:
# Gradient for kernel: [[-0.00096572 -0.00113665]
#  [ 0.00094054  0.00114777]]
# Gradient for bias: [ 0.00041727 -0.00057838]
# Gradient for kernel: [[-0.00213147]
#  [ 0.00223991]]
# Gradient for bias: [-0.00115126]
# Epoch 9959:
# Gradient for kernel: [[-0.0009655  -0.00113639]
#  [ 0.00094034  0.00114752]]
# Gradient for bias: [ 0.00041719 -0.00057825]
# Gradient for kernel: [[-0.00213106]
#  [ 0.00223948]]
# Gradient for bias: [-0.00115102]
# Epoch 9960:
# Gradient for kernel: [[-0.0009653  -0.00113614]
#  [ 0.00094014  0.00114727]]
# Gradient for bias: [ 0.0004171  -0.00057812]
# Gradient for kernel: [[-0.00213067]
#  [ 0.00223903]]
# Gradient for bias: [-0.0011508]
# Epoch 9961:
# Gradient for kernel: [[-0.00096508 -0.0011359 ]
#  [ 0.00093994  0.00114701]]
# Gradient for bias: [ 0.00041702 -0.00057799]
# Gradient for kernel: [[-0.00213025]
#  [ 0.0022386 ]]
# Gradient for bias: [-0.00115056]
# Epoch 9962:
# Gradient for kernel: [[-0.00096488 -0.00113565]
#  [ 0.00093975  0.00114676]]
# Gradient for bias: [ 0.00041693 -0.00057787]
# Gradient for kernel: [[-0.00212986]
#  [ 0.00223816]]
# Gradient for bias: [-0.00115033]
# Epoch 9963:
# Gradient for kernel: [[-0.00096467 -0.0011354 ]
#  [ 0.00093955  0.00114651]]
# Gradient for bias: [ 0.00041685 -0.00057774]
# Gradient for kernel: [[-0.00212945]
#  [ 0.00223773]]
# Gradient for bias: [-0.0011501]
# Epoch 9964:
# Gradient for kernel: [[-0.00096446 -0.00113515]
#  [ 0.00093935  0.00114625]]
# Gradient for bias: [ 0.00041676 -0.00057761]
# Gradient for kernel: [[-0.00212905]
#  [ 0.00223729]]
# Gradient for bias: [-0.00114987]
# Epoch 9965:
# Gradient for kernel: [[-0.00096426 -0.0011349 ]
#  [ 0.00093915  0.001146  ]]
# Gradient for bias: [ 0.00041667 -0.00057749]
# Gradient for kernel: [[-0.00212865]
#  [ 0.00223684]]
# Gradient for bias: [-0.00114965]
# Epoch 9966:
# Gradient for kernel: [[-0.00096405 -0.00113465]
#  [ 0.00093896  0.00114575]]
# Gradient for bias: [ 0.00041658 -0.00057736]
# Gradient for kernel: [[-0.00212825]
#  [ 0.0022364 ]]
# Gradient for bias: [-0.00114942]
# Epoch 9967:
# Gradient for kernel: [[-0.00096384 -0.0011344 ]
#  [ 0.00093876  0.0011455 ]]
# Gradient for bias: [ 0.0004165  -0.00057723]
# Gradient for kernel: [[-0.00212784]
#  [ 0.00223596]]
# Gradient for bias: [-0.0011492]
# Epoch 9968:
# Gradient for kernel: [[-0.00096364 -0.00113415]
#  [ 0.00093856  0.00114525]]
# Gradient for bias: [ 0.00041641 -0.0005771 ]
# Gradient for kernel: [[-0.00212745]
#  [ 0.00223552]]
# Gradient for bias: [-0.00114897]
# Epoch 9969:
# Gradient for kernel: [[-0.00096343 -0.0011339 ]
#  [ 0.00093836  0.001145  ]]
# Gradient for bias: [ 0.00041632 -0.00057697]
# Gradient for kernel: [[-0.00212704]
#  [ 0.00223508]]
# Gradient for bias: [-0.00114875]
# Epoch 9970:
# Gradient for kernel: [[-0.00096323 -0.00113365]
#  [ 0.00093817  0.00114475]]
# Gradient for bias: [ 0.00041623 -0.00057684]
# Gradient for kernel: [[-0.00212665]
#  [ 0.00223463]]
# Gradient for bias: [-0.00114853]
# Epoch 9971:
# Gradient for kernel: [[-0.00096301 -0.0011334 ]
#  [ 0.00093797  0.00114449]]
# Gradient for bias: [ 0.00041615 -0.00057671]
# Gradient for kernel: [[-0.00212624]
#  [ 0.00223421]]
# Gradient for bias: [-0.00114829]
# Epoch 9972:
# Gradient for kernel: [[-0.00096281 -0.00113315]
#  [ 0.00093777  0.00114425]]
# Gradient for bias: [ 0.00041606 -0.00057658]
# Gradient for kernel: [[-0.00212584]
#  [ 0.00223376]]
# Gradient for bias: [-0.00114808]
# Epoch 9973:
# Gradient for kernel: [[-0.0009626  -0.0011329 ]
#  [ 0.00093757  0.00114399]]
# Gradient for bias: [ 0.00041597 -0.00057645]
# Gradient for kernel: [[-0.00212544]
#  [ 0.00223332]]
# Gradient for bias: [-0.00114785]
# Epoch 9974:
# Gradient for kernel: [[-0.00096239 -0.00113265]
#  [ 0.00093738  0.00114374]]
# Gradient for bias: [ 0.00041589 -0.00057633]
# Gradient for kernel: [[-0.00212504]
#  [ 0.00223289]]
# Gradient for bias: [-0.00114761]
# Epoch 9975:
# Gradient for kernel: [[-0.00096218 -0.00113241]
#  [ 0.00093718  0.00114349]]
# Gradient for bias: [ 0.0004158 -0.0005762]
# Gradient for kernel: [[-0.00212463]
#  [ 0.00223245]]
# Gradient for bias: [-0.00114738]
# Epoch 9976:
# Gradient for kernel: [[-0.00096197 -0.00113216]
#  [ 0.00093698  0.00114324]]
# Gradient for bias: [ 0.00041572 -0.00057607]
# Gradient for kernel: [[-0.00212423]
#  [ 0.00223202]]
# Gradient for bias: [-0.00114715]
# Epoch 9977:
# Gradient for kernel: [[-0.00096177 -0.00113191]
#  [ 0.00093679  0.00114299]]
# Gradient for bias: [ 0.00041564 -0.00057595]
# Gradient for kernel: [[-0.00212383]
#  [ 0.00223158]]
# Gradient for bias: [-0.00114693]
# Epoch 9978:
# Gradient for kernel: [[-0.00096155 -0.00113166]
#  [ 0.00093659  0.00114274]]
# Gradient for bias: [ 0.00041555 -0.00057582]
# Gradient for kernel: [[-0.00212343]
#  [ 0.00223115]]
# Gradient for bias: [-0.0011467]
# Epoch 9979:
# Gradient for kernel: [[-0.00096135 -0.00113141]
#  [ 0.0009364   0.00114249]]
# Gradient for bias: [ 0.00041547 -0.00057569]
# Gradient for kernel: [[-0.00212303]
#  [ 0.0022307 ]]
# Gradient for bias: [-0.00114647]
# Epoch 9980:
# Gradient for kernel: [[-0.00096114 -0.00113117]
#  [ 0.0009362   0.00114223]]
# Gradient for bias: [ 0.00041538 -0.00057557]
# Gradient for kernel: [[-0.00212263]
#  [ 0.00223027]]
# Gradient for bias: [-0.00114624]
# Epoch 9981:
# Gradient for kernel: [[-0.00096093 -0.00113092]
#  [ 0.00093601  0.00114198]]
# Gradient for bias: [ 0.0004153  -0.00057545]
# Gradient for kernel: [[-0.00212222]
#  [ 0.00222984]]
# Gradient for bias: [-0.001146]
# Epoch 9982:
# Gradient for kernel: [[-0.00096072 -0.00113067]
#  [ 0.00093581  0.00114173]]
# Gradient for bias: [ 0.00041522 -0.00057531]
# Gradient for kernel: [[-0.00212183]
#  [ 0.0022294 ]]
# Gradient for bias: [-0.00114579]
# Epoch 9983:
# Gradient for kernel: [[-0.00096052 -0.00113043]
#  [ 0.00093561  0.00114148]]
# Gradient for bias: [ 0.00041513 -0.00057519]
# Gradient for kernel: [[-0.00212143]
#  [ 0.00222896]]
# Gradient for bias: [-0.00114556]
# Epoch 9984:
# Gradient for kernel: [[-0.00096031 -0.00113018]
#  [ 0.00093542  0.00114123]]
# Gradient for bias: [ 0.00041504 -0.00057506]
# Gradient for kernel: [[-0.00212103]
#  [ 0.00222853]]
# Gradient for bias: [-0.00114534]
# Epoch 9985:
# Gradient for kernel: [[-0.0009601  -0.00112993]
#  [ 0.00093522  0.00114098]]
# Gradient for bias: [ 0.00041496 -0.00057493]
# Gradient for kernel: [[-0.00212062]
#  [ 0.00222809]]
# Gradient for bias: [-0.00114511]
# Epoch 9986:
# Gradient for kernel: [[-0.0009599  -0.00112968]
#  [ 0.00093503  0.00114073]]
# Gradient for bias: [ 0.00041487 -0.00057481]
# Gradient for kernel: [[-0.00212023]
#  [ 0.00222766]]
# Gradient for bias: [-0.00114488]
# Epoch 9987:
# Gradient for kernel: [[-0.00095969 -0.00112943]
#  [ 0.00093483  0.00114048]]
# Gradient for bias: [ 0.00041479 -0.00057468]
# Gradient for kernel: [[-0.00211983]
#  [ 0.00222722]]
# Gradient for bias: [-0.00114466]
# Epoch 9988:
# Gradient for kernel: [[-0.00095948 -0.00112919]
#  [ 0.00093463  0.00114023]]
# Gradient for bias: [ 0.0004147  -0.00057455]
# Gradient for kernel: [[-0.00211943]
#  [ 0.00222678]]
# Gradient for bias: [-0.00114443]
# Epoch 9989:
# Gradient for kernel: [[-0.00095928 -0.00112893]
#  [ 0.00093444  0.00113999]]
# Gradient for bias: [ 0.00041461 -0.00057442]
# Gradient for kernel: [[-0.00211903]
#  [ 0.00222634]]
# Gradient for bias: [-0.00114421]
# Epoch 9990:
# Gradient for kernel: [[-0.00095907 -0.00112869]
#  [ 0.00093424  0.00113973]]
# Gradient for bias: [ 0.00041453 -0.0005743 ]
# Gradient for kernel: [[-0.00211863]
#  [ 0.00222591]]
# Gradient for bias: [-0.00114398]
# Epoch 9991:
# Gradient for kernel: [[-0.00095887 -0.00112844]
#  [ 0.00093405  0.00113949]]
# Gradient for bias: [ 0.00041444 -0.00057417]
# Gradient for kernel: [[-0.00211823]
#  [ 0.00222548]]
# Gradient for bias: [-0.00114376]
# Epoch 9992:
# Gradient for kernel: [[-0.00095866 -0.0011282 ]
#  [ 0.00093385  0.00113924]]
# Gradient for bias: [ 0.00041436 -0.00057404]
# Gradient for kernel: [[-0.00211783]
#  [ 0.00222504]]
# Gradient for bias: [-0.00114354]
# Epoch 9993:
# Gradient for kernel: [[-0.00095846 -0.00112795]
#  [ 0.00093365  0.00113898]]
# Gradient for bias: [ 0.00041427 -0.00057392]
# Gradient for kernel: [[-0.00211744]
#  [ 0.0022246 ]]
# Gradient for bias: [-0.00114331]
# Epoch 9994:
# Gradient for kernel: [[-0.00095826 -0.0011277 ]
#  [ 0.00093346  0.00113873]]
# Gradient for bias: [ 0.00041418 -0.00057379]
# Gradient for kernel: [[-0.00211704]
#  [ 0.00222416]]
# Gradient for bias: [-0.00114309]
# Epoch 9995:
# Gradient for kernel: [[-0.00095805 -0.00112745]
#  [ 0.00093326  0.00113849]]
# Gradient for bias: [ 0.00041409 -0.00057366]
# Gradient for kernel: [[-0.00211665]
#  [ 0.00222372]]
# Gradient for bias: [-0.00114287]
# Epoch 9996:
# Gradient for kernel: [[-0.00095784 -0.00112721]
#  [ 0.00093307  0.00113824]]
# Gradient for bias: [ 0.00041401 -0.00057353]
# Gradient for kernel: [[-0.00211624]
#  [ 0.00222329]]
# Gradient for bias: [-0.00114264]
# Epoch 9997:
# Gradient for kernel: [[-0.00095763 -0.00112696]
#  [ 0.00093287  0.00113799]]
# Gradient for bias: [ 0.00041393 -0.0005734 ]
# Gradient for kernel: [[-0.00211584]
#  [ 0.00222286]]
# Gradient for bias: [-0.00114241]
# Epoch 9998:
# Gradient for kernel: [[-0.00095743 -0.00112672]
#  [ 0.00093268  0.00113774]]
# Gradient for bias: [ 0.00041384 -0.00057328]
# Gradient for kernel: [[-0.00211545]
#  [ 0.00222242]]
# Gradient for bias: [-0.00114219]
# Epoch 9999:
# Gradient for kernel: [[-0.00095722 -0.00112647]
#  [ 0.00093248  0.00113748]]
# Gradient for bias: [ 0.00041376 -0.00057317]
# Gradient for kernel: [[-0.00211505]
#  [ 0.002222  ]]
# Gradient for bias: [-0.00114195]
# True labels (y): [0. 1. 1. 0.]
# Predictions after training: [0.08563473 0.90268654 0.9218333  0.07491664]
# 'A program has been written to output the gradients at each epoch using TensorFlow s GradientTape library, and it has been tested. '

# %% [markdown]
# #True labels (y): [0. 1. 1. 0.]
# #Predictions after training: [0.03138629 0.95564526 0.9624098  0.04976979] 이도윤
