# %% [markdown]
# <a href="https://colab.research.google.com/github/Archi2903/AI-in-Engenery/blob/main/HW2_%EC%9D%B4%EB%8F%84%EC%9C%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Energy resources and artificial intelligence 이도윤22251844
#
# HW#01 - XOR model
#
# 내용:
# Using Keras (tf.keras), train and compare a single-layer perceptron and a small MLP (e.g. one hidden layer) to learn the logical gates AND, OR, and XOR on the four 2-bit inputs.
#
# Report final accuracy for each gate, show the models’ predictions (and optionally a loss curve).
#
# Submit the jupyter notebook file.

# %%
# Set random seeds for reproducibility 42
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# DATA 준비
X = np.array([
    [0., 0.],
    [0., 1.],
    [1., 0.],
    [1., 1.]
])

# Target labels for each task (AND, OR, XOR)
y_AND = np.array([[0.], [0.], [0.], [1.]])
y_OR  = np.array([[0.], [1.], [1.], [1.]])
y_XOR = np.array([[0.], [1.], [1.], [0.]])

# Defenite main functions(perceptron, mlp_xor, train)
def perceptron(input_dim=2):        # input_dim - binary input (0 and 1) )
    """function perceptron (AND/OR)."""
    model = keras.Sequential([
                              # Sequential - model type (a linear stack of layers)
        keras.layers.Dense(1,    # Dense - fully connected layer with 1 neuron
                           activation='sigmoid',    # sigmoid - activation function (outputs values between 0 and 1)
                           input_shape=(input_dim,)) # input_shape - shape of the input data (2 features)
    ]) #
    model.compile(  # compile the model with specified parameters
        optimizer=keras.optimizers.SGD(learning_rate=0.1), # optimizer - Stochastic Gradient Descent with learning rate 0.1
        loss='binary_crossentropy', # loss function - binary crossentropy (suitable for binary classification)
        metrics=['accuracy'] # metrics - accuracy to evaluate the model's performance
    )
    return model

def mlp_xor(input_dim=2):
    """function mlp_xor (XOR)"""
    model = keras.Sequential([
        keras.layers.Dense(2, # hidden layer with 4 neurons,because XOR is not linearly separable
                           activation='sigmoid', #
                           input_shape=(input_dim,)),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(
        optimizer=keras.optimizers.SGD(learning_rate=0.1), # optimizer - Stochastic Gradient Descent with learning rate 0.1
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

def train(name, model, X, y, epochs): # name : AND/OR/XOR , model - perceptron, X - bin data(0,1), y , epochs - number training
    model.fit(X, y, epochs=epochs, verbose=0) # verbose=0 - no output during training
    print(f"Logical gate \n{name} - probabilities and rounding (threshold 0.5)") # if value > 0.5,then 1, else 0
    for a, b in X:
        p = model.predict(np.array([[a, b]], dtype=np.float32), verbose=0)[0, 0]
        print(f"{int(a)} {name} {int(b)} -> prob={p:.4f} pred={int(p>=0.5)}")

    print("Weights:", [w.shape for w in model.get_weights()])

# %% [markdown]
# Training perceptron
#
# # Training models for AND, OR, XOR logical gates

# %%
# 1.Simulation situacion Underfitting (epochs=5) ~3 sec calculation

# Training AND
model_and = perceptron()
train("AND", model_and, X, y_AND, epochs=5) # epochs - число эпох обучения

# Training OR
model_or = perceptron()
train("OR", model_or, X, y_OR, epochs=5)

# Training XOR(model - perceptron)
model_xor = perceptron()
train("XOR", model_xor, X, y_XOR, epochs=5)
# Out:
# c:\Users\에너지자원공학과\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Logical gate
# AND - probabilities and rounding (threshold 0.5)
# 0 AND 0 -> prob=0.4723 pred=0
# 0 AND 1 -> prob=0.5018 pred=1
# 1 AND 0 -> prob=0.4122 pred=0
# 1 AND 1 -> prob=0.4411 pred=0
# Weights: [(2, 1), (1,)]
# Logical gate
# OR - probabilities and rounding (threshold 0.5)
# 0 OR 0 -> prob=0.5228 pred=1
# 0 OR 1 -> prob=0.7240 pred=1
# 1 OR 0 -> prob=0.4570 pred=0
# 1 OR 1 -> prob=0.6683 pred=1
# Weights: [(2, 1), (1,)]
# Logical gate
# XOR - probabilities and rounding (threshold 0.5)
# 0 XOR 0 -> prob=0.5006 pred=1
# 0 XOR 1 -> prob=0.7006 pred=1
# 1 XOR 0 -> prob=0.2921 pred=0
# 1 XOR 1 -> prob=0.4907 pred=0
# Weights: [(2, 1), (1,)]

# %%
# 1.Simulation situacion derfitting (epochs>300) ~40 sec calculation!

# Training AND
model_and = perceptron()
train("AND", model_and, X, y_AND, epochs=300) # epochs - number training
# Training OR
model_or = perceptron()
train("OR", model_or, X, y_OR, epochs=300)

# Training XOR(model - perceptron)
model_xor = perceptron()
train("XOR", model_xor, X, y_XOR, epochs=300)
# Out:
# Logical gate
# AND - probabilities and rounding (threshold 0.5)
# 0 AND 0 -> prob=0.0788 pred=0
# 0 AND 1 -> prob=0.2861 pred=0
# 1 AND 0 -> prob=0.2379 pred=0
# 1 AND 1 -> prob=0.5940 pred=1
# Weights: [(2, 1), (1,)]
# Logical gate
# OR - probabilities and rounding (threshold 0.5)
# 0 OR 0 -> prob=0.4185 pred=0
# 0 OR 1 -> prob=0.8109 pred=1
# 1 OR 0 -> prob=0.9038 pred=1
# 1 OR 1 -> prob=0.9825 pred=1
# Weights: [(2, 1), (1,)]
# Logical gate
# XOR - probabilities and rounding (threshold 0.5)
# 0 XOR 0 -> prob=0.4412 pred=0
# 0 XOR 1 -> prob=0.4820 pred=0
# 1 XOR 0 -> prob=0.4994 pred=0
# 1 XOR 1 -> prob=0.5404 pred=1
# Weights: [(2, 1), (1,)]

# %% [markdown]
# # Problem XOR
# A simple perceptron model is not suitable for learning the XOR logical gate, because the XOR function is not linearly separable. Therefore, a more complex model (such as a multilayer perceptron with a hidden layer) will be used for training.

# %%
# Training XOR with MLP(Success only big epochs>10000) ~7minutes calculation!!!!!!!!!
model_xor = mlp_xor()
train("XOR", model_xor, X, y_XOR, epochs=5000)
"T4 5000 epochs ~3min  test:1-0, 2-0,3 - x, 4-x"
# Out:
# Logical gate
# XOR - probabilities and rounding (threshold 0.5)
# 0 XOR 0 -> prob=0.0770 pred=0
# 0 XOR 1 -> prob=0.8205 pred=1
# 1 XOR 0 -> prob=0.8203 pred=1
# 1 XOR 1 -> prob=0.2408 pred=0
# Weights: [(2, 2), (2,), (2, 1), (1,)]
# 'T4 5000 epochs ~3min  test:1-0, 2-0,3 - x, 4-x'

# %% [markdown]
# # **HW #02 - Automatic differentiation**
# 22251844 이도윤
# ## Write a program that prints out the gradients of your neural network model (designed to solve the XOR problem) at each epoch during training, so that you can observe how the weights change throughout the training process.

# %%
"For output the gradients at each epoch in tensorflow has tf.GradientTape"

"1.Add loss function and optimization method SGD"
# Selection of the loss function (MSE) and the optimization method (SGD) for training
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)

"2. Write function every epoch with Gradient"
# A training loop for 1000 epochs with gradient computation and output; for gradient output the tf.GradientTape() API is used
for epoch in range(10000):
    # operation for auti different
    with tf.GradientTape() as tape:
        y_pred = model_xor(X)                             # forward
        loss_value = tf.reduce_mean(tf.square(y_pred - y_XOR))  # MSE: the mean squared difference between the prediction and the target value
    # We compute the gradients of the loss function with respect to all trainable parameters (weights and biases)

    gradients = tape.gradient(loss_value, model_xor.trainable_variables)
    # update the model parameters at each step of gradient descent
    optimizer.apply_gradients(zip(gradients, model_xor.trainable_variables))
    # We output the gradients for each parameter at the current epoch
    print(f"Epoch {epoch}:")
    for var, grad in zip(model_xor.trainable_variables, gradients):
        print(f"Gradient for {var.name}: {grad.numpy()}")

# Check
predictions = model_xor(X).numpy()


print("True labels (y):", y_XOR.reshape(-1))          # True XOR
print("Predictions after training:", predictions.reshape(-1))  # Predict

"Result: wrtite programm"
"A program has been written to output the gradients at each epoch using TensorFlow s GradientTape library, and it has been tested. "
# Out:
# Epoch 0:
# Gradient for kernel: [[-0.00756957  0.00168353]
#  [-0.00762281  0.00172521]]
# Gradient for bias: [0.00325475 0.00088784]
# Gradient for kernel: [[0.01151581]
#  [0.00168002]]
# Gradient for bias: [-0.0017095]
# Epoch 1:
# Gradient for kernel: [[-0.00750767  0.00168422]
#  [-0.00756093  0.00172591]]
# Gradient for bias: [0.00332865 0.00088842]
# Gradient for kernel: [[0.01147667]
#  [0.00168028]]
# Gradient for bias: [-0.00177387]
# Epoch 2:
# Gradient for kernel: [[-0.0074471   0.00168486]
#  [-0.00750034  0.00172656]]
# Gradient for bias: [0.00340086 0.00088887]
# Gradient for kernel: [[0.01143829]
#  [0.00168058]]
# Gradient for bias: [-0.00183667]
# Epoch 3:
# Gradient for kernel: [[-0.0073878   0.00168546]
#  [-0.00744104  0.00172717]]
# Gradient for bias: [0.00347141 0.00088921]
# Gradient for kernel: [[0.01140064]
#  [0.00168092]]
# Gradient for bias: [-0.00189794]
# Epoch 4:
# Gradient for kernel: [[-0.0073297   0.00168601]
#  [-0.00738293  0.00172773]]
# Gradient for bias: [0.0035404  0.00088942]
# Gradient for kernel: [[0.01136368]
#  [0.0016813 ]]
# Gradient for bias: [-0.00195777]
# Epoch 5:
# Gradient for kernel: [[-0.00727286  0.00168652]
#  [-0.00732607  0.00172825]]
# Gradient for bias: [0.00360776 0.00088951]
# Gradient for kernel: [[0.01132745]
#  [0.00168173]]
# Gradient for bias: [-0.0020161]
# Epoch 6:
# Gradient for kernel: [[-0.00721716  0.00168699]
#  [-0.00727035  0.00172873]]
# Gradient for bias: [0.00367363 0.00088949]
# Gradient for kernel: [[0.01129188]
#  [0.0016822 ]]
# Gradient for bias: [-0.00207304]
# Epoch 7:
# Gradient for kernel: [[-0.00716264  0.00168741]
#  [-0.00721583  0.00172916]]
# Gradient for bias: [0.00373796 0.00088935]
# Gradient for kernel: [[0.01125701]
#  [0.0016827 ]]
# Gradient for bias: [-0.00212857]
# Epoch 8:
# Gradient for kernel: [[-0.00710925  0.0016878 ]
#  [-0.00716241  0.00172955]]
# Gradient for bias: [0.00380083 0.00088911]
# Gradient for kernel: [[0.01122278]
#  [0.00168324]]
# Gradient for bias: [-0.00218275]
# Epoch 9:
# Gradient for kernel: [[-0.00705697  0.00168814]
#  [-0.00711011  0.0017299 ]]
# Gradient for bias: [0.00386225 0.00088875]
# Gradient for kernel: [[0.01118919]
#  [0.00168383]]
# Gradient for bias: [-0.00223558]
# Epoch 10:
# Gradient for kernel: [[-0.00700575  0.00168845]
#  [-0.00705887  0.00173021]]
# Gradient for bias: [0.00392229 0.00088829]
# Gradient for kernel: [[0.01115623]
#  [0.00168445]]
# Gradient for bias: [-0.00228714]
# Epoch 11:
# Gradient for kernel: [[-0.00695558  0.00168872]
#  [-0.00700869  0.00173048]]
# Gradient for bias: [0.00398095 0.00088774]
# Gradient for kernel: [[0.01112388]
#  [0.0016851 ]]
# Gradient for bias: [-0.00233743]
# Epoch 12:
# Gradient for kernel: [[-0.00690645  0.00168895]
#  [-0.00695953  0.00173071]]
# Gradient for bias: [0.00403826 0.00088708]
# Gradient for kernel: [[0.01109212]
#  [0.00168579]]
# Gradient for bias: [-0.00238648]
# Epoch 13:
# Gradient for kernel: [[-0.00685831  0.00168914]
#  [-0.00691136  0.00173091]]
# Gradient for bias: [0.00409427 0.00088631]
# Gradient for kernel: [[0.01106095]
#  [0.00168651]]
# Gradient for bias: [-0.00243433]
# Epoch 14:
# Gradient for kernel: [[-0.00681113  0.0016893 ]
#  [-0.00686414  0.00173107]]
# Gradient for bias: [0.00414904 0.00088546]
# Gradient for kernel: [[0.01103033]
#  [0.00168726]]
# Gradient for bias: [-0.00248103]
# Epoch 15:
# Gradient for kernel: [[-0.00676495  0.00168943]
#  [-0.00681793  0.00173119]]
# Gradient for bias: [0.00420249 0.00088451]
# Gradient for kernel: [[0.0110003 ]
#  [0.00168805]]
# Gradient for bias: [-0.0025265]
# Epoch 16:
# Gradient for kernel: [[-0.00671968  0.00168952]
#  [-0.00677264  0.00173128]]
# Gradient for bias: [0.00425475 0.00088347]
# Gradient for kernel: [[0.01097081]
#  [0.00168887]]
# Gradient for bias: [-0.00257088]
# Epoch 17:
# Gradient for kernel: [[-0.00667533  0.00168958]
#  [-0.00672825  0.00173134]]
# Gradient for bias: [0.00430581 0.00088235]
# Gradient for kernel: [[0.01094184]
#  [0.00168972]]
# Gradient for bias: [-0.00261417]
# Epoch 18:
# Gradient for kernel: [[-0.00663185  0.0016896 ]
#  [-0.00668474  0.00173136]]
# Gradient for bias: [0.00435572 0.00088114]
# Gradient for kernel: [[0.01091339]
#  [0.0016906 ]]
# Gradient for bias: [-0.00265639]
# Epoch 19:
# Gradient for kernel: [[-0.00658926  0.0016896 ]
#  [-0.00664211  0.00173135]]
# Gradient for bias: [0.00440447 0.00087984]
# Gradient for kernel: [[0.01088544]
#  [0.00169151]]
# Gradient for bias: [-0.00269755]
# Epoch 20:
# Gradient for kernel: [[-0.00654753  0.00168956]
#  [-0.00660034  0.00173131]]
# Gradient for bias: [0.0044521  0.00087846]
# Gradient for kernel: [[0.01085801]
#  [0.00169244]]
# Gradient for bias: [-0.00273766]
# Epoch 21:
# Gradient for kernel: [[-0.00650662  0.00168949]
#  [-0.0065594   0.00173124]]
# Gradient for bias: [0.00449864 0.000877  ]
# Gradient for kernel: [[0.01083106]
#  [0.00169341]]
# Gradient for bias: [-0.00277679]
# Epoch 22:
# Gradient for kernel: [[-0.00646654  0.0016894 ]
#  [-0.00651927  0.00173114]]
# Gradient for bias: [0.0045441  0.00087546]
# Gradient for kernel: [[0.0108046]
#  [0.0016944]]
# Gradient for bias: [-0.00281491]
# Epoch 23:
# Gradient for kernel: [[-0.00642725  0.00168927]
#  [-0.00647994  0.00173101]]
# Gradient for bias: [0.00458851 0.00087384]
# Gradient for kernel: [[0.01077859]
#  [0.00169542]]
# Gradient for bias: [-0.00285207]
# Epoch 24:
# Gradient for kernel: [[-0.00638874  0.00168912]
#  [-0.00644139  0.00173085]]
# Gradient for bias: [0.0046319  0.00087214]
# Gradient for kernel: [[0.01075304]
#  [0.00169646]]
# Gradient for bias: [-0.00288828]
# Epoch 25:
# Gradient for kernel: [[-0.00635095  0.00168894]
#  [-0.00640356  0.00173066]]
# Gradient for bias: [0.00467434 0.00087038]
# Gradient for kernel: [[0.01072792]
#  [0.00169753]]
# Gradient for bias: [-0.00292363]
# Epoch 26:
# Gradient for kernel: [[-0.00631392  0.00168873]
#  [-0.00636649  0.00173044]]
# Gradient for bias: [0.00471578 0.00086855]
# Gradient for kernel: [[0.01070325]
#  [0.00169862]]
# Gradient for bias: [-0.00295806]
# Epoch 27:
# Gradient for kernel: [[-0.00627764  0.0016885 ]
#  [-0.00633016  0.0017302 ]]
# Gradient for bias: [0.00475624 0.00086664]
# Gradient for kernel: [[0.010679  ]
#  [0.00169974]]
# Gradient for bias: [-0.00299159]
# Epoch 28:
# Gradient for kernel: [[-0.00624208  0.00168824]
#  [-0.00629454  0.00172993]]
# Gradient for bias: [0.00479576 0.00086466]
# Gradient for kernel: [[0.01065518]
#  [0.00170088]]
# Gradient for bias: [-0.00302425]
# Epoch 29:
# Gradient for kernel: [[-0.00620715  0.00168796]
#  [-0.00625957  0.00172964]]
# Gradient for bias: [0.00483444 0.00086263]
# Gradient for kernel: [[0.01063173]
#  [0.00170204]]
# Gradient for bias: [-0.00305615]
# Epoch 30:
# Gradient for kernel: [[-0.00617295  0.00168765]
#  [-0.00622531  0.00172932]]
# Gradient for bias: [0.00487216 0.00086052]
# Gradient for kernel: [[0.0106087 ]
#  [0.00170322]]
# Gradient for bias: [-0.00308715]
# Epoch 31:
# Gradient for kernel: [[-0.00613941  0.00168731]
#  [-0.00619172  0.00172898]]
# Gradient for bias: [0.004909   0.00085835]
# Gradient for kernel: [[0.01058607]
#  [0.00170443]]
# Gradient for bias: [-0.00311736]
# Epoch 32:
# Gradient for kernel: [[-0.00610651  0.00168696]
#  [-0.00615877  0.00172861]]
# Gradient for bias: [0.00494501 0.00085612]
# Gradient for kernel: [[0.01056382]
#  [0.00170566]]
# Gradient for bias: [-0.0031468]
# Epoch 33:
# Gradient for kernel: [[-0.00607424  0.00168658]
#  [-0.00612646  0.00172822]]
# Gradient for bias: [0.00498018 0.00085383]
# Gradient for kernel: [[0.01054194]
#  [0.0017069 ]]
# Gradient for bias: [-0.00317547]
# Epoch 34:
# Gradient for kernel: [[-0.00604257  0.00168618]
#  [-0.00609473  0.00172781]]
# Gradient for bias: [0.00501456 0.00085148]
# Gradient for kernel: [[0.0105204 ]
#  [0.00170817]]
# Gradient for bias: [-0.00320342]
# Epoch 35:
# Gradient for kernel: [[-0.00601153  0.00168576]
#  [-0.00606363  0.00172738]]
# Gradient for bias: [0.00504812 0.00084908]
# Gradient for kernel: [[0.01049924]
#  [0.00170946]]
# Gradient for bias: [-0.00323061]
# Epoch 36:
# Gradient for kernel: [[-0.00598106  0.00168532]
#  [-0.0060331   0.00172692]]
# Gradient for bias: [0.00508091 0.00084662]
# Gradient for kernel: [[0.01047841]
#  [0.00171076]]
# Gradient for bias: [-0.00325711]
# Epoch 37:
# Gradient for kernel: [[-0.00595118  0.00168485]
#  [-0.00600317  0.00172645]]
# Gradient for bias: [0.00511293 0.0008441 ]
# Gradient for kernel: [[0.01045793]
#  [0.00171208]]
# Gradient for bias: [-0.0032829]
# Epoch 38:
# Gradient for kernel: [[-0.00592185  0.00168437]
#  [-0.00597378  0.00172595]]
# Gradient for bias: [0.00514422 0.00084154]
# Gradient for kernel: [[0.01043778]
#  [0.00171342]]
# Gradient for bias: [-0.00330802]
# Epoch 39:
# Gradient for kernel: [[-0.00589309  0.00168387]
#  [-0.00594496  0.00172543]]
# Gradient for bias: [0.00517477 0.00083892]
# Gradient for kernel: [[0.01041795]
#  [0.00171478]]
# Gradient for bias: [-0.00333247]
# Epoch 40:
# Gradient for kernel: [[-0.00586483  0.00168335]
#  [-0.00591665  0.0017249 ]]
# Gradient for bias: [0.00520464 0.00083625]
# Gradient for kernel: [[0.01039843]
#  [0.00171615]]
# Gradient for bias: [-0.00335628]
# Epoch 41:
# Gradient for kernel: [[-0.00583714  0.00168281]
#  [-0.00588888  0.00172434]]
# Gradient for bias: [0.00523379 0.00083354]
# Gradient for kernel: [[0.01037923]
#  [0.00171754]]
# Gradient for bias: [-0.00337945]
# Epoch 42:
# Gradient for kernel: [[-0.00580994  0.00168225]
#  [-0.00586163  0.00172377]]
# Gradient for bias: [0.00526226 0.00083078]
# Gradient for kernel: [[0.01036033]
#  [0.00171895]]
# Gradient for bias: [-0.00340199]
# Epoch 43:
# Gradient for kernel: [[-0.00578326  0.00168168]
#  [-0.00583488  0.00172318]]
# Gradient for bias: [0.00529006 0.00082797]
# Gradient for kernel: [[0.01034173]
#  [0.00172037]]
# Gradient for bias: [-0.00342393]
# Epoch 44:
# Gradient for kernel: [[-0.00575707  0.00168108]
#  [-0.00580863  0.00172257]]
# Gradient for bias: [0.0053172  0.00082511]
# Gradient for kernel: [[0.01032343]
#  [0.00172181]]
# Gradient for bias: [-0.00344526]
# Epoch 45:
# Gradient for kernel: [[-0.00573136  0.00168048]
#  [-0.00578286  0.00172194]]
# Gradient for bias: [0.00534371 0.00082221]
# Gradient for kernel: [[0.0103054 ]
#  [0.00172326]]
# Gradient for bias: [-0.00346601]
# Epoch 46:
# Gradient for kernel: [[-0.00570611  0.00167985]
#  [-0.00575756  0.0017213 ]]
# Gradient for bias: [0.00536961 0.00081928]
# Gradient for kernel: [[0.01028766]
#  [0.00172472]]
# Gradient for bias: [-0.0034862]
# Epoch 47:
# Gradient for kernel: [[-0.00568134  0.00167921]
#  [-0.0057327   0.00172064]]
# Gradient for bias: [0.00539489 0.00081629]
# Gradient for kernel: [[0.01027018]
#  [0.0017262 ]]
# Gradient for bias: [-0.00350584]
# Epoch 48:
# Gradient for kernel: [[-0.005657    0.00167855]
#  [-0.00570831  0.00171997]]
# Gradient for bias: [0.00541957 0.00081327]
# Gradient for kernel: [[0.01025297]
#  [0.00172769]]
# Gradient for bias: [-0.00352494]
# Epoch 49:
# Gradient for kernel: [[-0.00563314  0.00167788]
#  [-0.00568437  0.00171928]]
# Gradient for bias: [0.00544365 0.00081021]
# Gradient for kernel: [[0.01023603]
#  [0.0017292 ]]
# Gradient for bias: [-0.00354349]
# Epoch 50:
# Gradient for kernel: [[-0.00560967  0.00167719]
#  [-0.00566083  0.00171857]]
# Gradient for bias: [0.0054672  0.00080712]
# Gradient for kernel: [[0.01021933]
#  [0.00173071]]
# Gradient for bias: [-0.00356156]
# Epoch 51:
# Gradient for kernel: [[-0.00558661  0.00167649]
#  [-0.00563773  0.00171785]]
# Gradient for bias: [0.00549019 0.00080398]
# Gradient for kernel: [[0.01020287]
#  [0.00173224]]
# Gradient for bias: [-0.00357911]
# Epoch 52:
# Gradient for kernel: [[-0.00556402  0.00167578]
#  [-0.00561505  0.00171712]]
# Gradient for bias: [0.00551259 0.0008008 ]
# Gradient for kernel: [[0.01018668]
#  [0.00173379]]
# Gradient for bias: [-0.00359613]
# Epoch 53:
# Gradient for kernel: [[-0.0055418   0.00167505]
#  [-0.00559276  0.00171637]]
# Gradient for bias: [0.00553449 0.0007976 ]
# Gradient for kernel: [[0.01017071]
#  [0.00173534]]
# Gradient for bias: [-0.00361269]
# Epoch 54:
# Gradient for kernel: [[-0.00551996  0.00167431]
#  [-0.00557086  0.00171561]]
# Gradient for bias: [0.00555588 0.00079436]
# Gradient for kernel: [[0.01015497]
#  [0.0017369 ]]
# Gradient for bias: [-0.0036288]
# Epoch 55:
# Gradient for kernel: [[-0.00549853  0.00167355]
#  [-0.00554935  0.00171483]]
# Gradient for bias: [0.00557673 0.00079109]
# Gradient for kernel: [[0.01013947]
#  [0.00173848]]
# Gradient for bias: [-0.00364442]
# Epoch 56:
# Gradient for kernel: [[-0.00547749  0.00167279]
#  [-0.00552824  0.00171405]]
# Gradient for bias: [0.00559707 0.00078778]
# Gradient for kernel: [[0.0101242 ]
#  [0.00174006]]
# Gradient for bias: [-0.00365957]
# Epoch 57:
# Gradient for kernel: [[-0.00545682  0.001672  ]
#  [-0.00550749  0.00171325]]
# Gradient for bias: [0.00561692 0.00078444]
# Gradient for kernel: [[0.01010915]
#  [0.00174166]]
# Gradient for bias: [-0.00367427]
# Epoch 58:
# Gradient for kernel: [[-0.0054365   0.00167121]
#  [-0.00548709  0.00171243]]
# Gradient for bias: [0.00563631 0.00078107]
# Gradient for kernel: [[0.0100943 ]
#  [0.00174327]]
# Gradient for bias: [-0.00368856]
# Epoch 59:
# Gradient for kernel: [[-0.00541655  0.00167041]
#  [-0.00546708  0.00171161]]
# Gradient for bias: [0.0056552  0.00077767]
# Gradient for kernel: [[0.01007968]
#  [0.00174488]]
# Gradient for bias: [-0.00370241]
# Epoch 60:
# Gradient for kernel: [[-0.0053969   0.00166959]
#  [-0.00544736  0.00171077]]
# Gradient for bias: [0.00567369 0.00077425]
# Gradient for kernel: [[0.01006523]
#  [0.0017465 ]]
# Gradient for bias: [-0.00371589]
# Epoch 61:
# Gradient for kernel: [[-0.00537761  0.00166877]
#  [-0.00542801  0.00170993]]
# Gradient for bias: [0.00569171 0.00077079]
# Gradient for kernel: [[0.010051  ]
#  [0.00174814]]
# Gradient for bias: [-0.00372894]
# Epoch 62:
# Gradient for kernel: [[-0.00535866  0.00166793]
#  [-0.00540897  0.00170907]]
# Gradient for bias: [0.00570929 0.00076731]
# Gradient for kernel: [[0.01003696]
#  [0.00174978]]
# Gradient for bias: [-0.0037416]
# Epoch 63:
# Gradient for kernel: [[-0.00534002  0.00166709]
#  [-0.00539025  0.0017082 ]]
# Gradient for bias: [0.00572646 0.0007638 ]
# Gradient for kernel: [[0.0100231 ]
#  [0.00175143]]
# Gradient for bias: [-0.00375389]
# Epoch 64:
# Gradient for kernel: [[-0.00532169  0.00166623]
#  [-0.00537185  0.00170732]]
# Gradient for bias: [0.0057432  0.00076027]
# Gradient for kernel: [[0.01000943]
#  [0.00175309]]
# Gradient for bias: [-0.0037658]
# Epoch 65:
# Gradient for kernel: [[-0.00530369  0.00166536]
#  [-0.00535379  0.00170643]]
# Gradient for bias: [0.00575951 0.00075671]
# Gradient for kernel: [[0.00999596]
#  [0.00175476]]
# Gradient for bias: [-0.00377732]
# Epoch 66:
# Gradient for kernel: [[-0.00528599  0.00166449]
#  [-0.005336    0.00170553]]
# Gradient for bias: [0.00577545 0.00075313]
# Gradient for kernel: [[0.00998266]
#  [0.00175643]]
# Gradient for bias: [-0.0037885]
# Epoch 67:
# Gradient for kernel: [[-0.0052686   0.0016636 ]
#  [-0.00531853  0.00170462]]
# Gradient for bias: [0.00579096 0.00074952]
# Gradient for kernel: [[0.00996954]
#  [0.00175811]]
# Gradient for bias: [-0.0037993]
# Epoch 68:
# Gradient for kernel: [[-0.00525147  0.00166271]
#  [-0.00530133  0.00170371]]
# Gradient for bias: [0.00580613 0.0007459 ]
# Gradient for kernel: [[0.00995658]
#  [0.0017598 ]]
# Gradient for bias: [-0.0038098]
# Epoch 69:
# Gradient for kernel: [[-0.00523464  0.0016618 ]
#  [-0.00528443  0.00170278]]
# Gradient for bias: [0.0058209  0.00074225]
# Gradient for kernel: [[0.0099438]
#  [0.0017615]]
# Gradient for bias: [-0.00381993]
# Epoch 70:
# Gradient for kernel: [[-0.00521808  0.00166089]
#  [-0.00526779  0.00170184]]
# Gradient for bias: [0.00583532 0.00073858]
# Gradient for kernel: [[0.00993118]
#  [0.0017632 ]]
# Gradient for bias: [-0.00382975]
# Epoch 71:
# Gradient for kernel: [[-0.0052018   0.00165997]
#  [-0.00525143  0.0017009 ]]
# Gradient for bias: [0.00584937 0.00073489]
# Gradient for kernel: [[0.00991871]
#  [0.00176491]]
# Gradient for bias: [-0.00383924]
# Epoch 72:
# Gradient for kernel: [[-0.00518579  0.00165904]
#  [-0.00523534  0.00169994]]
# Gradient for bias: [0.00586305 0.00073117]
# Gradient for kernel: [[0.00990641]
#  [0.00176662]]
# Gradient for bias: [-0.00384841]
# Epoch 73:
# Gradient for kernel: [[-0.00517002  0.0016581 ]
#  [-0.00521949  0.00169898]]
# Gradient for bias: [0.00587643 0.00072744]
# Gradient for kernel: [[0.00989425]
#  [0.00176834]]
# Gradient for bias: [-0.00385729]
# Epoch 74:
# Gradient for kernel: [[-0.00515454  0.00165716]
#  [-0.00520394  0.00169802]]
# Gradient for bias: [0.00588942 0.0007237 ]
# Gradient for kernel: [[0.00988226]
#  [0.00177007]]
# Gradient for bias: [-0.00386584]
# Epoch 75:
# Gradient for kernel: [[-0.0051393   0.00165621]
#  [-0.00518861  0.00169704]]
# Gradient for bias: [0.0059021  0.00071993]
# Gradient for kernel: [[0.00987041]
#  [0.0017718 ]]
# Gradient for bias: [-0.00387411]
# Epoch 76:
# Gradient for kernel: [[-0.0051243   0.00165525]
#  [-0.00517355  0.00169606]]
# Gradient for bias: [0.00591445 0.00071615]
# Gradient for kernel: [[0.00985872]
#  [0.00177354]]
# Gradient for bias: [-0.00388208]
# Epoch 77:
# Gradient for kernel: [[-0.00510951  0.00165428]
#  [-0.00515868  0.00169507]]
# Gradient for bias: [0.00592653 0.00071235]
# Gradient for kernel: [[0.00984713]
#  [0.00177528]]
# Gradient for bias: [-0.00388982]
# Epoch 78:
# Gradient for kernel: [[-0.00509501  0.00165331]
#  [-0.00514409  0.00169407]]
# Gradient for bias: [0.00593824 0.00070853]
# Gradient for kernel: [[0.00983572]
#  [0.00177703]]
# Gradient for bias: [-0.00389722]
# Epoch 79:
# Gradient for kernel: [[-0.00508072  0.00165233]
#  [-0.00512972  0.00169307]]
# Gradient for bias: [0.00594967 0.0007047 ]
# Gradient for kernel: [[0.00982444]
#  [0.00177878]]
# Gradient for bias: [-0.00390438]
# Epoch 80:
# Gradient for kernel: [[-0.00506664  0.00165134]
#  [-0.00511556  0.00169205]]
# Gradient for bias: [0.00596081 0.00070085]
# Gradient for kernel: [[0.00981328]
#  [0.00178053]]
# Gradient for bias: [-0.00391128]
# Epoch 81:
# Gradient for kernel: [[-0.00505278  0.00165035]
#  [-0.00510162  0.00169104]]
# Gradient for bias: [0.00597167 0.00069699]
# Gradient for kernel: [[0.00980224]
#  [0.00178229]]
# Gradient for bias: [-0.00391793]
# Epoch 82:
# Gradient for kernel: [[-0.00503913  0.00164935]
#  [-0.00508788  0.00169001]]
# Gradient for bias: [0.00598226 0.00069311]
# Gradient for kernel: [[0.00979133]
#  [0.00178406]]
# Gradient for bias: [-0.00392434]
# Epoch 83:
# Gradient for kernel: [[-0.0050257   0.00164835]
#  [-0.00507436  0.00168899]]
# Gradient for bias: [0.00599256 0.00068922]
# Gradient for kernel: [[0.00978055]
#  [0.00178583]]
# Gradient for bias: [-0.00393049]
# Epoch 84:
# Gradient for kernel: [[-0.00501249  0.00164734]
#  [-0.00506108  0.00168795]]
# Gradient for bias: [0.00600257 0.00068532]
# Gradient for kernel: [[0.00976991]
#  [0.0017876 ]]
# Gradient for bias: [-0.00393639]
# Epoch 85:
# Gradient for kernel: [[-0.00499946  0.00164633]
#  [-0.00504797  0.00168691]]
# Gradient for bias: [0.00601233 0.0006814 ]
# Gradient for kernel: [[0.00975937]
#  [0.00178938]]
# Gradient for bias: [-0.00394206]
# Epoch 86:
# Gradient for kernel: [[-0.00498664  0.00164531]
#  [-0.00503507  0.00168586]]
# Gradient for bias: [0.00602182 0.00067748]
# Gradient for kernel: [[0.00974894]
#  [0.00179116]]
# Gradient for bias: [-0.00394751]
# Epoch 87:
# Gradient for kernel: [[-0.004974    0.00164428]
#  [-0.00502235  0.00168481]]
# Gradient for bias: [0.00603108 0.00067354]
# Gradient for kernel: [[0.00973863]
#  [0.00179294]]
# Gradient for bias: [-0.00395275]
# Epoch 88:
# Gradient for kernel: [[-0.00496156  0.00164325]
#  [-0.00500982  0.00168376]]
# Gradient for bias: [0.00604008 0.00066959]
# Gradient for kernel: [[0.00972843]
#  [0.00179472]]
# Gradient for bias: [-0.00395776]
# Epoch 89:
# Gradient for kernel: [[-0.00494933  0.00164222]
#  [-0.0049975   0.0016827 ]]
# Gradient for bias: [0.00604881 0.00066563]
# Gradient for kernel: [[0.00971836]
#  [0.00179651]]
# Gradient for bias: [-0.00396254]
# Epoch 90:
# Gradient for kernel: [[-0.00493722  0.00164118]
#  [-0.00498533  0.00168163]]
# Gradient for bias: [0.00605736 0.00066166]
# Gradient for kernel: [[0.00970837]
#  [0.0017983 ]]
# Gradient for bias: [-0.00396715]
# Epoch 91:
# Gradient for kernel: [[-0.00492532  0.00164013]
#  [-0.00497334  0.00168056]]
# Gradient for bias: [0.00606564 0.00065768]
# Gradient for kernel: [[0.00969849]
#  [0.00180009]]
# Gradient for bias: [-0.00397153]
# Epoch 92:
# Gradient for kernel: [[-0.0049136   0.00163909]
#  [-0.00496154  0.00167949]]
# Gradient for bias: [0.0060737  0.00065369]
# Gradient for kernel: [[0.00968872]
#  [0.00180189]]
# Gradient for bias: [-0.00397572]
# Epoch 93:
# Gradient for kernel: [[-0.00490204  0.00163803]
#  [-0.0049499   0.00167841]]
# Gradient for bias: [0.00608154 0.00064969]
# Gradient for kernel: [[0.00967904]
#  [0.00180369]]
# Gradient for bias: [-0.00397972]
# Epoch 94:
# Gradient for kernel: [[-0.00489066  0.00163698]
#  [-0.00493843  0.00167732]]
# Gradient for bias: [0.00608916 0.00064569]
# Gradient for kernel: [[0.00966946]
#  [0.00180549]]
# Gradient for bias: [-0.00398353]
# Epoch 95:
# Gradient for kernel: [[-0.00487944  0.00163592]
#  [-0.00492713  0.00167623]]
# Gradient for bias: [0.00609655 0.00064167]
# Gradient for kernel: [[0.00965999]
#  [0.00180729]]
# Gradient for bias: [-0.00398713]
# Epoch 96:
# Gradient for kernel: [[-0.00486834  0.00163485]
#  [-0.00491596  0.00167514]]
# Gradient for bias: [0.00610379 0.00063765]
# Gradient for kernel: [[0.00965059]
#  [0.00180909]]
# Gradient for bias: [-0.00399061]
# Epoch 97:
# Gradient for kernel: [[-0.00485744  0.00163378]
#  [-0.00490496  0.00167405]]
# Gradient for bias: [0.00611078 0.00063362]
# Gradient for kernel: [[0.0096413]
#  [0.0018109]]
# Gradient for bias: [-0.00399386]
# Epoch 98:
# Gradient for kernel: [[-0.00484668  0.00163271]
#  [-0.00489412  0.00167295]]
# Gradient for bias: [0.00611758 0.00062958]
# Gradient for kernel: [[0.00963209]
#  [0.00181271]]
# Gradient for bias: [-0.00399696]
# Epoch 99:
# Gradient for kernel: [[-0.00483609  0.00163164]
#  [-0.00488345  0.00167185]]
# Gradient for bias: [0.00612416 0.00062554]
# Gradient for kernel: [[0.00962298]
#  [0.00181452]]
# Gradient for bias: [-0.00399986]
# Epoch 100:
# Gradient for kernel: [[-0.00482565  0.00163056]
#  [-0.00487292  0.00167075]]
# Gradient for bias: [0.00613056 0.00062149]
# Gradient for kernel: [[0.00961396]
#  [0.00181633]]
# Gradient for bias: [-0.00400261]
# Epoch 101:
# Gradient for kernel: [[-0.00481532  0.00162948]
#  [-0.00486252  0.00166964]]
# Gradient for bias: [0.00613679 0.00061743]
# Gradient for kernel: [[0.00960501]
#  [0.00181814]]
# Gradient for bias: [-0.0040052]
# Epoch 102:
# Gradient for kernel: [[-0.00480515  0.00162839]
#  [-0.00485225  0.00166853]]
# Gradient for bias: [0.00614283 0.00061337]
# Gradient for kernel: [[0.00959615]
#  [0.00181995]]
# Gradient for bias: [-0.00400764]
# Epoch 103:
# Gradient for kernel: [[-0.00479512  0.00162731]
#  [-0.00484215  0.00166741]]
# Gradient for bias: [0.00614868 0.0006093 ]
# Gradient for kernel: [[0.00958738]
#  [0.00182177]]
# Gradient for bias: [-0.00400991]
# Epoch 104:
# Gradient for kernel: [[-0.00478521  0.00162622]
#  [-0.00483215  0.00166629]]
# Gradient for bias: [0.00615437 0.00060523]
# Gradient for kernel: [[0.00957867]
#  [0.00182358]]
# Gradient for bias: [-0.00401205]
# Epoch 105:
# Gradient for kernel: [[-0.00477544  0.00162513]
#  [-0.0048223   0.00166518]]
# Gradient for bias: [0.00615989 0.00060115]
# Gradient for kernel: [[0.00957004]
#  [0.0018254 ]]
# Gradient for bias: [-0.00401404]
# Epoch 106:
# Gradient for kernel: [[-0.0047658   0.00162403]
#  [-0.00481258  0.00166405]]
# Gradient for bias: [0.00616523 0.00059707]
# Gradient for kernel: [[0.0095615 ]
#  [0.00182721]]
# Gradient for bias: [-0.00401587]
# Epoch 107:
# Gradient for kernel: [[-0.00475627  0.00162293]
#  [-0.00480296  0.00166293]]
# Gradient for bias: [0.00617043 0.00059298]
# Gradient for kernel: [[0.00955301]
#  [0.00182903]]
# Gradient for bias: [-0.0040176]
# Epoch 108:
# Gradient for kernel: [[-0.00474689  0.00162183]
#  [-0.00479348  0.0016618 ]]
# Gradient for bias: [0.00617546 0.0005889 ]
# Gradient for kernel: [[0.00954462]
#  [0.00183085]]
# Gradient for bias: [-0.00401916]
# Epoch 109:
# Gradient for kernel: [[-0.00473759  0.00162073]
#  [-0.0047841   0.00166067]]
# Gradient for bias: [0.00618035 0.00058481]
# Gradient for kernel: [[0.00953627]
#  [0.00183267]]
# Gradient for bias: [-0.00402062]
# Epoch 110:
# Gradient for kernel: [[-0.00472846  0.00161963]
#  [-0.0047749   0.00165954]]
# Gradient for bias: [0.00618504 0.00058071]
# Gradient for kernel: [[0.00952802]
#  [0.00183448]]
# Gradient for bias: [-0.0040219]
# Epoch 111:
# Gradient for kernel: [[-0.00471943  0.00161852]
#  [-0.00476577  0.00165841]]
# Gradient for bias: [0.00618961 0.00057661]
# Gradient for kernel: [[0.00951983]
#  [0.0018363 ]]
# Gradient for bias: [-0.00402308]
# Epoch 112:
# Gradient for kernel: [[-0.00471054  0.00161741]
#  [-0.00475679  0.00165727]]
# Gradient for bias: [0.006194   0.00057251]
# Gradient for kernel: [[0.00951172]
#  [0.00183812]]
# Gradient for bias: [-0.00402411]
# Epoch 113:
# Gradient for kernel: [[-0.00470171  0.00161631]
#  [-0.00474789  0.00165613]]
# Gradient for bias: [0.0061983  0.00056841]
# Gradient for kernel: [[0.00950365]
#  [0.00183994]]
# Gradient for bias: [-0.00402506]
# Epoch 114:
# Gradient for kernel: [[-0.00469304  0.00161519]
#  [-0.00473914  0.00165499]]
# Gradient for bias: [0.00620239 0.0005643 ]
# Gradient for kernel: [[0.00949567]
#  [0.00184176]]
# Gradient for bias: [-0.00402584]
# Epoch 115:
# Gradient for kernel: [[-0.00468444  0.00161408]
#  [-0.00473045  0.00165385]]
# Gradient for bias: [0.00620638 0.00056019]
# Gradient for kernel: [[0.00948773]
#  [0.00184358]]
# Gradient for bias: [-0.00402654]
# Epoch 116:
# Gradient for kernel: [[-0.00467596  0.00161296]
#  [-0.00472188  0.00165271]]
# Gradient for bias: [0.00621025 0.00055608]
# Gradient for kernel: [[0.00947987]
#  [0.00184539]]
# Gradient for bias: [-0.00402713]
# Epoch 117:
# Gradient for kernel: [[-0.0046676   0.00161185]
#  [-0.00471344  0.00165157]]
# Gradient for bias: [0.00621395 0.00055197]
# Gradient for kernel: [[0.00947207]
#  [0.00184721]]
# Gradient for bias: [-0.00402758]
# Epoch 118:
# Gradient for kernel: [[-0.00465931  0.00161073]
#  [-0.00470507  0.00165042]]
# Gradient for bias: [0.00621755 0.00054786]
# Gradient for kernel: [[0.00946432]
#  [0.00184903]]
# Gradient for bias: [-0.00402794]
# Epoch 119:
# Gradient for kernel: [[-0.00465111  0.00160961]
#  [-0.00469678  0.00164927]]
# Gradient for bias: [0.00622105 0.00054375]
# Gradient for kernel: [[0.00945661]
#  [0.00185084]]
# Gradient for bias: [-0.00402823]
# Epoch 120:
# Gradient for kernel: [[-0.00464306  0.00160849]
#  [-0.00468865  0.00164812]]
# Gradient for bias: [0.00622435 0.00053963]
# Gradient for kernel: [[0.009449  ]
#  [0.00185266]]
# Gradient for bias: [-0.00402835]
# Epoch 121:
# Gradient for kernel: [[-0.00463509  0.00160737]
#  [-0.00468059  0.00164697]]
# Gradient for bias: [0.00622756 0.00053551]
# Gradient for kernel: [[0.00944142]
#  [0.00185448]]
# Gradient for bias: [-0.00402839]
# Epoch 122:
# Gradient for kernel: [[-0.0046272   0.00160625]
#  [-0.00467263  0.00164582]]
# Gradient for bias: [0.00623064 0.0005314 ]
# Gradient for kernel: [[0.0094339 ]
#  [0.00185629]]
# Gradient for bias: [-0.00402833]
# Epoch 123:
# Gradient for kernel: [[-0.0046194   0.00160512]
#  [-0.00466474  0.00164467]]
# Gradient for bias: [0.00623363 0.00052729]
# Gradient for kernel: [[0.00942644]
#  [0.0018581 ]]
# Gradient for bias: [-0.00402819]
# Epoch 124:
# Gradient for kernel: [[-0.0046117   0.001604  ]
#  [-0.00465695  0.00164352]]
# Gradient for bias: [0.0062365  0.00052317]
# Gradient for kernel: [[0.00941902]
#  [0.00185992]]
# Gradient for bias: [-0.00402795]
# Epoch 125:
# Gradient for kernel: [[-0.00460408  0.00160287]
#  [-0.00464926  0.00164236]]
# Gradient for bias: [0.00623924 0.00051905]
# Gradient for kernel: [[0.00941166]
#  [0.00186173]]
# Gradient for bias: [-0.00402761]
# Epoch 126:
# Gradient for kernel: [[-0.00459654  0.00160174]
#  [-0.00464163  0.00164121]]
# Gradient for bias: [0.0062419  0.00051494]
# Gradient for kernel: [[0.00940434]
#  [0.00186354]]
# Gradient for bias: [-0.0040272]
# Epoch 127:
# Gradient for kernel: [[-0.00458911  0.00160062]
#  [-0.00463412  0.00164005]]
# Gradient for bias: [0.00624442 0.00051083]
# Gradient for kernel: [[0.00939709]
#  [0.00186535]]
# Gradient for bias: [-0.00402667]
# Epoch 128:
# Gradient for kernel: [[-0.00458172  0.00159949]
#  [-0.00462663  0.0016389 ]]
# Gradient for bias: [0.00624689 0.00050671]
# Gradient for kernel: [[0.00938986]
#  [0.00186716]]
# Gradient for bias: [-0.00402611]
# Epoch 129:
# Gradient for kernel: [[-0.00457444  0.00159836]
#  [-0.00461927  0.00163774]]
# Gradient for bias: [0.00624922 0.0005026 ]
# Gradient for kernel: [[0.00938269]
#  [0.00186896]]
# Gradient for bias: [-0.00402543]
# Epoch 130:
# Gradient for kernel: [[-0.00456722  0.00159723]
#  [-0.00461198  0.00163659]]
# Gradient for bias: [0.00625146 0.00049849]
# Gradient for kernel: [[0.00937556]
#  [0.00187077]]
# Gradient for bias: [-0.00402468]
# Epoch 131:
# Gradient for kernel: [[-0.00456009  0.0015961 ]
#  [-0.00460477  0.00163543]]
# Gradient for bias: [0.00625359 0.00049438]
# Gradient for kernel: [[0.00936849]
#  [0.00187257]]
# Gradient for bias: [-0.00402384]
# Epoch 132:
# Gradient for kernel: [[-0.00455305  0.00159497]
#  [-0.00459766  0.00163427]]
# Gradient for bias: [0.00625561 0.00049027]
# Gradient for kernel: [[0.00936146]
#  [0.00187438]]
# Gradient for bias: [-0.00402291]
# Epoch 133:
# Gradient for kernel: [[-0.00454606  0.00159384]
#  [-0.00459058  0.00163311]]
# Gradient for bias: [0.00625756 0.00048617]
# Gradient for kernel: [[0.00935447]
#  [0.00187618]]
# Gradient for bias: [-0.00402194]
# Epoch 134:
# Gradient for kernel: [[-0.00453918  0.00159271]
#  [-0.00458363  0.00163195]]
# Gradient for bias: [0.00625939 0.00048206]
# Gradient for kernel: [[0.00934753]
#  [0.00187798]]
# Gradient for bias: [-0.00402085]
# Epoch 135:
# Gradient for kernel: [[-0.00453233  0.00159158]
#  [-0.00457668  0.00163079]]
# Gradient for bias: [0.00626118 0.00047796]
# Gradient for kernel: [[0.00934062]
#  [0.00187977]]
# Gradient for bias: [-0.00401975]
# Epoch 136:
# Gradient for kernel: [[-0.00452556  0.00159045]
#  [-0.00456984  0.00162963]]
# Gradient for bias: [0.00626286 0.00047386]
# Gradient for kernel: [[0.00933375]
#  [0.00188157]]
# Gradient for bias: [-0.00401855]
# Epoch 137:
# Gradient for kernel: [[-0.00451887  0.00158932]
#  [-0.00456305  0.00162847]]
# Gradient for bias: [0.00626446 0.00046977]
# Gradient for kernel: [[0.00932693]
#  [0.00188336]]
# Gradient for bias: [-0.00401728]
# Epoch 138:
# Gradient for kernel: [[-0.00451229  0.00158818]
#  [-0.00455639  0.00162731]]
# Gradient for bias: [0.00626591 0.00046567]
# Gradient for kernel: [[0.00932017]
#  [0.00188516]]
# Gradient for bias: [-0.0040159]
# Epoch 139:
# Gradient for kernel: [[-0.00450572  0.00158705]
#  [-0.00454973  0.00162615]]
# Gradient for bias: [0.00626735 0.00046158]
# Gradient for kernel: [[0.00931341]
#  [0.00188695]]
# Gradient for bias: [-0.00401452]
# Epoch 140:
# Gradient for kernel: [[-0.00449923  0.00158592]
#  [-0.00454316  0.00162499]]
# Gradient for bias: [0.00626868 0.00045748]
# Gradient for kernel: [[0.00930671]
#  [0.00188874]]
# Gradient for bias: [-0.00401304]
# Epoch 141:
# Gradient for kernel: [[-0.00449279  0.00158479]
#  [-0.00453665  0.00162383]]
# Gradient for bias: [0.00626995 0.0004534 ]
# Gradient for kernel: [[0.00930003]
#  [0.00189053]]
# Gradient for bias: [-0.00401152]
# Epoch 142:
# Gradient for kernel: [[-0.00448645  0.00158366]
#  [-0.00453023  0.00162267]]
# Gradient for bias: [0.00627111 0.00044931]
# Gradient for kernel: [[0.00929342]
#  [0.00189231]]
# Gradient for bias: [-0.00400991]
# Epoch 143:
# Gradient for kernel: [[-0.00448015  0.00158253]
#  [-0.00452384  0.00162151]]
# Gradient for bias: [0.00627221 0.00044523]
# Gradient for kernel: [[0.00928682]
#  [0.0018941 ]]
# Gradient for bias: [-0.00400825]
# Epoch 144:
# Gradient for kernel: [[-0.00447392  0.00158139]
#  [-0.00451753  0.00162035]]
# Gradient for bias: [0.00627323 0.00044115]
# Gradient for kernel: [[0.00928027]
#  [0.00189588]]
# Gradient for bias: [-0.00400654]
# Epoch 145:
# Gradient for kernel: [[-0.00446772  0.00158026]
#  [-0.00451125  0.00161919]]
# Gradient for bias: [0.00627421 0.00043707]
# Gradient for kernel: [[0.00927373]
#  [0.00189766]]
# Gradient for bias: [-0.00400479]
# Epoch 146:
# Gradient for kernel: [[-0.00446164  0.00157913]
#  [-0.00450508  0.00161803]]
# Gradient for bias: [0.00627505 0.000433  ]
# Gradient for kernel: [[0.00926726]
#  [0.00189944]]
# Gradient for bias: [-0.00400294]
# Epoch 147:
# Gradient for kernel: [[-0.00445556  0.001578  ]
#  [-0.00449891  0.00161687]]
# Gradient for bias: [0.00627588 0.00042894]
# Gradient for kernel: [[0.00926079]
#  [0.00190121]]
# Gradient for bias: [-0.00400108]
# Epoch 148:
# Gradient for kernel: [[-0.00444956  0.00157687]
#  [-0.00449283  0.00161571]]
# Gradient for bias: [0.00627662 0.00042487]
# Gradient for kernel: [[0.00925437]
#  [0.00190298]]
# Gradient for bias: [-0.00399915]
# Epoch 149:
# Gradient for kernel: [[-0.00444361  0.00157574]
#  [-0.0044868   0.00161456]]
# Gradient for bias: [0.00627729 0.00042081]
# Gradient for kernel: [[0.00924798]
#  [0.00190475]]
# Gradient for bias: [-0.00399717]
# Epoch 150:
# Gradient for kernel: [[-0.00443771  0.00157461]
#  [-0.00448083  0.0016134 ]]
# Gradient for bias: [0.00627789 0.00041675]
# Gradient for kernel: [[0.00924163]
#  [0.00190652]]
# Gradient for bias: [-0.00399512]
# Epoch 151:
# Gradient for kernel: [[-0.00443189  0.00157348]
#  [-0.00447492  0.00161224]]
# Gradient for bias: [0.00627842 0.0004127 ]
# Gradient for kernel: [[0.0092353 ]
#  [0.00190829]]
# Gradient for bias: [-0.00399304]
# Epoch 152:
# Gradient for kernel: [[-0.00442609  0.00157235]
#  [-0.00446903  0.00161108]]
# Gradient for bias: [0.00627892 0.00040865]
# Gradient for kernel: [[0.009229  ]
#  [0.00191005]]
# Gradient for bias: [-0.00399092]
# Epoch 153:
# Gradient for kernel: [[-0.00442037  0.00157122]
#  [-0.00446324  0.00160992]]
# Gradient for bias: [0.00627931 0.00040461]
# Gradient for kernel: [[0.00922274]
#  [0.00191181]]
# Gradient for bias: [-0.00398873]
# Epoch 154:
# Gradient for kernel: [[-0.00441468  0.00157009]
#  [-0.00445747  0.00160877]]
# Gradient for bias: [0.00627967 0.00040057]
# Gradient for kernel: [[0.00921651]
#  [0.00191357]]
# Gradient for bias: [-0.00398651]
# Epoch 155:
# Gradient for kernel: [[-0.00440903  0.00156896]
#  [-0.00445173  0.00160761]]
# Gradient for bias: [0.00627997 0.00039653]
# Gradient for kernel: [[0.00921029]
#  [0.00191533]]
# Gradient for bias: [-0.00398425]
# Epoch 156:
# Gradient for kernel: [[-0.00440344  0.00156784]
#  [-0.00444607  0.00160646]]
# Gradient for bias: [0.00628021 0.0003925 ]
# Gradient for kernel: [[0.0092041 ]
#  [0.00191708]]
# Gradient for bias: [-0.00398196]
# Epoch 157:
# Gradient for kernel: [[-0.0043979   0.00156671]
#  [-0.00444043  0.0016053 ]]
# Gradient for bias: [0.00628041 0.00038848]
# Gradient for kernel: [[0.00919794]
#  [0.00191883]]
# Gradient for bias: [-0.00397963]
# Epoch 158:
# Gradient for kernel: [[-0.00439238  0.00156559]
#  [-0.00443484  0.00160415]]
# Gradient for bias: [0.00628055 0.00038445]
# Gradient for kernel: [[0.0091918 ]
#  [0.00192058]]
# Gradient for bias: [-0.00397725]
# Epoch 159:
# Gradient for kernel: [[-0.00438693  0.00156446]
#  [-0.00442931  0.001603  ]]
# Gradient for bias: [0.00628063 0.00038044]
# Gradient for kernel: [[0.0091857 ]
#  [0.00192233]]
# Gradient for bias: [-0.00397484]
# Epoch 160:
# Gradient for kernel: [[-0.0043815   0.00156334]
#  [-0.00442381  0.00160185]]
# Gradient for bias: [0.00628067 0.00037643]
# Gradient for kernel: [[0.00917961]
#  [0.00192407]]
# Gradient for bias: [-0.00397239]
# Epoch 161:
# Gradient for kernel: [[-0.00437614  0.00156222]
#  [-0.00441836  0.00160069]]
# Gradient for bias: [0.00628065 0.00037242]
# Gradient for kernel: [[0.00917356]
#  [0.00192581]]
# Gradient for bias: [-0.0039699]
# Epoch 162:
# Gradient for kernel: [[-0.00437083  0.00156109]
#  [-0.00441297  0.00159954]]
# Gradient for bias: [0.00628055 0.00036842]
# Gradient for kernel: [[0.00916754]
#  [0.00192755]]
# Gradient for bias: [-0.00396736]
# Epoch 163:
# Gradient for kernel: [[-0.00436554  0.00155997]
#  [-0.0044076   0.00159839]]
# Gradient for bias: [0.00628043 0.00036442]
# Gradient for kernel: [[0.00916153]
#  [0.00192929]]
# Gradient for bias: [-0.0039648]
# Epoch 164:
# Gradient for kernel: [[-0.00436032  0.00155885]
#  [-0.0044023   0.00159725]]
# Gradient for bias: [0.00628024 0.00036043]
# Gradient for kernel: [[0.00915556]
#  [0.00193102]]
# Gradient for bias: [-0.00396218]
# Epoch 165:
# Gradient for kernel: [[-0.00435511  0.00155773]
#  [-0.00439701  0.0015961 ]]
# Gradient for bias: [0.00628003 0.00035644]
# Gradient for kernel: [[0.0091496 ]
#  [0.00193275]]
# Gradient for bias: [-0.00395956]
# Epoch 166:
# Gradient for kernel: [[-0.00434997  0.00155661]
#  [-0.00439178  0.00159495]]
# Gradient for bias: [0.00627974 0.00035246]
# Gradient for kernel: [[0.00914368]
#  [0.00193447]]
# Gradient for bias: [-0.00395687]
# Epoch 167:
# Gradient for kernel: [[-0.00434483  0.00155549]
#  [-0.00438657  0.0015938 ]]
# Gradient for bias: [0.00627943 0.00034849]
# Gradient for kernel: [[0.00913776]
#  [0.0019362 ]]
# Gradient for bias: [-0.00395419]
# Epoch 168:
# Gradient for kernel: [[-0.00433977  0.00155437]
#  [-0.00438143  0.00159266]]
# Gradient for bias: [0.00627905 0.00034451]
# Gradient for kernel: [[0.00913188]
#  [0.00193792]]
# Gradient for bias: [-0.00395144]
# Epoch 169:
# Gradient for kernel: [[-0.00433476  0.00155326]
#  [-0.00437633  0.00159151]]
# Gradient for bias: [0.00627861 0.00034055]
# Gradient for kernel: [[0.00912603]
#  [0.00193964]]
# Gradient for bias: [-0.00394866]
# Epoch 170:
# Gradient for kernel: [[-0.00432971  0.00155214]
#  [-0.0043712   0.00159037]]
# Gradient for bias: [0.00627821 0.00033659]
# Gradient for kernel: [[0.00912016]
#  [0.00194135]]
# Gradient for bias: [-0.00394592]
# Epoch 171:
# Gradient for kernel: [[-0.00432476  0.00155103]
#  [-0.00436618  0.00158923]]
# Gradient for bias: [0.0062777  0.00033264]
# Gradient for kernel: [[0.00911435]
#  [0.00194307]]
# Gradient for bias: [-0.00394308]
# Epoch 172:
# Gradient for kernel: [[-0.00431983  0.00154991]
#  [-0.00436118  0.00158809]]
# Gradient for bias: [0.00627716 0.00032869]
# Gradient for kernel: [[0.00910855]
#  [0.00194478]]
# Gradient for bias: [-0.00394023]
# Epoch 173:
# Gradient for kernel: [[-0.00431493  0.0015488 ]
#  [-0.00435619  0.00158695]]
# Gradient for bias: [0.00627658 0.00032474]
# Gradient for kernel: [[0.00910276]
#  [0.00194648]]
# Gradient for bias: [-0.00393736]
# Epoch 174:
# Gradient for kernel: [[-0.00431007  0.00154769]
#  [-0.00435125  0.00158581]]
# Gradient for bias: [0.00627597 0.00032081]
# Gradient for kernel: [[0.009097  ]
#  [0.00194819]]
# Gradient for bias: [-0.00393446]
# Epoch 175:
# Gradient for kernel: [[-0.00430525  0.00154658]
#  [-0.00434636  0.00158467]]
# Gradient for bias: [0.0062753  0.00031688]
# Gradient for kernel: [[0.00909127]
#  [0.00194989]]
# Gradient for bias: [-0.00393153]
# Epoch 176:
# Gradient for kernel: [[-0.00430045  0.00154547]
#  [-0.00434148  0.00158353]]
# Gradient for bias: [0.00627462 0.00031296]
# Gradient for kernel: [[0.00908554]
#  [0.00195158]]
# Gradient for bias: [-0.0039286]
# Epoch 177:
# Gradient for kernel: [[-0.00429569  0.00154436]
#  [-0.00433665  0.00158239]]
# Gradient for bias: [0.00627389 0.00030903]
# Gradient for kernel: [[0.00907984]
#  [0.00195328]]
# Gradient for bias: [-0.00392562]
# Epoch 178:
# Gradient for kernel: [[-0.00429094  0.00154325]
#  [-0.00433182  0.00158126]]
# Gradient for bias: [0.00627314 0.00030512]
# Gradient for kernel: [[0.00907415]
#  [0.00195497]]
# Gradient for bias: [-0.00392264]
# Epoch 179:
# Gradient for kernel: [[-0.00428625  0.00154215]
#  [-0.00432706  0.00158013]]
# Gradient for bias: [0.00627234 0.00030122]
# Gradient for kernel: [[0.00906849]
#  [0.00195666]]
# Gradient for bias: [-0.00391962]
# Epoch 180:
# Gradient for kernel: [[-0.0042816   0.00154104]
#  [-0.00432231  0.00157899]]
# Gradient for bias: [0.00627149 0.00029732]
# Gradient for kernel: [[0.00906284]
#  [0.00195834]]
# Gradient for bias: [-0.00391658]
# Epoch 181:
# Gradient for kernel: [[-0.00427695  0.00153994]
#  [-0.00431759  0.00157786]]
# Gradient for bias: [0.00627064 0.00029342]
# Gradient for kernel: [[0.0090572 ]
#  [0.00196002]]
# Gradient for bias: [-0.00391353]
# Epoch 182:
# Gradient for kernel: [[-0.00427234  0.00153884]
#  [-0.00431291  0.00157673]]
# Gradient for bias: [0.00626973 0.00028953]
# Gradient for kernel: [[0.00905159]
#  [0.0019617 ]]
# Gradient for bias: [-0.00391044]
# Epoch 183:
# Gradient for kernel: [[-0.00426777  0.00153773]
#  [-0.00430826  0.0015756 ]]
# Gradient for bias: [0.00626879 0.00028565]
# Gradient for kernel: [[0.00904599]
#  [0.00196338]]
# Gradient for bias: [-0.00390734]
# Epoch 184:
# Gradient for kernel: [[-0.00426323  0.00153664]
#  [-0.00430364  0.00157448]]
# Gradient for bias: [0.00626781 0.00028178]
# Gradient for kernel: [[0.00904042]
#  [0.00196505]]
# Gradient for bias: [-0.00390421]
# Epoch 185:
# Gradient for kernel: [[-0.00425873  0.00153554]
#  [-0.00429906  0.00157335]]
# Gradient for bias: [0.0062668  0.00027791]
# Gradient for kernel: [[0.00903486]
#  [0.00196672]]
# Gradient for bias: [-0.00390106]
# Epoch 186:
# Gradient for kernel: [[-0.00425422  0.00153444]
#  [-0.00429447  0.00157223]]
# Gradient for bias: [0.00626579 0.00027405]
# Gradient for kernel: [[0.0090293 ]
#  [0.00196838]]
# Gradient for bias: [-0.00389793]
# Epoch 187:
# Gradient for kernel: [[-0.00424978  0.00153334]
#  [-0.00428996  0.0015711 ]]
# Gradient for bias: [0.0062647  0.00027019]
# Gradient for kernel: [[0.00902379]
#  [0.00197005]]
# Gradient for bias: [-0.00389473]
# Epoch 188:
# Gradient for kernel: [[-0.00424536  0.00153225]
#  [-0.00428546  0.00156998]]
# Gradient for bias: [0.00626359 0.00026634]
# Gradient for kernel: [[0.00901828]
#  [0.00197171]]
# Gradient for bias: [-0.00389152]
# Epoch 189:
# Gradient for kernel: [[-0.00424095  0.00153115]
#  [-0.00428097  0.00156886]]
# Gradient for bias: [0.00626247 0.0002625 ]
# Gradient for kernel: [[0.00901278]
#  [0.00197337]]
# Gradient for bias: [-0.00388831]
# Epoch 190:
# Gradient for kernel: [[-0.00423658  0.00153006]
#  [-0.00427653  0.00156774]]
# Gradient for bias: [0.00626131 0.00025866]
# Gradient for kernel: [[0.00900731]
#  [0.00197502]]
# Gradient for bias: [-0.00388508]
# Epoch 191:
# Gradient for kernel: [[-0.00423224  0.00152897]
#  [-0.0042721   0.00156662]]
# Gradient for bias: [0.00626012 0.00025483]
# Gradient for kernel: [[0.00900185]
#  [0.00197667]]
# Gradient for bias: [-0.00388183]
# Epoch 192:
# Gradient for kernel: [[-0.00422791  0.00152788]
#  [-0.00426769  0.0015655 ]]
# Gradient for bias: [0.00625892 0.000251  ]
# Gradient for kernel: [[0.00899639]
#  [0.00197832]]
# Gradient for bias: [-0.00387858]
# Epoch 193:
# Gradient for kernel: [[-0.00422359  0.00152679]
#  [-0.00426329  0.00156439]]
# Gradient for bias: [0.00625771 0.00024719]
# Gradient for kernel: [[0.00899094]
#  [0.00197996]]
# Gradient for bias: [-0.00387533]
# Epoch 194:
# Gradient for kernel: [[-0.00421932  0.0015257 ]
#  [-0.00425895  0.00156327]]
# Gradient for bias: [0.00625644 0.00024338]
# Gradient for kernel: [[0.00898552]
#  [0.0019816 ]]
# Gradient for bias: [-0.00387203]
# Epoch 195:
# Gradient for kernel: [[-0.00421507  0.00152462]
#  [-0.00425463  0.00156216]]
# Gradient for bias: [0.00625514 0.00023958]
# Gradient for kernel: [[0.00898011]
#  [0.00198323]]
# Gradient for bias: [-0.00386873]
# Epoch 196:
# Gradient for kernel: [[-0.00421084  0.00152353]
#  [-0.00425033  0.00156105]]
# Gradient for bias: [0.00625383 0.00023578]
# Gradient for kernel: [[0.00897471]
#  [0.00198487]]
# Gradient for bias: [-0.00386542]
# Epoch 197:
# Gradient for kernel: [[-0.00420663  0.00152245]
#  [-0.00424604  0.00155994]]
# Gradient for bias: [0.0062525  0.00023199]
# Gradient for kernel: [[0.00896933]
#  [0.0019865 ]]
# Gradient for bias: [-0.0038621]
# Epoch 198:
# Gradient for kernel: [[-0.00420245  0.00152137]
#  [-0.00424178  0.00155883]]
# Gradient for bias: [0.00625114 0.00022821]
# Gradient for kernel: [[0.00896396]
#  [0.00198812]]
# Gradient for bias: [-0.00385876]
# Epoch 199:
# Gradient for kernel: [[-0.00419829  0.00152029]
#  [-0.00423754  0.00155772]]
# Gradient for bias: [0.00624976 0.00022444]
# Gradient for kernel: [[0.0089586 ]
#  [0.00198974]]
# Gradient for bias: [-0.00385542]
# Epoch 200:
# Gradient for kernel: [[-0.00419415  0.00151921]
#  [-0.00423334  0.00155662]]
# Gradient for bias: [0.00624835 0.00022067]
# Gradient for kernel: [[0.00895326]
#  [0.00199136]]
# Gradient for bias: [-0.00385205]
# Epoch 201:
# Gradient for kernel: [[-0.00419004  0.00151813]
#  [-0.00422915  0.00155551]]
# Gradient for bias: [0.00624692 0.0002169 ]
# Gradient for kernel: [[0.00894793]
#  [0.00199298]]
# Gradient for bias: [-0.00384868]
# Epoch 202:
# Gradient for kernel: [[-0.00418593  0.00151706]
#  [-0.00422496  0.00155441]]
# Gradient for bias: [0.0062455  0.00021315]
# Gradient for kernel: [[0.0089426 ]
#  [0.00199459]]
# Gradient for bias: [-0.00384533]
# Epoch 203:
# Gradient for kernel: [[-0.00418188  0.00151598]
#  [-0.00422083  0.00155331]]
# Gradient for bias: [0.006244  0.0002094]
# Gradient for kernel: [[0.00893731]
#  [0.0019962 ]]
# Gradient for bias: [-0.0038419]
# Epoch 204:
# Gradient for kernel: [[-0.00417782  0.00151491]
#  [-0.0042167   0.00155221]]
# Gradient for bias: [0.00624251 0.00020566]
# Gradient for kernel: [[0.00893201]
#  [0.0019978 ]]
# Gradient for bias: [-0.00383852]
# Epoch 205:
# Gradient for kernel: [[-0.0041738   0.00151384]
#  [-0.0042126   0.00155111]]
# Gradient for bias: [0.00624098 0.00020192]
# Gradient for kernel: [[0.00892673]
#  [0.00199941]]
# Gradient for bias: [-0.00383509]
# Epoch 206:
# Gradient for kernel: [[-0.00416977  0.00151277]
#  [-0.00420849  0.00155001]]
# Gradient for bias: [0.00623947 0.0001982 ]
# Gradient for kernel: [[0.00892145]
#  [0.00200101]]
# Gradient for bias: [-0.00383169]
# Epoch 207:
# Gradient for kernel: [[-0.00416582  0.0015117 ]
#  [-0.00420447  0.00154892]]
# Gradient for bias: [0.00623787 0.00019448]
# Gradient for kernel: [[0.00891622]
#  [0.0020026 ]]
# Gradient for bias: [-0.00382822]
# Epoch 208:
# Gradient for kernel: [[-0.00416183  0.00151063]
#  [-0.00420041  0.00154782]]
# Gradient for bias: [0.00623631 0.00019076]
# Gradient for kernel: [[0.00891096]
#  [0.0020042 ]]
# Gradient for bias: [-0.0038248]
# Epoch 209:
# Gradient for kernel: [[-0.00415786  0.00150956]
#  [-0.00419637  0.00154673]]
# Gradient for bias: [0.00623474 0.00018706]
# Gradient for kernel: [[0.00890571]
#  [0.00200578]]
# Gradient for bias: [-0.00382137]
# Epoch 210:
# Gradient for kernel: [[-0.00415394  0.0015085 ]
#  [-0.00419237  0.00154564]]
# Gradient for bias: [0.00623312 0.00018336]
# Gradient for kernel: [[0.0089005 ]
#  [0.00200736]]
# Gradient for bias: [-0.00381791]
# Epoch 211:
# Gradient for kernel: [[-0.00415001  0.00150744]
#  [-0.00418837  0.00154455]]
# Gradient for bias: [0.0062315  0.00017968]
# Gradient for kernel: [[0.00889527]
#  [0.00200894]]
# Gradient for bias: [-0.00381448]
# Epoch 212:
# Gradient for kernel: [[-0.00414612  0.00150638]
#  [-0.00418441  0.00154346]]
# Gradient for bias: [0.00622984 0.00017598]
# Gradient for kernel: [[0.00889007]
#  [0.00201053]]
# Gradient for bias: [-0.00381099]
# Epoch 213:
# Gradient for kernel: [[-0.00414225  0.00150532]
#  [-0.00418046  0.00154238]]
# Gradient for bias: [0.00622817 0.00017231]
# Gradient for kernel: [[0.00888489]
#  [0.0020121 ]]
# Gradient for bias: [-0.00380752]
# Epoch 214:
# Gradient for kernel: [[-0.00413842  0.00150426]
#  [-0.00417656  0.00154129]]
# Gradient for bias: [0.00622646 0.00016864]
# Gradient for kernel: [[0.00887972]
#  [0.00201367]]
# Gradient for bias: [-0.00380402]
# Epoch 215:
# Gradient for kernel: [[-0.00413458  0.0015032 ]
#  [-0.00417265  0.00154021]]
# Gradient for bias: [0.00622475 0.00016497]
# Gradient for kernel: [[0.00887455]
#  [0.00201524]]
# Gradient for bias: [-0.00380051]
# Epoch 216:
# Gradient for kernel: [[-0.00413077  0.00150214]
#  [-0.00416876  0.00153913]]
# Gradient for bias: [0.00622302 0.00016132]
# Gradient for kernel: [[0.0088694]
#  [0.0020168]]
# Gradient for bias: [-0.00379702]
# Epoch 217:
# Gradient for kernel: [[-0.00412695  0.00150109]
#  [-0.00416486  0.00153805]]
# Gradient for bias: [0.0062213  0.00015767]
# Gradient for kernel: [[0.00886424]
#  [0.00201836]]
# Gradient for bias: [-0.00379353]
# Epoch 218:
# Gradient for kernel: [[-0.00412315  0.00150004]
#  [-0.004161    0.00153697]]
# Gradient for bias: [0.00621956 0.00015404]
# Gradient for kernel: [[0.00885909]
#  [0.00201992]]
# Gradient for bias: [-0.00379004]
# Epoch 219:
# Gradient for kernel: [[-0.00411939  0.00149899]
#  [-0.00415716  0.00153589]]
# Gradient for bias: [0.00621778 0.0001504 ]
# Gradient for kernel: [[0.00885397]
#  [0.00202147]]
# Gradient for bias: [-0.00378651]
# Epoch 220:
# Gradient for kernel: [[-0.00411561  0.00149794]
#  [-0.00415331  0.00153481]]
# Gradient for bias: [0.00621602 0.00014677]
# Gradient for kernel: [[0.00884883]
#  [0.00202302]]
# Gradient for bias: [-0.00378303]
# Epoch 221:
# Gradient for kernel: [[-0.00411189  0.00149689]
#  [-0.0041495   0.00153374]]
# Gradient for bias: [0.00621421 0.00014315]
# Gradient for kernel: [[0.00884373]
#  [0.00202457]]
# Gradient for bias: [-0.00377949]
# Epoch 222:
# Gradient for kernel: [[-0.00410816  0.00149585]
#  [-0.00414572  0.00153267]]
# Gradient for bias: [0.0062124  0.00013954]
# Gradient for kernel: [[0.00883862]
#  [0.00202611]]
# Gradient for bias: [-0.00377598]
# Epoch 223:
# Gradient for kernel: [[-0.00410445  0.0014948 ]
#  [-0.00414192  0.0015316 ]]
# Gradient for bias: [0.00621058 0.00013594]
# Gradient for kernel: [[0.00883352]
#  [0.00202765]]
# Gradient for bias: [-0.00377247]
# Epoch 224:
# Gradient for kernel: [[-0.00410078  0.00149376]
#  [-0.00413819  0.00153053]]
# Gradient for bias: [0.00620872 0.00013234]
# Gradient for kernel: [[0.00882845]
#  [0.00202918]]
# Gradient for bias: [-0.00376891]
# Epoch 225:
# Gradient for kernel: [[-0.00409709  0.00149272]
#  [-0.00413443  0.00152946]]
# Gradient for bias: [0.00620688 0.00012875]
# Gradient for kernel: [[0.00882337]
#  [0.00203071]]
# Gradient for bias: [-0.00376539]
# ...
# Epoch 9927:
# Gradient for kernel: [[-0.00044386  0.00024866]
#  [-0.00044401  0.00025278]]
# Gradient for bias: [ 0.00072317 -0.00026565]
# Gradient for kernel: [[0.00104365]
#  [0.00082051]]
# Gradient for bias: [-0.00045902]
# Epoch 9928:
# Gradient for kernel: [[-0.00044381  0.00024863]
#  [-0.00044397  0.00025275]]
# Gradient for bias: [ 0.00072309 -0.00026562]
# Gradient for kernel: [[0.00104355]
#  [0.00082044]]
# Gradient for bias: [-0.00045897]
# Epoch 9929:
# Gradient for kernel: [[-0.00044377  0.00024861]
#  [-0.00044392  0.00025273]]
# Gradient for bias: [ 0.00072301 -0.00026559]
# Gradient for kernel: [[0.00104345]
#  [0.00082038]]
# Gradient for bias: [-0.00045893]
# Epoch 9930:
# Gradient for kernel: [[-0.00044372  0.00024859]
#  [-0.00044388  0.00025271]]
# Gradient for bias: [ 0.00072293 -0.00026555]
# Gradient for kernel: [[0.00104334]
#  [0.00082031]]
# Gradient for bias: [-0.00045889]
# Epoch 9931:
# Gradient for kernel: [[-0.00044368  0.00024857]
#  [-0.00044383  0.00025269]]
# Gradient for bias: [ 0.00072286 -0.00026553]
# Gradient for kernel: [[0.00104324]
#  [0.00082024]]
# Gradient for bias: [-0.00045884]
# Epoch 9932:
# Gradient for kernel: [[-0.00044363  0.00024855]
#  [-0.00044379  0.00025267]]
# Gradient for bias: [ 0.00072278 -0.0002655 ]
# Gradient for kernel: [[0.00104314]
#  [0.00082017]]
# Gradient for bias: [-0.0004588]
# Epoch 9933:
# Gradient for kernel: [[-0.00044359  0.00024853]
#  [-0.00044374  0.00025265]]
# Gradient for bias: [ 0.0007227  -0.00026547]
# Gradient for kernel: [[0.00104303]
#  [0.00082011]]
# Gradient for bias: [-0.00045876]
# Epoch 9934:
# Gradient for kernel: [[-0.00044354  0.00024851]
#  [-0.0004437   0.00025262]]
# Gradient for bias: [ 0.00072262 -0.00026543]
# Gradient for kernel: [[0.00104293]
#  [0.00082004]]
# Gradient for bias: [-0.00045872]
# Epoch 9935:
# Gradient for kernel: [[-0.0004435   0.00024848]
#  [-0.00044365  0.0002526 ]]
# Gradient for bias: [ 0.00072254 -0.00026541]
# Gradient for kernel: [[0.00104282]
#  [0.00081997]]
# Gradient for bias: [-0.00045867]
# Epoch 9936:
# Gradient for kernel: [[-0.00044345  0.00024846]
#  [-0.00044361  0.00025258]]
# Gradient for bias: [ 0.00072247 -0.00026537]
# Gradient for kernel: [[0.00104272]
#  [0.00081991]]
# Gradient for bias: [-0.00045863]
# Epoch 9937:
# Gradient for kernel: [[-0.00044341  0.00024844]
#  [-0.00044356  0.00025256]]
# Gradient for bias: [ 0.00072239 -0.00026534]
# Gradient for kernel: [[0.00104262]
#  [0.00081984]]
# Gradient for bias: [-0.00045859]
# Epoch 9938:
# Gradient for kernel: [[-0.00044336  0.00024842]
#  [-0.00044351  0.00025254]]
# Gradient for bias: [ 0.00072231 -0.00026531]
# Gradient for kernel: [[0.00104251]
#  [0.00081977]]
# Gradient for bias: [-0.00045855]
# Epoch 9939:
# Gradient for kernel: [[-0.00044331  0.0002484 ]
#  [-0.00044347  0.00025251]]
# Gradient for bias: [ 0.00072224 -0.00026528]
# Gradient for kernel: [[0.00104241]
#  [0.0008197 ]]
# Gradient for bias: [-0.00045851]
# Epoch 9940:
# Gradient for kernel: [[-0.00044326  0.00024838]
#  [-0.00044342  0.00025249]]
# Gradient for bias: [ 0.00072216 -0.00026525]
# Gradient for kernel: [[0.0010423 ]
#  [0.00081964]]
# Gradient for bias: [-0.00045847]
# Epoch 9941:
# Gradient for kernel: [[-0.00044321  0.00024836]
#  [-0.00044337  0.00025247]]
# Gradient for bias: [ 0.00072209 -0.00026522]
# Gradient for kernel: [[0.0010422 ]
#  [0.00081957]]
# Gradient for bias: [-0.00045843]
# Epoch 9942:
# Gradient for kernel: [[-0.00044317  0.00024834]
#  [-0.00044332  0.00025245]]
# Gradient for bias: [ 0.00072201 -0.00026519]
# Gradient for kernel: [[0.00104209]
#  [0.0008195 ]]
# Gradient for bias: [-0.00045839]
# Epoch 9943:
# Gradient for kernel: [[-0.00044312  0.00024831]
#  [-0.00044327  0.00025243]]
# Gradient for bias: [ 0.00072194 -0.00026516]
# Gradient for kernel: [[0.00104199]
#  [0.00081944]]
# Gradient for bias: [-0.00045835]
# Epoch 9944:
# Gradient for kernel: [[-0.00044307  0.00024829]
#  [-0.00044322  0.00025241]]
# Gradient for bias: [ 0.00072187 -0.00026513]
# Gradient for kernel: [[0.00104188]
#  [0.00081937]]
# Gradient for bias: [-0.00045831]
# Epoch 9945:
# Gradient for kernel: [[-0.00044302  0.00024827]
#  [-0.00044318  0.00025238]]
# Gradient for bias: [ 0.00072179 -0.0002651 ]
# Gradient for kernel: [[0.00104178]
#  [0.0008193 ]]
# Gradient for bias: [-0.00045827]
# Epoch 9946:
# Gradient for kernel: [[-0.00044297  0.00024825]
#  [-0.00044313  0.00025236]]
# Gradient for bias: [ 0.00072172 -0.00026507]
# Gradient for kernel: [[0.00104167]
#  [0.00081923]]
# Gradient for bias: [-0.00045824]
# Epoch 9947:
# Gradient for kernel: [[-0.00044292  0.00024823]
#  [-0.00044308  0.00025234]]
# Gradient for bias: [ 0.00072164 -0.00026504]
# Gradient for kernel: [[0.00104157]
#  [0.00081917]]
# Gradient for bias: [-0.00045819]
# Epoch 9948:
# Gradient for kernel: [[-0.00044288  0.00024821]
#  [-0.00044303  0.00025232]]
# Gradient for bias: [ 0.00072157 -0.00026501]
# Gradient for kernel: [[0.00104147]
#  [0.0008191 ]]
# Gradient for bias: [-0.00045815]
# Epoch 9949:
# Gradient for kernel: [[-0.00044283  0.00024819]
#  [-0.00044299  0.0002523 ]]
# Gradient for bias: [ 0.00072149 -0.00026498]
# Gradient for kernel: [[0.00104136]
#  [0.00081903]]
# Gradient for bias: [-0.00045811]
# Epoch 9950:
# Gradient for kernel: [[-0.00044278  0.00024817]
#  [-0.00044294  0.00025228]]
# Gradient for bias: [ 0.00072142 -0.00026495]
# Gradient for kernel: [[0.00104126]
#  [0.00081897]]
# Gradient for bias: [-0.00045807]
# Epoch 9951:
# Gradient for kernel: [[-0.00044274  0.00024814]
#  [-0.00044289  0.00025225]]
# Gradient for bias: [ 0.00072134 -0.00026492]
# Gradient for kernel: [[0.00104115]
#  [0.0008189 ]]
# Gradient for bias: [-0.00045803]
# Epoch 9952:
# Gradient for kernel: [[-0.00044269  0.00024812]
#  [-0.00044285  0.00025223]]
# Gradient for bias: [ 0.00072126 -0.00026489]
# Gradient for kernel: [[0.00104105]
#  [0.00081883]]
# Gradient for bias: [-0.00045799]
# Epoch 9953:
# Gradient for kernel: [[-0.00044264  0.0002481 ]
#  [-0.0004428   0.00025221]]
# Gradient for bias: [ 0.00072119 -0.00026486]
# Gradient for kernel: [[0.00104095]
#  [0.00081877]]
# Gradient for bias: [-0.00045795]
# Epoch 9954:
# Gradient for kernel: [[-0.0004426   0.00024808]
#  [-0.00044275  0.00025219]]
# Gradient for bias: [ 0.00072111 -0.00026483]
# Gradient for kernel: [[0.00104084]
#  [0.0008187 ]]
# Gradient for bias: [-0.00045791]
# Epoch 9955:
# Gradient for kernel: [[-0.00044255  0.00024806]
#  [-0.00044271  0.00025217]]
# Gradient for bias: [ 0.00072104 -0.0002648 ]
# Gradient for kernel: [[0.00104074]
#  [0.00081863]]
# Gradient for bias: [-0.00045787]
# Epoch 9956:
# Gradient for kernel: [[-0.0004425   0.00024804]
#  [-0.00044266  0.00025215]]
# Gradient for bias: [ 0.00072096 -0.00026477]
# Gradient for kernel: [[0.00104063]
#  [0.00081856]]
# Gradient for bias: [-0.00045783]
# Epoch 9957:
# Gradient for kernel: [[-0.00044246  0.00024802]
#  [-0.00044261  0.00025212]]
# Gradient for bias: [ 0.00072089 -0.00026474]
# Gradient for kernel: [[0.00104053]
#  [0.0008185 ]]
# Gradient for bias: [-0.00045779]
# Epoch 9958:
# Gradient for kernel: [[-0.00044241  0.000248  ]
#  [-0.00044256  0.0002521 ]]
# Gradient for bias: [ 0.00072081 -0.00026471]
# Gradient for kernel: [[0.00104043]
#  [0.00081843]]
# Gradient for bias: [-0.00045775]
# Epoch 9959:
# Gradient for kernel: [[-0.00044236  0.00024798]
#  [-0.00044252  0.00025208]]
# Gradient for bias: [ 0.00072074 -0.00026467]
# Gradient for kernel: [[0.00104032]
#  [0.00081836]]
# Gradient for bias: [-0.00045771]
# Epoch 9960:
# Gradient for kernel: [[-0.00044231  0.00024795]
#  [-0.00044247  0.00025206]]
# Gradient for bias: [ 0.00072066 -0.00026465]
# Gradient for kernel: [[0.00104022]
#  [0.0008183 ]]
# Gradient for bias: [-0.00045767]
# Epoch 9961:
# Gradient for kernel: [[-0.00044226  0.00024793]
#  [-0.00044242  0.00025204]]
# Gradient for bias: [ 0.00072059 -0.00026461]
# Gradient for kernel: [[0.00104011]
#  [0.00081823]]
# Gradient for bias: [-0.00045763]
# Epoch 9962:
# Gradient for kernel: [[-0.00044222  0.00024791]
#  [-0.00044238  0.00025202]]
# Gradient for bias: [ 0.00072051 -0.00026458]
# Gradient for kernel: [[0.00104001]
#  [0.00081816]]
# Gradient for bias: [-0.00045759]
# Epoch 9963:
# Gradient for kernel: [[-0.00044217  0.00024789]
#  [-0.00044233  0.00025199]]
# Gradient for bias: [ 0.00072043 -0.00026455]
# Gradient for kernel: [[0.00103991]
#  [0.0008181 ]]
# Gradient for bias: [-0.00045755]
# Epoch 9964:
# Gradient for kernel: [[-0.00044213  0.00024787]
#  [-0.00044228  0.00025197]]
# Gradient for bias: [ 0.00072036 -0.00026453]
# Gradient for kernel: [[0.0010398 ]
#  [0.00081803]]
# Gradient for bias: [-0.0004575]
# Epoch 9965:
# Gradient for kernel: [[-0.00044208  0.00024785]
#  [-0.00044224  0.00025195]]
# Gradient for bias: [ 0.00072028 -0.00026449]
# Gradient for kernel: [[0.0010397 ]
#  [0.00081796]]
# Gradient for bias: [-0.00045746]
# Epoch 9966:
# Gradient for kernel: [[-0.00044204  0.00024783]
#  [-0.00044219  0.00025193]]
# Gradient for bias: [ 0.0007202  -0.00026446]
# Gradient for kernel: [[0.0010396 ]
#  [0.00081789]]
# Gradient for bias: [-0.00045742]
# Epoch 9967:
# Gradient for kernel: [[-0.00044199  0.00024781]
#  [-0.00044215  0.00025191]]
# Gradient for bias: [ 0.00072012 -0.00026443]
# Gradient for kernel: [[0.0010395 ]
#  [0.00081783]]
# Gradient for bias: [-0.00045738]
# Epoch 9968:
# Gradient for kernel: [[-0.00044195  0.00024778]
#  [-0.0004421   0.00025189]]
# Gradient for bias: [ 0.00072004 -0.0002644 ]
# Gradient for kernel: [[0.00103939]
#  [0.00081776]]
# Gradient for bias: [-0.00045734]
# Epoch 9969:
# Gradient for kernel: [[-0.00044191  0.00024776]
#  [-0.00044206  0.00025186]]
# Gradient for bias: [ 0.00071997 -0.00026437]
# Gradient for kernel: [[0.00103929]
#  [0.00081769]]
# Gradient for bias: [-0.00045729]
# Epoch 9970:
# Gradient for kernel: [[-0.00044186  0.00024774]
#  [-0.00044201  0.00025184]]
# Gradient for bias: [ 0.00071989 -0.00026434]
# Gradient for kernel: [[0.00103919]
#  [0.00081763]]
# Gradient for bias: [-0.00045725]
# Epoch 9971:
# Gradient for kernel: [[-0.00044182  0.00024772]
#  [-0.00044197  0.00025182]]
# Gradient for bias: [ 0.00071981 -0.00026431]
# Gradient for kernel: [[0.00103909]
#  [0.00081756]]
# Gradient for bias: [-0.0004572]
# Epoch 9972:
# Gradient for kernel: [[-0.00044177  0.0002477 ]
#  [-0.00044193  0.0002518 ]]
# Gradient for bias: [ 0.00071973 -0.00026428]
# Gradient for kernel: [[0.00103899]
#  [0.0008175 ]]
# Gradient for bias: [-0.00045716]
# Epoch 9973:
# Gradient for kernel: [[-0.00044173  0.00024768]
#  [-0.00044188  0.00025178]]
# Gradient for bias: [ 0.00071965 -0.00026426]
# Gradient for kernel: [[0.00103888]
#  [0.00081743]]
# Gradient for bias: [-0.00045711]
# Epoch 9974:
# Gradient for kernel: [[-0.00044168  0.00024766]
#  [-0.00044184  0.00025176]]
# Gradient for bias: [ 0.00071957 -0.00026423]
# Gradient for kernel: [[0.00103878]
#  [0.00081736]]
# Gradient for bias: [-0.00045707]
# Epoch 9975:
# Gradient for kernel: [[-0.00044164  0.00024763]
#  [-0.00044179  0.00025173]]
# Gradient for bias: [ 0.0007195 -0.0002642]
# Gradient for kernel: [[0.00103868]
#  [0.0008173 ]]
# Gradient for bias: [-0.00045703]
# Epoch 9976:
# Gradient for kernel: [[-0.00044159  0.00024761]
#  [-0.00044175  0.00025171]]
# Gradient for bias: [ 0.00071942 -0.00026417]
# Gradient for kernel: [[0.00103858]
#  [0.00081723]]
# Gradient for bias: [-0.00045699]
# Epoch 9977:
# Gradient for kernel: [[-0.00044155  0.00024759]
#  [-0.0004417   0.00025169]]
# Gradient for bias: [ 0.00071934 -0.00026414]
# Gradient for kernel: [[0.00103847]
#  [0.00081716]]
# Gradient for bias: [-0.00045694]
# Epoch 9978:
# Gradient for kernel: [[-0.0004415   0.00024757]
#  [-0.00044166  0.00025167]]
# Gradient for bias: [ 0.00071926 -0.00026411]
# Gradient for kernel: [[0.00103837]
#  [0.0008171 ]]
# Gradient for bias: [-0.0004569]
# Epoch 9979:
# Gradient for kernel: [[-0.00044146  0.00024755]
#  [-0.00044162  0.00025165]]
# Gradient for bias: [ 0.00071918 -0.00026408]
# Gradient for kernel: [[0.00103827]
#  [0.00081703]]
# Gradient for bias: [-0.00045685]
# Epoch 9980:
# Gradient for kernel: [[-0.00044141  0.00024753]
#  [-0.00044157  0.00025162]]
# Gradient for bias: [ 0.0007191  -0.00026405]
# Gradient for kernel: [[0.00103817]
#  [0.00081697]]
# Gradient for bias: [-0.00045681]
# Epoch 9981:
# Gradient for kernel: [[-0.00044137  0.00024751]
#  [-0.00044153  0.0002516 ]]
# Gradient for bias: [ 0.00071902 -0.00026402]
# Gradient for kernel: [[0.00103807]
#  [0.0008169 ]]
# Gradient for bias: [-0.00045676]
# Epoch 9982:
# Gradient for kernel: [[-0.00044133  0.00024749]
#  [-0.00044148  0.00025158]]
# Gradient for bias: [ 0.00071894 -0.00026399]
# Gradient for kernel: [[0.00103796]
#  [0.00081683]]
# Gradient for bias: [-0.00045672]
# Epoch 9983:
# Gradient for kernel: [[-0.00044128  0.00024746]
#  [-0.00044144  0.00025156]]
# Gradient for bias: [ 0.00071886 -0.00026396]
# Gradient for kernel: [[0.00103786]
#  [0.00081677]]
# Gradient for bias: [-0.00045668]
# Epoch 9984:
# Gradient for kernel: [[-0.00044124  0.00024744]
#  [-0.00044139  0.00025154]]
# Gradient for bias: [ 0.00071879 -0.00026393]
# Gradient for kernel: [[0.00103776]
#  [0.0008167 ]]
# Gradient for bias: [-0.00045664]
# Epoch 9985:
# Gradient for kernel: [[-0.00044119  0.00024742]
#  [-0.00044135  0.00025152]]
# Gradient for bias: [ 0.00071871 -0.0002639 ]
# Gradient for kernel: [[0.00103766]
#  [0.00081664]]
# Gradient for bias: [-0.00045659]
# Epoch 9986:
# Gradient for kernel: [[-0.00044115  0.0002474 ]
#  [-0.0004413   0.00025149]]
# Gradient for bias: [ 0.00071863 -0.00026387]
# Gradient for kernel: [[0.00103755]
#  [0.00081657]]
# Gradient for bias: [-0.00045655]
# Epoch 9987:
# Gradient for kernel: [[-0.0004411   0.00024738]
#  [-0.00044126  0.00025147]]
# Gradient for bias: [ 0.00071855 -0.00026384]
# Gradient for kernel: [[0.00103745]
#  [0.0008165 ]]
# Gradient for bias: [-0.00045651]
# Epoch 9988:
# Gradient for kernel: [[-0.00044106  0.00024736]
#  [-0.00044121  0.00025145]]
# Gradient for bias: [ 0.00071847 -0.00026381]
# Gradient for kernel: [[0.00103735]
#  [0.00081644]]
# Gradient for bias: [-0.00045646]
# Epoch 9989:
# Gradient for kernel: [[-0.00044101  0.00024734]
#  [-0.00044117  0.00025143]]
# Gradient for bias: [ 0.0007184  -0.00026378]
# Gradient for kernel: [[0.00103724]
#  [0.00081637]]
# Gradient for bias: [-0.00045643]
# Epoch 9990:
# Gradient for kernel: [[-0.00044097  0.00024732]
#  [-0.00044112  0.00025141]]
# Gradient for bias: [ 0.00071832 -0.00026375]
# Gradient for kernel: [[0.00103714]
#  [0.0008163 ]]
# Gradient for bias: [-0.00045638]
# Epoch 9991:
# Gradient for kernel: [[-0.00044092  0.0002473 ]
#  [-0.00044108  0.00025139]]
# Gradient for bias: [ 0.00071825 -0.00026372]
# Gradient for kernel: [[0.00103704]
#  [0.00081624]]
# Gradient for bias: [-0.00045634]
# Epoch 9992:
# Gradient for kernel: [[-0.00044088  0.00024727]
#  [-0.00044103  0.00025136]]
# Gradient for bias: [ 0.00071817 -0.00026369]
# Gradient for kernel: [[0.00103693]
#  [0.00081617]]
# Gradient for bias: [-0.0004563]
# Epoch 9993:
# Gradient for kernel: [[-0.00044084  0.00024725]
#  [-0.00044099  0.00025134]]
# Gradient for bias: [ 0.00071809 -0.00026366]
# Gradient for kernel: [[0.00103683]
#  [0.0008161 ]]
# Gradient for bias: [-0.00045625]
# Epoch 9994:
# Gradient for kernel: [[-0.00044079  0.00024723]
#  [-0.00044094  0.00025132]]
# Gradient for bias: [ 0.00071801 -0.00026363]
# Gradient for kernel: [[0.00103673]
#  [0.00081604]]
# Gradient for bias: [-0.00045621]
# Epoch 9995:
# Gradient for kernel: [[-0.00044074  0.00024721]
#  [-0.0004409   0.0002513 ]]
# Gradient for bias: [ 0.00071794 -0.0002636 ]
# Gradient for kernel: [[0.00103663]
#  [0.00081597]]
# Gradient for bias: [-0.00045617]
# Epoch 9996:
# Gradient for kernel: [[-0.0004407   0.00024719]
#  [-0.00044086  0.00025128]]
# Gradient for bias: [ 0.00071786 -0.00026357]
# Gradient for kernel: [[0.00103653]
#  [0.00081591]]
# Gradient for bias: [-0.00045613]
# Epoch 9997:
# Gradient for kernel: [[-0.00044066  0.00024717]
#  [-0.00044081  0.00025126]]
# Gradient for bias: [ 0.00071778 -0.00026354]
# Gradient for kernel: [[0.00103643]
#  [0.00081584]]
# Gradient for bias: [-0.00045609]
# Epoch 9998:
# Gradient for kernel: [[-0.00044061  0.00024715]
#  [-0.00044077  0.00025123]]
# Gradient for bias: [ 0.0007177  -0.00026351]
# Gradient for kernel: [[0.00103632]
#  [0.00081577]]
# Gradient for bias: [-0.00045605]
# Epoch 9999:
# Gradient for kernel: [[-0.00044057  0.00024713]
#  [-0.00044072  0.00025121]]
# Gradient for bias: [ 0.00071763 -0.00026348]
# Gradient for kernel: [[0.00103622]
#  [0.00081571]]
# Gradient for bias: [-0.00045601]
# True labels (y): [0. 1. 1. 0.]
# Predictions after training: [0.04561535 0.942938   0.9429838  0.05864919]
# 'A program has been written to output the gradients at each epoch using TensorFlow s GradientTape library, and it has been tested. '

# %% [markdown]
# #True labels (y): [0. 1. 1. 0.]
# #Predictions after training: [0.03138629 0.95564526 0.9624098  0.04976979] 이도윤
